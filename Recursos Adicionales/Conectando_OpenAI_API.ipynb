# %% [markdown]
# Autor:
# Manuel Eugenio Morocho Cayamcela, PhD
#
# # Introducción al API de OpenAI

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Bienvenido a este tutorial básico para usar la API de OpenAI en un Jupyter Notebook. Este tutorial cubrirá cómo generar texto utilizando el modelo GPT-3 de OpenAI.
#
# Primero, necesitarás instalar la biblioteca `openai` de Python. Puedes hacerlo ejecutando el siguiente comando en una celda de tu Jupyter Notebook:

# %%
# !pip install --upgrade openai

# %%
from openai import OpenAI

# %% [markdown]
# Antes de poder usar la API de OpenAI, necesitarás una clave de API. Puedes obtener una registrándote en el [sitio web de OpenAI](https://openai.com/signup/). Una vez que tengas tu clave de API, puedes configurarla de la siguiente manera:

# %%
import os

# Reemplaza 'tu-clave-de-api' con tu clave de API real
os.environ['OPENAI_API_KEY'] = 'tu-clave-de-api'

# %% [markdown]
# **Nota:** Recuerda reemplazar `'tu-clave-de-api'` con tu clave de API real. Además, ten en cuenta que debes mantener tu clave de API segura y no compartirla con nadie.
#
# Ahora que hemos configurado nuestra clave de API, podemos usar la API de OpenAI para generar texto. Aquí hay un ejemplo de cómo hacerlo:

# %%
client = OpenAI()

completion = client.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {"role": "system", "content": "You are a poetic assistant, skilled in explaining complex programming concepts with creative flair."},
    {"role": "user", "content": "Compose a poem that explains the concept of recursion in programming."}
  ]
)

print(completion.choices[0].message)
# Out:
# ChatCompletionMessage(content="In the realm of code and logic's art,\nThere lies a concept, dear to heart,\nRecursion dances with grace and might,\nA loop that mirrors the starry night.\n\nLike a mirror reflecting its reflection,\nRecursion calls itself, a strong connection,\nA function that calls upon its own name,\nIn a loop of beauty, not seeking fame.\n\nWith each recursive call anew,\nA journey within itself, true and true,\nBreaking down tasks to small and fine,\nSolving problems like aged wine.\n\nA loop within a loop, a tale untold,\nSolving puzzles, mysteries unfold,\nInfinite power within its loop,\nRecursive magic, a programmer's scoop.\n\nSo embrace recursion, its power vast,\nIn programming's world, it's unsurpassed,\nA poetic loop, a dance sublime,\nIn the realm of code, for all time.", refusal=None, role='assistant', function_call=None, tool_calls=None)

# %% [markdown]
# Y eso es todo! Ahora deberías ser capaz de usar la API de OpenAI para generar texto en un Jupyter Notebook. Recuerda que puedes experimentar con diferentes valores para `prompt`, `temperature` y `max_tokens` para ver cómo afectan al texto generado.

# %% [markdown]
# ## Generación de imágenes con OpenAI

# %%
from openai import OpenAI
client = OpenAI()

response = client.images.generate(
  model= "dall-e-3",
  prompt="A cute, fluffy cat with the body of a cactus.",
  size= "1024x1024",
  quality="standard",
  n=1,
)

image_url = response.data[0].url

# %%
image_url
# Out:
# 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-W20tbZtH09wd8KWlhPJ668Sc/user-3TRfUw5UEu4zE46s10mjt1HV/img-N7UOfaGWINqVg9oOrsfaqMBA.png?st=2024-09-14T17%3A46%3A22Z&se=2024-09-14T19%3A46%3A22Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-09-13T23%3A11%3A39Z&ske=2024-09-14T23%3A11%3A39Z&sks=b&skv=2024-08-04&sig=fTuixXrOuethcbmKKzYOSMKwVurkv/OsCPOTf0V3WaU%3D'

# %%
from openai import OpenAI
client = OpenAI()

response = client.images.generate(
  model="dall-e-3",
  prompt="a monkey in a skateboard in the space eating pizza",
  size="1024x1024",
  quality="standard",
  n=1,
)

image_url = response.data[0].url
image_url

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from openai import OpenAI
client = OpenAI()

response = client.images.generate(
  model="dall-e-3",
  prompt="Un gato con la cabeza de un cactus.",
  size="1024x1024",
  quality="standard",
  n=1,
)

image_url = response.data[0].url
image_url
# Out:
# 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-W20tbZtH09wd8KWlhPJ668Sc/user-3TRfUw5UEu4zE46s10mjt1HV/img-Y4rbeA1f0T8vtxPn0uaZvUIm.png?st=2024-09-14T17%3A48%3A19Z&se=2024-09-14T19%3A48%3A19Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-09-13T23%3A13%3A28Z&ske=2024-09-14T23%3A13%3A28Z&sks=b&skv=2024-08-04&sig=zEWiYwj25/Z7dWaQUtrx78dZjPTwBsbSxMX2r2BGTgw%3D'

# %% [markdown]
# ## Texto a voz con OpenAI

# %%
from openai import OpenAI

client = OpenAI()

response = client.audio.speech.create(
    model="tts-1",
    voice="alloy",
    #input="We are having a great time learning about OpenAI's APIs and how to use them in our projects.",
    input="Nos estamos divirtiendo y aprendiendo a usar el API de OpenAI.",
)

response.stream_to_file("output.mp3")
# Out:
# /var/folders/8j/f0xtldm91_1c2bpdr69fxgzw0000gn/T/ipykernel_54915/2258234625.py:12: DeprecationWarning: Due to a bug, this method doesn't actually stream the response content, `.with_streaming_response.method()` should be used instead
#   response.stream_to_file("output.mp3")

# %% [markdown]
# ## Voz a texto con OpenAI

# %%
from openai import OpenAI
client = OpenAI()

audio_file= open("/Users/eugenio/Documents/Notebooks_ArtificialIntelligence/Recursos Adicionales/output.mp3", "rb")
transcription = client.audio.transcriptions.create(
  model="whisper-1", 
  file=audio_file
)
print(transcription.text)
# Out:
# Nos estamos divirtiendo y aprendiendo a usar el API de OpenAI.

# %% [markdown]
# ## Preguntando a un DataFrame de Pandas

# %%
import pandas as pd

# Import the 'mall_customers.csv' file
df = pd.read_csv('/Users/eugenio/Documents/Notebooks_ArtificialIntelligence/Bases de Datos/mall_customers.csv')

# Display the first 5 records
df.head(5)
#EDA
# Convertir la tabla a una representación de cadena (string)
df_string = df.to_string()

# Pregunta sobre la edad promedio de los clientes en la tabla
#question = "¿Cómo diseñarías una campaña de marketing para que el segmento de clientes Alto Ingreso-Bajo Gasto incremente su puntaje de gasto?"
question = "¿Cómo diseñarías una campaña de marketing con un enfoque generacional?"


# Pasar la variable al API de OpenAI
client = OpenAI()
response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a data analyst. Here is the data:\n" + df_string},
        {"role": "user", "content": question}
    ]
)

# Obtener la respuesta del API
answer = response.choices[0].message.content
print(answer)
# Out:
# Diseñar una campaña de marketing con un enfoque generacional implica segmentar el mercado en diferentes generaciones y adaptar el mensaje, los canales de comunicación y las estrategias a las características y preferencias de cada grupo de edad. Aquí hay algunos pasos para diseñar una campaña de marketing generacional:
#
# 1. **Identificar las generaciones relevantes**: En primer lugar, es importante identificar las generaciones a las que se quiere dirigir la campaña. Las generaciones principales suelen ser: Baby Boomers (nacidos entre 1946 y 1964), Generación X (nacidos entre 1965 y 1980), Millennials o Generación Y (nacidos entre 1981 y 1996) y Generación Z (nacidos a partir de 1997).
#
# ...

# %% [markdown]
# Eso es todo, ahora puedes probar OpenAI en tu propio código. ¡Buena suerte!

# %% [markdown]
# ### **Actividad Individual 9.4:** Uso de la API de OpenAI
#
# Después de seguir el tutorial del notebook 'Conectando_OpenAI_API', los estudiantes realizarán una actividad individual en la que utilizarán la API de OpenAI para realizar una tarea específica de procesamiento de lenguaje natural (NLP). Los estudiantes elegirán dos modelos disponibles en OpenAI, los probarán y realizarán un análisis crítico de los resultados generados por cada modelo.
#
# #### Objetivo
#
# El objetivo de esta actividad es que los estudiantes usen modelos de OpenAI en dos tareas específicas y desarrollen habilidades críticas para evaluar la calidad de los resultados generados.
#
# #### Instrucciones
#
# 1. **Configura el Entorno**:
#     - Asegúrate de tener acceso a la API de OpenAI. Si no tienes una clave de API, regístrate en [OpenAI](https://beta.openai.com/signup/) y obtén una clave de API.
#
# 2. **Elige Dos Modelos de OpenAI**:
#     - Visita la [documentación de la API de OpenAI](https://beta.openai.com/docs/models) y elige dos modelos para la tarea que deseas realizar. Puedes elegir entre tareas como generación de texto, generación de imágenes, clasificación, respuesta a preguntas, etc.
#
# 3. **Prueba los Modelos**:
#     - Utiliza los modelos seleccionados para realizar las tareas seleccionadas.
#
# 4. **Analiza los Resultados**:
#     - Revisa los resultados generados por ambos modelos y compáralos con el conjunto de datos original. Evalúa la relevancia y coherencia de cada resultado.
#
# 6. **Entrega**:
#     - Prepara un informe breve que incluya:
#         - Una descripción de la tarea que realizaste.
#         - Los resultados generados por ambos modelos.
#         - Un análisis crítico de cada resultado, incluyendo observaciones sobre su relevancia y coherencia.
#         - Expórtalo como PDF y súbelo a la actividad designada en Moodle.
