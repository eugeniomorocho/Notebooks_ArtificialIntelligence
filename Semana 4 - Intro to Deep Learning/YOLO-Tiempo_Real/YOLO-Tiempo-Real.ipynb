# %% [markdown]
# Autor:
# Manuel Eugenio Morocho Cayamcela, PhD
#
# # YOLO en Tiempo Real: Detección de Objetos
#
# Bienvenidos a este cuaderno de Jupyter, donde exploraremos la tarea de la detección de objetos en tiempo real utilizando YOLO (You Only Look Once), una técnica avanzada de visión por computadora.
#
# En este cuaderno, aprenderás a utilizar YOLO para identificar y localizar diversos objetos en imágenes y secuencias de video. Esta habilidad es esencial en una amplia gama de aplicaciones, desde la conducción autónoma hasta la vigilancia de seguridad, y representa uno de los avances más emocionantes en el campo de la inteligencia artificial y la visión por computadora.
#
# A lo largo de este curso, explorarás conceptos clave como:
#
# - Detección de objetos en tiempo real.
# - Configuración de modelos YOLO pre-entrenados.
# - Interpretación de resultados de detección.
# - Aplicaciones prácticas de la detección de objetos.
#
# ¡Prepárate para sumergirte en un emocionante mundo de visión por computadora y adquirir habilidades valiosas que te servirán en tu carrera en inteligencia artificial y más allá!
#
# Recuerda consultar este cuaderno para acceder a los recursos y ejemplos que te ayudarán a comprender YOLO y la percepción computacional en tiempo real.
#
# Eugenio.

# %% [markdown]
# El siguiente código utiliza el comando `!pip` para instalar dos paquetes de Python: `opencv-python` y `ultralytics`.
#
# - `opencv-python`: Esta es una biblioteca popular para tareas de visión por computadora en Python. Proporciona una variedad de funciones para el procesamiento de imágenes y videos, incluyendo detección de objetos, manipulación de imágenes y extracción de características.
#
# - `ultralytics`: Esta es una biblioteca construida sobre PyTorch, que se enfoca principalmente en tareas de visión por computadora como detección de objetos y clasificación de imágenes. Proporciona interfaces fáciles de usar para entrenar y evaluar modelos de aprendizaje profundo para estas tareas.
#
# Al ejecutar este comando, estás instalando estos paquetes en tu entorno de Python para que puedas usarlos en tu código.

# %%
# Instalamos las librerías necesarias
# !pip install opencv-python ultralytics

# %% [markdown]
# Este fragmento de código importa tres bibliotecas en Python:
#
# 1. `ultralytics`: Esta es una biblioteca que proporciona una interfaz para usar modelos de detección de objetos YOLO (You Only Look Once). Permite entrenar, evaluar y utilizar modelos de detección de objetos de manera eficiente.
#
# 2. `cv2` (OpenCV): Esta es una biblioteca popular para el procesamiento de imágenes y videos en Python. Proporciona una amplia gama de funciones para trabajar con imágenes y videos, incluyendo cargar imágenes, realizar operaciones de procesamiento de imágenes, y mostrar imágenes en una ventana, entre otros.
#
# 3. `math`: Este es un módulo estándar de Python que proporciona funciones matemáticas comunes, como funciones trigonométricas, logarítmicas y aritméticas.
#
# El código importa estas bibliotecas para utilizarlas en el resto del programa, pero en este fragmento específico no se están utilizando ninguna función o clase de estas bibliotecas.

# %%
# Importamos las librerías necesarias
from ultralytics import YOLO
import cv2
import math

# %%
# Cargamos el modelo YOLO pre-entrenado en COCO dataset
model = YOLO("yolo-Weights/yolov8n.pt")

# %%
# Revisamos las clases que puede detectar el modelo
model.names
# Out:
# {0: 'person',
#  1: 'bicycle',
#  2: 'car',
#  3: 'motorcycle',
#  4: 'airplane',
#  5: 'bus',
#  6: 'train',
#  7: 'truck',
#  8: 'boat',
#  9: 'traffic light',
#  10: 'fire hydrant',
#  11: 'stop sign',
#  12: 'parking meter',
#  13: 'bench',
#  14: 'bird',
#  15: 'cat',
#  16: 'dog',
#  17: 'horse',
#  18: 'sheep',
#  19: 'cow',
#  20: 'elephant',
#  21: 'bear',
#  22: 'zebra',
#  23: 'giraffe',
#  24: 'backpack',
#  25: 'umbrella',
#  26: 'handbag',
#  27: 'tie',
#  28: 'suitcase',
#  29: 'frisbee',
#  30: 'skis',
#  31: 'snowboard',
#  32: 'sports ball',
#  33: 'kite',
#  34: 'baseball bat',
#  35: 'baseball glove',
#  36: 'skateboard',
#  37: 'surfboard',
#  38: 'tennis racket',
#  39: 'bottle',
#  40: 'wine glass',
#  41: 'cup',
#  42: 'fork',
#  43: 'knife',
#  44: 'spoon',
#  45: 'bowl',
#  46: 'banana',
#  47: 'apple',
#  48: 'sandwich',
#  49: 'orange',
#  50: 'broccoli',
#  51: 'carrot',
#  52: 'hot dog',
#  53: 'pizza',
#  54: 'donut',
#  55: 'cake',
#  56: 'chair',
#  57: 'couch',
#  58: 'potted plant',
#  59: 'bed',
#  60: 'dining table',
#  61: 'toilet',
#  62: 'tv',
#  63: 'laptop',
#  64: 'mouse',
#  65: 'remote',
#  66: 'keyboard',
#  67: 'cell phone',
#  68: 'microwave',
#  69: 'oven',
#  70: 'toaster',
#  71: 'sink',
#  72: 'refrigerator',
#  73: 'book',
#  74: 'clock',
#  75: 'vase',
#  76: 'scissors',
#  77: 'teddy bear',
#  78: 'hair drier',
#  79: 'toothbrush'}

# %%
# Definimos una lista de nombres con todas las clases para identificar objetos detectados
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ] # Aquí se enumeran todas las clases

# %%
# Configuramos la captura de video desde la cámara
captura = cv2.VideoCapture(0) # Se abre la cámara por defecto

# Establecemos el ancho y alto de la imagen
captura.set(cv2.CAP_PROP_FRAME_WIDTH, 640) # Ancho de la imagen
captura.set(cv2.CAP_PROP_FRAME_HEIGHT, 480) # Alto de la imagen

# Iniciamos un bucle para procesar los fotogramas de la cámara
while True:
    success, img = captura.read() # Capturamos un fotograma

    # Realizamos la detección de objetos en la imagen capturada (usando el modelo de YOLO pre-entrenado que cargamos anteriormente)
    results = model(img, stream=True)

   # Procesamos los resultados de la detección
    for r in results:
        boxes = r.boxes

        # Iteramos sobre las cajas delimitadoras detectadas
        for box in boxes:
            # Obtenemos las coordenadas de la caja delimitadora
            x1, y1, x2, y2 = box.xyxy[0] # se utiliza para acceder al primer (y posiblemente único) conjunto de coordenadas en box.xyxy
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # Convertimos a valores enteros

            # Dibujamos la caja delimitadora en la imagen
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 1)

            # Obtenemos la confianza de la detección
            confidence = math.ceil((box.conf[0]*100)) #/100
            print("Confidence --->",confidence)

            # Obtenemos el nombre de la clase detectada
            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            # Mostramos el nombre de la clase junto a la caja delimitadora
            org = [x1, y1] # Define el punto de origen (esquina superior izquierda) donde se colocará el texto en la imagen
            font = cv2.FONT_HERSHEY_SIMPLEX # Define el tipo de fuente que se utilizará para el texto
            fontScale = 1 # Define la escala de la fuente (tamaño del texto)
            color = (255, 0, 0) # Color: Azul (formato BGR)
            thickness = 1 # Define el grosor de las líneas del texto
            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness) # Dibuja el texto en la imagen en la posición especificada con la fuente, escala, color y grosor definidos

    # Mostramos la imagen con las detecciones
    cv2.imshow('Webcam', img) # Muestra la imagen en una ventana llamada 'Webcam'

    # Salimos del bucle si se presiona la tecla 'q'
    #if cv2.waitKey(1) == ord('q'):
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

# Liberamos la cámara y cerramos todas las ventanas
captura.release()
cv2.destroyAllWindows()
# Out:
# 2024-09-14 09:49:13.851 Python[52171:3453007] WARNING: AVCaptureDeviceTypeExternal is deprecated for Continuity Cameras. Please use AVCaptureDeviceTypeContinuityCamera and add NSCameraUseContinuityCameraDeviceType to your Info.plist.
# 0: 480x640 1 cell phone, 1 scissors, 277.0ms
# Confidence ---> 77
# Class name --> cell phone
# Confidence ---> 43
# Class name --> scissors
# Speed: 13.3ms preprocess, 277.0ms inference, 22.4ms postprocess per image at shape (1, 3, 480, 640)
# 2024-09-14 09:49:21.441 Python[52171:3453007] WARNING: Secure coding is not enabled for restorable state! Enable secure coding by implementing NSApplicationDelegate.applicationSupportsSecureRestorableState: and returning YES.
# 0: 480x640 1 cell phone, 1 scissors, 165.1ms
# Confidence ---> 77
# Class name --> cell phone
# Confidence ---> 33
# Class name --> scissors
# Speed: 2.2ms preprocess, 165.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 351.6ms
# Confidence ---> 78
# Class name --> cell phone
# Confidence ---> 56
# Class name --> scissors
# Speed: 42.0ms preprocess, 351.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 126.5ms
# Confidence ---> 81
# Class name --> cell phone
# Confidence ---> 46
# Class name --> scissors
# Confidence ---> 27
# Class name --> person
# Speed: 3.1ms preprocess, 126.5ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 129.0ms
# Confidence ---> 73
# Class name --> cell phone
# Confidence ---> 41
# Class name --> scissors
# Confidence ---> 28
# Class name --> person
# Speed: 1.5ms preprocess, 129.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 118.9ms
# Confidence ---> 84
# Class name --> cell phone
# Confidence ---> 32
# Class name --> scissors
# Speed: 3.2ms preprocess, 118.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 107.5ms
# Confidence ---> 84
# Class name --> cell phone
# Confidence ---> 41
# Class name --> scissors
# Confidence ---> 30
# Class name --> person
# Speed: 1.3ms preprocess, 107.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 142.2ms
# Confidence ---> 84
# Class name --> cell phone
# Confidence ---> 52
# Class name --> scissors
# Confidence ---> 38
# Class name --> person
# Speed: 1.4ms preprocess, 142.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 123.2ms
# Confidence ---> 82
# Class name --> cell phone
# Confidence ---> 40
# Class name --> scissors
# Confidence ---> 26
# Class name --> person
# Speed: 3.0ms preprocess, 123.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 129.5ms
# Confidence ---> 85
# Class name --> cell phone
# Confidence ---> 38
# Class name --> scissors
# Speed: 1.0ms preprocess, 129.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 93.4ms
# Confidence ---> 82
# Class name --> cell phone
# Confidence ---> 44
# Class name --> scissors
# Confidence ---> 28
# Class name --> person
# Speed: 2.2ms preprocess, 93.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 82.9ms
# Confidence ---> 76
# Class name --> cell phone
# Confidence ---> 45
# Class name --> scissors
# Speed: 1.2ms preprocess, 82.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 92.6ms
# Confidence ---> 81
# Class name --> cell phone
# Confidence ---> 45
# Class name --> scissors
# Confidence ---> 32
# Class name --> person
# Speed: 2.0ms preprocess, 92.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 84.8ms
# Confidence ---> 81
# Class name --> cell phone
# Confidence ---> 40
# Class name --> scissors
# Speed: 1.7ms preprocess, 84.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 97.7ms
# Confidence ---> 81
# Class name --> cell phone
# Confidence ---> 48
# Class name --> scissors
# Confidence ---> 29
# Class name --> person
# Speed: 2.4ms preprocess, 97.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 89.8ms
# Confidence ---> 81
# Class name --> cell phone
# Confidence ---> 34
# Class name --> scissors
# Confidence ---> 28
# Class name --> person
# Speed: 1.7ms preprocess, 89.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 93.8ms
# Confidence ---> 79
# Class name --> cell phone
# Confidence ---> 44
# Class name --> scissors
# Speed: 1.6ms preprocess, 93.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 91.0ms
# Confidence ---> 87
# Class name --> cell phone
# Confidence ---> 45
# Class name --> scissors
# Confidence ---> 28
# Class name --> person
# Speed: 1.5ms preprocess, 91.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 108.7ms
# Confidence ---> 79
# Class name --> cell phone
# Confidence ---> 39
# Class name --> scissors
# Confidence ---> 35
# Class name --> person
# Speed: 2.2ms preprocess, 108.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 95.7ms
# Confidence ---> 86
# Class name --> cell phone
# Confidence ---> 45
# Class name --> scissors
# Confidence ---> 28
# Class name --> person
# Speed: 2.1ms preprocess, 95.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 89.3ms
# Confidence ---> 77
# Class name --> cell phone
# Confidence ---> 45
# Class name --> scissors
# Confidence ---> 28
# Class name --> person
# Speed: 1.4ms preprocess, 89.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 92.3ms
# Confidence ---> 81
# Class name --> cell phone
# Confidence ---> 46
# Class name --> scissors
# Confidence ---> 27
# Class name --> person
# Speed: 1.1ms preprocess, 92.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 96.4ms
# Confidence ---> 85
# Class name --> cell phone
# Confidence ---> 40
# Class name --> scissors
# Confidence ---> 29
# Class name --> person
# Speed: 1.7ms preprocess, 96.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 97.5ms
# Confidence ---> 84
# Class name --> cell phone
# Confidence ---> 43
# Class name --> scissors
# Confidence ---> 29
# Class name --> person
# Speed: 1.8ms preprocess, 97.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 105.9ms
# Confidence ---> 85
# Class name --> cell phone
# Confidence ---> 48
# Class name --> scissors
# Confidence ---> 29
# Class name --> person
# Speed: 2.7ms preprocess, 105.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 100.8ms
# Confidence ---> 82
# Class name --> cell phone
# Confidence ---> 50
# Class name --> scissors
# Speed: 1.7ms preprocess, 100.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 118.5ms
# Confidence ---> 82
# Class name --> cell phone
# Confidence ---> 49
# Class name --> scissors
# Confidence ---> 31
# Class name --> person
# Speed: 1.4ms preprocess, 118.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 98.2ms
# Confidence ---> 80
# Class name --> cell phone
# Confidence ---> 35
# Class name --> scissors
# Confidence ---> 26
# Class name --> person
# Speed: 1.8ms preprocess, 98.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 105.8ms
# Confidence ---> 86
# Class name --> cell phone
# Confidence ---> 36
# Class name --> scissors
# Speed: 1.6ms preprocess, 105.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 101.1ms
# Confidence ---> 74
# Class name --> cell phone
# Confidence ---> 47
# Class name --> scissors
# Speed: 1.2ms preprocess, 101.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 99.1ms
# Confidence ---> 80
# Class name --> cell phone
# Confidence ---> 33
# Class name --> scissors
# Confidence ---> 28
# Class name --> person
# Speed: 1.9ms preprocess, 99.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 99.1ms
# Confidence ---> 84
# Class name --> cell phone
# Confidence ---> 37
# Class name --> scissors
# Speed: 1.8ms preprocess, 99.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 107.1ms
# Confidence ---> 83
# Class name --> cell phone
# Confidence ---> 34
# Class name --> scissors
# Speed: 1.6ms preprocess, 107.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 99.2ms
# Confidence ---> 81
# Class name --> cell phone
# Confidence ---> 43
# Class name --> scissors
# Confidence ---> 41
# Class name --> person
# Speed: 1.5ms preprocess, 99.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 100.4ms
# Confidence ---> 72
# Class name --> cell phone
# Confidence ---> 41
# Class name --> scissors
# Confidence ---> 28
# Class name --> person
# Speed: 2.2ms preprocess, 100.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 101.1ms
# Confidence ---> 75
# Class name --> cell phone
# Confidence ---> 31
# Class name --> scissors
# Speed: 1.9ms preprocess, 101.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 103.1ms
# Confidence ---> 84
# Class name --> cell phone
# Confidence ---> 43
# Class name --> scissors
# Speed: 1.5ms preprocess, 103.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 99.6ms
# Confidence ---> 81
# Class name --> cell phone
# Confidence ---> 38
# Class name --> scissors
# Speed: 2.7ms preprocess, 99.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 102.0ms
# Confidence ---> 84
# Class name --> cell phone
# Confidence ---> 58
# Class name --> scissors
# Confidence ---> 34
# Class name --> person
# Speed: 2.1ms preprocess, 102.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 100.9ms
# Confidence ---> 77
# Class name --> cell phone
# Confidence ---> 32
# Class name --> scissors
# Confidence ---> 31
# Class name --> person
# Speed: 2.1ms preprocess, 100.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 102.2ms
# Confidence ---> 79
# Class name --> cell phone
# Confidence ---> 40
# Class name --> scissors
# Confidence ---> 29
# Class name --> person
# Speed: 1.7ms preprocess, 102.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 102.5ms
# Confidence ---> 84
# Class name --> cell phone
# Confidence ---> 36
# Class name --> scissors
# Confidence ---> 26
# Class name --> person
# Speed: 1.9ms preprocess, 102.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 100.2ms
# Confidence ---> 80
# Class name --> cell phone
# Confidence ---> 40
# Class name --> scissors
# Speed: 1.4ms preprocess, 100.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 103.0ms
# Confidence ---> 80
# Class name --> cell phone
# Confidence ---> 42
# Class name --> scissors
# Confidence ---> 33
# Class name --> person
# Speed: 2.6ms preprocess, 103.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 240.2ms
# Confidence ---> 80
# Class name --> cell phone
# Confidence ---> 41
# Class name --> scissors
# Confidence ---> 29
# Class name --> person
# Speed: 1.6ms preprocess, 240.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 135.8ms
# Confidence ---> 76
# Class name --> cell phone
# Confidence ---> 38
# Class name --> scissors
# Confidence ---> 30
# Class name --> person
# Speed: 2.1ms preprocess, 135.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 103.1ms
# Confidence ---> 82
# Class name --> cell phone
# Confidence ---> 40
# Class name --> scissors
# Confidence ---> 30
# Class name --> person
# Speed: 1.6ms preprocess, 103.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 104.3ms
# Confidence ---> 79
# Class name --> cell phone
# Confidence ---> 28
# Class name --> scissors
# Speed: 1.9ms preprocess, 104.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 99.8ms
# Confidence ---> 78
# Class name --> cell phone
# Confidence ---> 35
# Class name --> scissors
# Confidence ---> 30
# Class name --> person
# Speed: 1.4ms preprocess, 99.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 101.6ms
# Confidence ---> 72
# Class name --> cell phone
# Confidence ---> 47
# Class name --> scissors
# Speed: 1.5ms preprocess, 101.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 101.8ms
# Confidence ---> 81
# Class name --> cell phone
# Confidence ---> 39
# Class name --> scissors
# Confidence ---> 28
# Class name --> person
# Speed: 1.7ms preprocess, 101.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 105.3ms
# Confidence ---> 77
# Class name --> cell phone
# Confidence ---> 39
# Class name --> scissors
# Confidence ---> 33
# Class name --> person
# Speed: 1.6ms preprocess, 105.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 99.4ms
# Confidence ---> 83
# Class name --> cell phone
# Confidence ---> 33
# Class name --> scissors
# Speed: 1.5ms preprocess, 99.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 95.9ms
# Confidence ---> 85
# Class name --> cell phone
# Confidence ---> 41
# Class name --> scissors
# Speed: 1.7ms preprocess, 95.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 108.9ms
# Confidence ---> 84
# Class name --> cell phone
# Confidence ---> 32
# Class name --> scissors
# Speed: 1.7ms preprocess, 108.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 101.1ms
# Confidence ---> 78
# Class name --> cell phone
# Confidence ---> 46
# Class name --> scissors
# Speed: 1.7ms preprocess, 101.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 103.2ms
# Confidence ---> 73
# Class name --> cell phone
# Confidence ---> 35
# Class name --> scissors
# Confidence ---> 29
# Class name --> person
# Speed: 1.8ms preprocess, 103.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 98.1ms
# Confidence ---> 79
# Class name --> cell phone
# Confidence ---> 49
# Class name --> scissors
# Confidence ---> 39
# Class name --> person
# Speed: 2.2ms preprocess, 98.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 112.6ms
# Confidence ---> 79
# Class name --> cell phone
# Confidence ---> 45
# Class name --> scissors
# Speed: 2.2ms preprocess, 112.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 106.7ms
# Confidence ---> 81
# Class name --> cell phone
# Confidence ---> 39
# Class name --> scissors
# Speed: 1.7ms preprocess, 106.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 99.9ms
# Confidence ---> 79
# Class name --> cell phone
# Confidence ---> 51
# Class name --> scissors
# Confidence ---> 38
# Class name --> person
# Speed: 1.7ms preprocess, 99.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 100.7ms
# Confidence ---> 79
# Class name --> cell phone
# Confidence ---> 40
# Class name --> scissors
# Confidence ---> 28
# Class name --> person
# Speed: 2.1ms preprocess, 100.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 104.1ms
# Confidence ---> 82
# Class name --> cell phone
# Confidence ---> 39
# Class name --> scissors
# Speed: 1.9ms preprocess, 104.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 117.3ms
# Confidence ---> 87
# Class name --> cell phone
# Confidence ---> 48
# Class name --> scissors
# Speed: 1.7ms preprocess, 117.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 112.1ms
# Confidence ---> 81
# Class name --> cell phone
# Confidence ---> 34
# Class name --> person
# Confidence ---> 33
# Class name --> scissors
# Speed: 2.1ms preprocess, 112.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 115.8ms
# Confidence ---> 74
# Class name --> cell phone
# Confidence ---> 32
# Class name --> scissors
# Confidence ---> 29
# Class name --> person
# Speed: 2.6ms preprocess, 115.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 114.9ms
# Confidence ---> 81
# Class name --> cell phone
# Confidence ---> 34
# Class name --> scissors
# Confidence ---> 29
# Class name --> person
# Speed: 2.9ms preprocess, 114.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 106.4ms
# Confidence ---> 86
# Class name --> cell phone
# Confidence ---> 43
# Class name --> scissors
# Speed: 2.2ms preprocess, 106.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 109.6ms
# Confidence ---> 84
# Class name --> cell phone
# Confidence ---> 39
# Class name --> person
# Confidence ---> 30
# Class name --> scissors
# Speed: 1.8ms preprocess, 109.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 112.6ms
# Confidence ---> 84
# Class name --> cell phone
# Confidence ---> 54
# Class name --> scissors
# Confidence ---> 31
# Class name --> person
# Speed: 2.3ms preprocess, 112.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 112.0ms
# Confidence ---> 82
# Class name --> cell phone
# Confidence ---> 55
# Class name --> scissors
# Confidence ---> 31
# Class name --> person
# Speed: 1.6ms preprocess, 112.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 123.2ms
# Confidence ---> 84
# Class name --> cell phone
# Confidence ---> 50
# Class name --> scissors
# Speed: 1.8ms preprocess, 123.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 122.8ms
# Confidence ---> 81
# Class name --> cell phone
# Confidence ---> 33
# Class name --> scissors
# Speed: 1.7ms preprocess, 122.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 111.6ms
# Confidence ---> 73
# Class name --> cell phone
# Confidence ---> 44
# Class name --> person
# Confidence ---> 41
# Class name --> scissors
# Speed: 1.9ms preprocess, 111.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 115.9ms
# Confidence ---> 81
# Class name --> cell phone
# Confidence ---> 39
# Class name --> scissors
# Confidence ---> 32
# Class name --> person
# Speed: 1.9ms preprocess, 115.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 108.9ms
# Confidence ---> 80
# Class name --> cell phone
# Confidence ---> 34
# Class name --> scissors
# Speed: 1.6ms preprocess, 108.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 104.2ms
# Confidence ---> 83
# Class name --> cell phone
# Confidence ---> 39
# Class name --> scissors
# Speed: 1.6ms preprocess, 104.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 128.7ms
# Confidence ---> 71
# Class name --> cell phone
# Confidence ---> 48
# Class name --> scissors
# Confidence ---> 28
# Class name --> person
# Speed: 1.6ms preprocess, 128.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 121.3ms
# Confidence ---> 81
# Class name --> cell phone
# Confidence ---> 49
# Class name --> scissors
# Speed: 1.6ms preprocess, 121.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 112.6ms
# Confidence ---> 76
# Class name --> cell phone
# Confidence ---> 31
# Class name --> scissors
# Confidence ---> 27
# Class name --> person
# Speed: 1.5ms preprocess, 112.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 104.1ms
# Confidence ---> 80
# Class name --> cell phone
# Confidence ---> 43
# Class name --> scissors
# Speed: 1.7ms preprocess, 104.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 110.1ms
# Confidence ---> 84
# Class name --> cell phone
# Confidence ---> 28
# Class name --> scissors
# Confidence ---> 28
# Class name --> person
# Speed: 1.8ms preprocess, 110.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 112.2ms
# Confidence ---> 85
# Class name --> cell phone
# Confidence ---> 62
# Class name --> scissors
# Confidence ---> 32
# Class name --> person
# Speed: 2.8ms preprocess, 112.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 133.5ms
# Confidence ---> 83
# Class name --> cell phone
# Confidence ---> 36
# Class name --> scissors
# Speed: 3.3ms preprocess, 133.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 110.5ms
# Confidence ---> 81
# Class name --> cell phone
# Confidence ---> 40
# Class name --> scissors
# Speed: 1.6ms preprocess, 110.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 115.6ms
# Confidence ---> 83
# Class name --> cell phone
# Confidence ---> 35
# Class name --> scissors
# Speed: 1.6ms preprocess, 115.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 117.9ms
# Confidence ---> 82
# Class name --> cell phone
# Confidence ---> 38
# Class name --> scissors
# Confidence ---> 38
# Class name --> person
# Speed: 1.6ms preprocess, 117.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 119.2ms
# Confidence ---> 78
# Class name --> cell phone
# Confidence ---> 49
# Class name --> scissors
# Confidence ---> 42
# Class name --> person
# Speed: 1.9ms preprocess, 119.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 152.2ms
# Confidence ---> 83
# Class name --> cell phone
# Confidence ---> 45
# Class name --> scissors
# Speed: 2.0ms preprocess, 152.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 129.0ms
# Confidence ---> 80
# Class name --> cell phone
# Confidence ---> 41
# Class name --> scissors
# Speed: 3.0ms preprocess, 129.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 189.2ms
# Confidence ---> 80
# Class name --> cell phone
# Confidence ---> 35
# Class name --> scissors
# Confidence ---> 29
# Class name --> person
# Speed: 45.7ms preprocess, 189.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 120.4ms
# Confidence ---> 82
# Class name --> cell phone
# Confidence ---> 47
# Class name --> scissors
# Speed: 2.2ms preprocess, 120.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 121.5ms
# Confidence ---> 80
# Class name --> cell phone
# Confidence ---> 32
# Class name --> scissors
# Confidence ---> 26
# Class name --> person
# Speed: 1.8ms preprocess, 121.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 119.3ms
# Confidence ---> 83
# Class name --> cell phone
# Confidence ---> 40
# Class name --> scissors
# Confidence ---> 26
# Class name --> person
# Speed: 1.8ms preprocess, 119.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 123.1ms
# Confidence ---> 82
# Class name --> cell phone
# Confidence ---> 34
# Class name --> scissors
# Confidence ---> 31
# Class name --> person
# Speed: 3.4ms preprocess, 123.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 124.6ms
# Confidence ---> 76
# Class name --> cell phone
# Confidence ---> 51
# Class name --> scissors
# Confidence ---> 33
# Class name --> person
# Speed: 1.8ms preprocess, 124.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 124.2ms
# Confidence ---> 82
# Class name --> cell phone
# Confidence ---> 37
# Class name --> scissors
# Confidence ---> 27
# Class name --> person
# Speed: 3.0ms preprocess, 124.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 121.4ms
# Confidence ---> 81
# Class name --> cell phone
# Confidence ---> 35
# Class name --> scissors
# Confidence ---> 28
# Class name --> person
# Speed: 1.7ms preprocess, 121.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 118.0ms
# Confidence ---> 78
# Class name --> cell phone
# Confidence ---> 41
# Class name --> scissors
# Confidence ---> 31
# Class name --> person
# Speed: 2.1ms preprocess, 118.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 122.8ms
# Confidence ---> 77
# Class name --> cell phone
# Confidence ---> 49
# Class name --> scissors
# Speed: 1.7ms preprocess, 122.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 123.8ms
# Confidence ---> 76
# Class name --> cell phone
# Confidence ---> 37
# Class name --> scissors
# Speed: 1.7ms preprocess, 123.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 119.8ms
# Confidence ---> 84
# Class name --> cell phone
# Confidence ---> 48
# Class name --> scissors
# Confidence ---> 28
# Class name --> person
# Speed: 2.5ms preprocess, 119.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 119.3ms
# Confidence ---> 80
# Class name --> cell phone
# Confidence ---> 32
# Class name --> scissors
# Confidence ---> 30
# Class name --> person
# Speed: 1.6ms preprocess, 119.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 110.2ms
# Confidence ---> 83
# Class name --> cell phone
# Confidence ---> 38
# Class name --> scissors
# Confidence ---> 27
# Class name --> person
# Speed: 3.0ms preprocess, 110.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 109.2ms
# Confidence ---> 77
# Class name --> cell phone
# Confidence ---> 37
# Class name --> scissors
# Confidence ---> 30
# Class name --> person
# Speed: 1.8ms preprocess, 109.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 104.8ms
# Confidence ---> 83
# Class name --> cell phone
# Confidence ---> 30
# Class name --> scissors
# Speed: 2.6ms preprocess, 104.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 104.4ms
# Confidence ---> 83
# Class name --> cell phone
# Confidence ---> 32
# Class name --> scissors
# Confidence ---> 30
# Class name --> person
# Speed: 1.8ms preprocess, 104.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 110.4ms
# Confidence ---> 82
# Class name --> cell phone
# Confidence ---> 33
# Class name --> scissors
# Speed: 1.5ms preprocess, 110.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 102.5ms
# Confidence ---> 83
# Class name --> cell phone
# Confidence ---> 44
# Class name --> person
# Confidence ---> 36
# Class name --> scissors
# Speed: 1.7ms preprocess, 102.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 107.3ms
# Confidence ---> 80
# Class name --> cell phone
# Confidence ---> 46
# Class name --> scissors
# Confidence ---> 26
# Class name --> person
# Speed: 1.7ms preprocess, 107.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 103.0ms
# Confidence ---> 88
# Class name --> cell phone
# Confidence ---> 39
# Class name --> scissors
# Speed: 1.7ms preprocess, 103.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 101.1ms
# Confidence ---> 80
# Class name --> cell phone
# Confidence ---> 40
# Class name --> scissors
# Speed: 1.9ms preprocess, 101.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 101.7ms
# Confidence ---> 81
# Class name --> cell phone
# Confidence ---> 45
# Class name --> scissors
# Confidence ---> 28
# Class name --> person
# Speed: 1.5ms preprocess, 101.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 101.5ms
# Confidence ---> 71
# Class name --> cell phone
# Confidence ---> 53
# Class name --> scissors
# Confidence ---> 38
# Class name --> person
# Speed: 2.0ms preprocess, 101.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 102.1ms
# Confidence ---> 78
# Class name --> cell phone
# Confidence ---> 38
# Class name --> scissors
# Confidence ---> 34
# Class name --> person
# Speed: 1.8ms preprocess, 102.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 105.5ms
# Confidence ---> 80
# Class name --> cell phone
# Confidence ---> 44
# Class name --> scissors
# Confidence ---> 41
# Class name --> person
# Speed: 2.3ms preprocess, 105.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 101.1ms
# Confidence ---> 79
# Class name --> cell phone
# Confidence ---> 34
# Class name --> scissors
# Confidence ---> 27
# Class name --> person
# Speed: 1.9ms preprocess, 101.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 102.4ms
# Confidence ---> 78
# Class name --> cell phone
# Confidence ---> 34
# Class name --> scissors
# Confidence ---> 28
# Class name --> person
# Speed: 2.2ms preprocess, 102.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 104.1ms
# Confidence ---> 82
# Class name --> cell phone
# Confidence ---> 38
# Class name --> scissors
# Confidence ---> 32
# Class name --> person
# Speed: 2.2ms preprocess, 104.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 115.1ms
# Confidence ---> 82
# Class name --> cell phone
# Confidence ---> 36
# Class name --> scissors
# Speed: 2.0ms preprocess, 115.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 122.4ms
# Confidence ---> 87
# Class name --> cell phone
# Confidence ---> 26
# Class name --> scissors
# Speed: 2.4ms preprocess, 122.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 111.9ms
# Confidence ---> 81
# Class name --> cell phone
# Confidence ---> 49
# Class name --> scissors
# Speed: 2.2ms preprocess, 111.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 119.3ms
# Confidence ---> 85
# Class name --> cell phone
# Confidence ---> 44
# Class name --> scissors
# Speed: 2.5ms preprocess, 119.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 118.4ms
# Confidence ---> 81
# Class name --> cell phone
# Confidence ---> 37
# Class name --> scissors
# Confidence ---> 34
# Class name --> person
# Speed: 2.0ms preprocess, 118.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 111.7ms
# Confidence ---> 80
# Class name --> cell phone
# Confidence ---> 47
# Class name --> scissors
# Speed: 3.1ms preprocess, 111.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 111.6ms
# Confidence ---> 84
# Class name --> cell phone
# Confidence ---> 34
# Class name --> scissors
# Confidence ---> 31
# Class name --> person
# Speed: 2.1ms preprocess, 111.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 122.3ms
# Confidence ---> 82
# Class name --> cell phone
# Confidence ---> 40
# Class name --> scissors
# Confidence ---> 31
# Class name --> person
# Speed: 1.7ms preprocess, 122.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 117.0ms
# Confidence ---> 82
# Class name --> cell phone
# Confidence ---> 42
# Class name --> scissors
# Confidence ---> 27
# Class name --> person
# Speed: 1.6ms preprocess, 117.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 170.4ms
# Confidence ---> 83
# Class name --> cell phone
# Confidence ---> 52
# Class name --> scissors
# Speed: 5.0ms preprocess, 170.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 114.2ms
# Confidence ---> 78
# Class name --> cell phone
# Confidence ---> 42
# Class name --> scissors
# Confidence ---> 34
# Class name --> person
# Speed: 2.8ms preprocess, 114.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 115.3ms
# Confidence ---> 76
# Class name --> cell phone
# Confidence ---> 37
# Class name --> scissors
# Speed: 2.8ms preprocess, 115.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 102.5ms
# Confidence ---> 83
# Class name --> cell phone
# Confidence ---> 45
# Class name --> scissors
# Confidence ---> 26
# Class name --> person
# Speed: 2.4ms preprocess, 102.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 100.9ms
# Confidence ---> 83
# Class name --> cell phone
# Confidence ---> 44
# Class name --> scissors
# Speed: 1.6ms preprocess, 100.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 100.0ms
# Confidence ---> 79
# Class name --> cell phone
# Confidence ---> 29
# Class name --> person
# Confidence ---> 29
# Class name --> scissors
# Speed: 1.5ms preprocess, 100.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 102.9ms
# Confidence ---> 83
# Class name --> cell phone
# Confidence ---> 44
# Class name --> scissors
# Confidence ---> 31
# Class name --> person
# Speed: 2.2ms preprocess, 102.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 scissors, 105.0ms
# Confidence ---> 84
# Class name --> cell phone
# Confidence ---> 39
# Class name --> scissors
# Speed: 1.6ms preprocess, 105.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 scissors, 111.2ms
# Confidence ---> 81
# Class name --> cell phone
# Confidence ---> 54
# Class name --> scissors
# Confidence ---> 38
# Class name --> person
# Speed: 1.6ms preprocess, 111.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 dining table, 1 cell phone, 1 scissors, 103.3ms
# Confidence ---> 85
# Class name --> cell phone
# Confidence ---> 47
# Class name --> scissors
# Confidence ---> 28
# Class name --> person
# Confidence ---> 26
# Class name --> diningtable
# Speed: 1.5ms preprocess, 103.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 1 scissors, 103.1ms
# Confidence ---> 77
# Class name --> cell phone
# Confidence ---> 57
# Class name --> scissors
# Confidence ---> 38
# Class name --> person
# Confidence ---> 29
# Class name --> person
# Speed: 1.5ms preprocess, 103.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 scissors, 135.4ms
# Confidence ---> 42
# Class name --> scissors
# Speed: 2.0ms preprocess, 135.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 105.4ms
# Confidence ---> 47
# Class name --> scissors
# Confidence ---> 33
# Class name --> person
# Speed: 1.7ms preprocess, 105.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 109.0ms
# Confidence ---> 51
# Class name --> scissors
# Confidence ---> 41
# Class name --> person
# Speed: 2.0ms preprocess, 109.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 scissors, 109.1ms
# Confidence ---> 78
# Class name --> scissors
# Speed: 2.3ms preprocess, 109.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 scissors, 111.1ms
# Confidence ---> 56
# Class name --> scissors
# Confidence ---> 33
# Class name --> person
# Confidence ---> 28
# Class name --> person
# Speed: 1.8ms preprocess, 111.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 105.9ms
# Confidence ---> 44
# Class name --> scissors
# Confidence ---> 26
# Class name --> person
# Speed: 1.6ms preprocess, 105.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 108.3ms
# Confidence ---> 48
# Class name --> scissors
# Confidence ---> 45
# Class name --> person
# Speed: 2.0ms preprocess, 108.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 104.9ms
# Confidence ---> 50
# Class name --> scissors
# Confidence ---> 38
# Class name --> person
# Speed: 1.7ms preprocess, 104.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 109.7ms
# Confidence ---> 42
# Class name --> person
# Confidence ---> 41
# Class name --> scissors
# Speed: 1.3ms preprocess, 109.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 108.3ms
# Confidence ---> 49
# Class name --> scissors
# Confidence ---> 36
# Class name --> person
# Speed: 2.5ms preprocess, 108.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 105.0ms
# Confidence ---> 58
# Class name --> scissors
# Confidence ---> 28
# Class name --> person
# Speed: 2.2ms preprocess, 105.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 104.4ms
# Confidence ---> 46
# Class name --> person
# Confidence ---> 39
# Class name --> scissors
# Speed: 1.5ms preprocess, 104.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 108.6ms
# Confidence ---> 51
# Class name --> scissors
# Confidence ---> 37
# Class name --> person
# Speed: 1.8ms preprocess, 108.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 103.8ms
# Confidence ---> 45
# Class name --> scissors
# Confidence ---> 30
# Class name --> person
# Speed: 1.7ms preprocess, 103.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 106.0ms
# Confidence ---> 39
# Class name --> scissors
# Confidence ---> 31
# Class name --> person
# Speed: 1.4ms preprocess, 106.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 101.4ms
# Confidence ---> 42
# Class name --> person
# Confidence ---> 40
# Class name --> scissors
# Speed: 1.8ms preprocess, 101.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 105.1ms
# Confidence ---> 47
# Class name --> scissors
# Confidence ---> 28
# Class name --> person
# Speed: 2.0ms preprocess, 105.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 107.4ms
# Confidence ---> 45
# Class name --> scissors
# Confidence ---> 41
# Class name --> person
# Speed: 1.9ms preprocess, 107.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 100.9ms
# Confidence ---> 49
# Class name --> scissors
# Confidence ---> 34
# Class name --> person
# Speed: 2.3ms preprocess, 100.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 104.1ms
# Confidence ---> 46
# Class name --> scissors
# Confidence ---> 35
# Class name --> person
# Speed: 2.0ms preprocess, 104.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 107.7ms
# Confidence ---> 50
# Class name --> scissors
# Confidence ---> 33
# Class name --> person
# Speed: 1.6ms preprocess, 107.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 133.3ms
# Confidence ---> 60
# Class name --> scissors
# Confidence ---> 53
# Class name --> person
# Speed: 1.6ms preprocess, 133.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 scissors, 109.3ms
# Confidence ---> 36
# Class name --> person
# Confidence ---> 34
# Class name --> person
# Confidence ---> 29
# Class name --> scissors
# Speed: 1.5ms preprocess, 109.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 scissors, 109.6ms
# Confidence ---> 55
# Class name --> scissors
# Confidence ---> 33
# Class name --> person
# Confidence ---> 31
# Class name --> person
# Speed: 1.5ms preprocess, 109.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 1 scissors, 105.1ms
# Confidence ---> 50
# Class name --> scissors
# Confidence ---> 31
# Class name --> remote
# Confidence ---> 27
# Class name --> person
# Speed: 1.7ms preprocess, 105.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 scissors, 105.6ms
# Confidence ---> 48
# Class name --> scissors
# Speed: 1.7ms preprocess, 105.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 scissors, 166.9ms
# Confidence ---> 68
# Class name --> scissors
# Speed: 1.6ms preprocess, 166.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 scissors, 110.9ms
# Confidence ---> 64
# Class name --> scissors
# Confidence ---> 38
# Class name --> person
# Confidence ---> 33
# Class name --> person
# Speed: 1.5ms preprocess, 110.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cups, 1 scissors, 105.9ms
# Confidence ---> 84
# Class name --> cup
# Confidence ---> 63
# Class name --> scissors
# Confidence ---> 49
# Class name --> cup
# Speed: 1.8ms preprocess, 105.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 1 scissors, 109.5ms
# Confidence ---> 89
# Class name --> cup
# Confidence ---> 53
# Class name --> scissors
# Confidence ---> 36
# Class name --> person
# Speed: 1.7ms preprocess, 109.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 remote, 1 scissors, 107.9ms
# Confidence ---> 98
# Class name --> cup
# Confidence ---> 64
# Class name --> scissors
# Confidence ---> 27
# Class name --> remote
# Speed: 2.1ms preprocess, 107.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 scissors, 106.2ms
# Confidence ---> 97
# Class name --> cup
# Confidence ---> 44
# Class name --> scissors
# Speed: 1.5ms preprocess, 106.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 scissors, 105.0ms
# Confidence ---> 97
# Class name --> cup
# Confidence ---> 26
# Class name --> scissors
# Speed: 2.2ms preprocess, 105.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 247.2ms
# Confidence ---> 97
# Class name --> cup
# Speed: 2.2ms preprocess, 247.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 scissors, 102.6ms
# Confidence ---> 97
# Class name --> cup
# Confidence ---> 27
# Class name --> scissors
# Speed: 1.6ms preprocess, 102.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 scissors, 105.4ms
# Confidence ---> 97
# Class name --> cup
# Confidence ---> 28
# Class name --> scissors
# Speed: 1.8ms preprocess, 105.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 scissors, 104.6ms
# Confidence ---> 96
# Class name --> cup
# Confidence ---> 32
# Class name --> scissors
# Speed: 2.4ms preprocess, 104.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 1 scissors, 107.9ms
# Confidence ---> 96
# Class name --> cup
# Confidence ---> 30
# Class name --> scissors
# Confidence ---> 27
# Class name --> person
# Speed: 1.8ms preprocess, 107.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 106.4ms
# Confidence ---> 96
# Class name --> cup
# Speed: 1.7ms preprocess, 106.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 scissors, 107.4ms
# Confidence ---> 95
# Class name --> cup
# Confidence ---> 27
# Class name --> scissors
# Speed: 1.7ms preprocess, 107.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 scissors, 104.0ms
# Confidence ---> 96
# Class name --> cup
# Confidence ---> 26
# Class name --> scissors
# Speed: 2.2ms preprocess, 104.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 scissors, 108.1ms
# Confidence ---> 96
# Class name --> cup
# Confidence ---> 31
# Class name --> scissors
# Speed: 2.3ms preprocess, 108.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 scissors, 104.6ms
# Confidence ---> 95
# Class name --> cup
# Confidence ---> 31
# Class name --> scissors
# Speed: 1.7ms preprocess, 104.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 102.8ms
# Confidence ---> 96
# Class name --> cup
# Speed: 1.7ms preprocess, 102.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 107.7ms
# Confidence ---> 96
# Class name --> cup
# Speed: 1.6ms preprocess, 107.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 scissors, 107.8ms
# Confidence ---> 96
# Class name --> cup
# Confidence ---> 26
# Class name --> scissors
# Speed: 1.9ms preprocess, 107.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 scissors, 104.2ms
# Confidence ---> 96
# Class name --> cup
# Confidence ---> 29
# Class name --> scissors
# Speed: 2.5ms preprocess, 104.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 scissors, 111.9ms
# Confidence ---> 96
# Class name --> cup
# Confidence ---> 31
# Class name --> scissors
# Speed: 1.7ms preprocess, 111.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 108.3ms
# Confidence ---> 96
# Class name --> cup
# Speed: 1.8ms preprocess, 108.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 101.2ms
# Confidence ---> 97
# Class name --> cup
# Speed: 1.9ms preprocess, 101.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# ...
# Class name --> person
# Speed: 3.0ms preprocess, 123.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 123.3ms
# Confidence ---> 57
# Class name --> scissors
# Confidence ---> 49
# Class name --> scissors
# Confidence ---> 38
# Class name --> person
# Speed: 2.1ms preprocess, 123.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 119.8ms
# Confidence ---> 51
# Class name --> scissors
# Confidence ---> 44
# Class name --> scissors
# Confidence ---> 33
# Class name --> person
# Speed: 2.0ms preprocess, 119.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 116.7ms
# Confidence ---> 51
# Class name --> scissors
# Confidence ---> 44
# Class name --> scissors
# Confidence ---> 36
# Class name --> person
# Speed: 1.8ms preprocess, 116.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 133.2ms
# Confidence ---> 51
# Class name --> scissors
# Confidence ---> 42
# Class name --> scissors
# Confidence ---> 35
# Class name --> person
# Speed: 2.0ms preprocess, 133.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 125.1ms
# Confidence ---> 54
# Class name --> scissors
# Confidence ---> 53
# Class name --> scissors
# Confidence ---> 29
# Class name --> person
# Speed: 1.6ms preprocess, 125.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 125.3ms
# Confidence ---> 58
# Class name --> scissors
# Confidence ---> 41
# Class name --> scissors
# Confidence ---> 39
# Class name --> person
# Speed: 2.8ms preprocess, 125.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 121.9ms
# Confidence ---> 57
# Class name --> scissors
# Confidence ---> 49
# Class name --> scissors
# Confidence ---> 41
# Class name --> person
# Speed: 2.2ms preprocess, 121.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 124.0ms
# Confidence ---> 57
# Class name --> scissors
# Confidence ---> 50
# Class name --> scissors
# Confidence ---> 38
# Class name --> person
# Speed: 1.9ms preprocess, 124.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 125.7ms
# Confidence ---> 55
# Class name --> scissors
# Confidence ---> 47
# Class name --> scissors
# Confidence ---> 45
# Class name --> person
# Speed: 2.3ms preprocess, 125.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 135.6ms
# Confidence ---> 55
# Class name --> scissors
# Confidence ---> 44
# Class name --> scissors
# Confidence ---> 36
# Class name --> person
# Speed: 1.8ms preprocess, 135.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 148.1ms
# Confidence ---> 56
# Class name --> scissors
# Confidence ---> 44
# Class name --> scissors
# Confidence ---> 34
# Class name --> person
# Speed: 2.0ms preprocess, 148.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 127.8ms
# Confidence ---> 57
# Class name --> scissors
# Confidence ---> 52
# Class name --> scissors
# Confidence ---> 39
# Class name --> person
# Speed: 4.1ms preprocess, 127.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 134.0ms
# Confidence ---> 60
# Class name --> scissors
# Confidence ---> 51
# Class name --> scissors
# Confidence ---> 39
# Class name --> person
# Speed: 2.4ms preprocess, 134.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 131.2ms
# Confidence ---> 57
# Class name --> scissors
# Confidence ---> 47
# Class name --> scissors
# Confidence ---> 35
# Class name --> person
# Speed: 2.1ms preprocess, 131.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 129.9ms
# Confidence ---> 57
# Class name --> scissors
# Confidence ---> 53
# Class name --> scissors
# Confidence ---> 33
# Class name --> person
# Speed: 3.6ms preprocess, 129.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 125.3ms
# Confidence ---> 53
# Class name --> scissors
# Confidence ---> 50
# Class name --> scissors
# Confidence ---> 35
# Class name --> person
# Speed: 1.8ms preprocess, 125.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 133.7ms
# Confidence ---> 59
# Class name --> scissors
# Confidence ---> 55
# Class name --> scissors
# Confidence ---> 34
# Class name --> person
# Speed: 2.5ms preprocess, 133.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 169.0ms
# Confidence ---> 54
# Class name --> scissors
# Confidence ---> 42
# Class name --> scissors
# Confidence ---> 33
# Class name --> person
# Speed: 28.6ms preprocess, 169.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 144.8ms
# Confidence ---> 60
# Class name --> scissors
# Confidence ---> 53
# Class name --> scissors
# Confidence ---> 35
# Class name --> person
# Speed: 1.9ms preprocess, 144.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 127.8ms
# Confidence ---> 56
# Class name --> scissors
# Confidence ---> 53
# Class name --> scissors
# Confidence ---> 40
# Class name --> person
# Speed: 1.8ms preprocess, 127.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 136.5ms
# Confidence ---> 65
# Class name --> scissors
# Confidence ---> 58
# Class name --> scissors
# Confidence ---> 41
# Class name --> person
# Speed: 2.1ms preprocess, 136.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 142.4ms
# Confidence ---> 52
# Class name --> scissors
# Confidence ---> 49
# Class name --> scissors
# Confidence ---> 36
# Class name --> person
# Speed: 2.5ms preprocess, 142.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 134.6ms
# Confidence ---> 58
# Class name --> scissors
# Confidence ---> 45
# Class name --> scissors
# Confidence ---> 38
# Class name --> person
# Speed: 2.0ms preprocess, 134.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 127.2ms
# Confidence ---> 57
# Class name --> scissors
# Confidence ---> 45
# Class name --> scissors
# Confidence ---> 34
# Class name --> person
# Speed: 1.7ms preprocess, 127.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 125.7ms
# Confidence ---> 47
# Class name --> scissors
# Confidence ---> 42
# Class name --> scissors
# Confidence ---> 35
# Class name --> person
# Speed: 1.7ms preprocess, 125.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 128.1ms
# Confidence ---> 58
# Class name --> scissors
# Confidence ---> 55
# Class name --> scissors
# Confidence ---> 38
# Class name --> person
# Speed: 2.7ms preprocess, 128.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 159.1ms
# Confidence ---> 52
# Class name --> scissors
# Confidence ---> 46
# Class name --> scissors
# Confidence ---> 26
# Class name --> person
# Speed: 1.9ms preprocess, 159.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 143.4ms
# Confidence ---> 48
# Class name --> scissors
# Confidence ---> 41
# Class name --> scissors
# Confidence ---> 28
# Class name --> person
# Speed: 2.1ms preprocess, 143.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 172.6ms
# Confidence ---> 59
# Class name --> scissors
# Confidence ---> 59
# Class name --> scissors
# Confidence ---> 39
# Class name --> person
# Speed: 8.4ms preprocess, 172.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 139.9ms
# Confidence ---> 57
# Class name --> scissors
# Confidence ---> 50
# Class name --> scissors
# Confidence ---> 28
# Class name --> person
# Speed: 2.1ms preprocess, 139.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 141.9ms
# Confidence ---> 57
# Class name --> scissors
# Confidence ---> 52
# Class name --> scissors
# Confidence ---> 42
# Class name --> person
# Speed: 2.1ms preprocess, 141.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 134.2ms
# Confidence ---> 61
# Class name --> scissors
# Confidence ---> 57
# Class name --> scissors
# Confidence ---> 40
# Class name --> person
# Speed: 2.0ms preprocess, 134.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 144.5ms
# Confidence ---> 55
# Class name --> scissors
# Confidence ---> 54
# Class name --> scissors
# Confidence ---> 37
# Class name --> person
# Speed: 2.4ms preprocess, 144.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 137.5ms
# Confidence ---> 55
# Class name --> scissors
# Confidence ---> 50
# Class name --> scissors
# Confidence ---> 35
# Class name --> person
# Speed: 2.6ms preprocess, 137.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 180.5ms
# Confidence ---> 51
# Class name --> scissors
# Confidence ---> 48
# Class name --> scissors
# Confidence ---> 33
# Class name --> person
# Speed: 1.9ms preprocess, 180.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 203.6ms
# Confidence ---> 50
# Class name --> scissors
# Confidence ---> 44
# Class name --> scissors
# Confidence ---> 33
# Class name --> person
# Speed: 3.0ms preprocess, 203.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 168.6ms
# Confidence ---> 44
# Class name --> scissors
# Confidence ---> 38
# Class name --> scissors
# Confidence ---> 37
# Class name --> person
# Speed: 2.0ms preprocess, 168.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 306.5ms
# Confidence ---> 45
# Class name --> scissors
# Confidence ---> 36
# Class name --> scissors
# Confidence ---> 29
# Class name --> person
# Speed: 2.2ms preprocess, 306.5ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 697.7ms
# Confidence ---> 56
# Class name --> scissors
# Confidence ---> 48
# Class name --> scissors
# Confidence ---> 39
# Class name --> person
# Speed: 2.4ms preprocess, 697.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 341.0ms
# Confidence ---> 54
# Class name --> scissors
# Confidence ---> 37
# Class name --> person
# Confidence ---> 35
# Class name --> scissors
# Speed: 4.9ms preprocess, 341.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 272.0ms
# Confidence ---> 55
# Class name --> scissors
# Confidence ---> 51
# Class name --> scissors
# Confidence ---> 41
# Class name --> person
# Speed: 4.2ms preprocess, 272.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 558.4ms
# Confidence ---> 49
# Class name --> scissors
# Confidence ---> 48
# Class name --> scissors
# Confidence ---> 36
# Class name --> person
# Speed: 4.0ms preprocess, 558.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 793.7ms
# Confidence ---> 56
# Class name --> scissors
# Confidence ---> 48
# Class name --> scissors
# Confidence ---> 36
# Class name --> person
# Speed: 30.4ms preprocess, 793.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 315.8ms
# Confidence ---> 53
# Class name --> scissors
# Confidence ---> 37
# Class name --> scissors
# Confidence ---> 34
# Class name --> person
# Speed: 7.8ms preprocess, 315.8ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 318.8ms
# Confidence ---> 54
# Class name --> scissors
# Confidence ---> 51
# Class name --> scissors
# Confidence ---> 38
# Class name --> person
# Speed: 3.3ms preprocess, 318.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 154.9ms
# Confidence ---> 61
# Class name --> scissors
# Confidence ---> 59
# Class name --> scissors
# Confidence ---> 40
# Class name --> person
# Speed: 3.2ms preprocess, 154.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 133.6ms
# Confidence ---> 57
# Class name --> scissors
# Confidence ---> 49
# Class name --> scissors
# Confidence ---> 34
# Class name --> person
# Speed: 2.8ms preprocess, 133.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 284.1ms
# Confidence ---> 57
# Class name --> scissors
# Confidence ---> 43
# Class name --> scissors
# Confidence ---> 36
# Class name --> person
# Speed: 6.5ms preprocess, 284.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 138.5ms
# Confidence ---> 59
# Class name --> scissors
# Confidence ---> 56
# Class name --> scissors
# Confidence ---> 35
# Class name --> person
# Speed: 2.1ms preprocess, 138.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 scissorss, 144.2ms
# Confidence ---> 52
# Class name --> scissors
# Confidence ---> 47
# Class name --> scissors
# Speed: 2.0ms preprocess, 144.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 144.9ms
# Confidence ---> 48
# Class name --> scissors
# Confidence ---> 42
# Class name --> scissors
# Confidence ---> 37
# Class name --> person
# Speed: 2.4ms preprocess, 144.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 194.3ms
# Confidence ---> 59
# Class name --> scissors
# Confidence ---> 53
# Class name --> scissors
# Confidence ---> 39
# Class name --> person
# Speed: 2.3ms preprocess, 194.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 264.5ms
# Confidence ---> 55
# Class name --> scissors
# Confidence ---> 49
# Class name --> scissors
# Confidence ---> 37
# Class name --> person
# Speed: 3.5ms preprocess, 264.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 160.2ms
# Confidence ---> 57
# Class name --> scissors
# Confidence ---> 45
# Class name --> scissors
# Confidence ---> 35
# Class name --> person
# Speed: 2.5ms preprocess, 160.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 147.5ms
# Confidence ---> 60
# Class name --> scissors
# Confidence ---> 57
# Class name --> scissors
# Confidence ---> 32
# Class name --> person
# Speed: 2.2ms preprocess, 147.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 147.1ms
# Confidence ---> 57
# Class name --> scissors
# Confidence ---> 56
# Class name --> scissors
# Confidence ---> 41
# Class name --> person
# Speed: 2.2ms preprocess, 147.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 scissorss, 258.8ms
# Confidence ---> 50
# Class name --> scissors
# Confidence ---> 45
# Class name --> scissors
# Confidence ---> 37
# Class name --> person
# Speed: 2.0ms preprocess, 258.8ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 scissorss, 288.0ms
# Confidence ---> 60
# Class name --> scissors
# Confidence ---> 52
# Class name --> scissors
# Confidence ---> 40
# Class name --> person
# Confidence ---> 28
# Class name --> person
# Speed: 5.5ms preprocess, 288.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### **Actividad 9.2: Aplicación de detección de objetos específicos con YOLO**
#
# Objetivo: Modificar el script de detección de objetos en tiempo real con YOLO para que solo detecte ciertas clases de objetos. Luego, darle una aplicación específica a esta detección.
#
# Instrucciones:
#
# 1. Elija un subconjunto de las 80 clases disponibles en YOLO que sean relevantes para una aplicación específica. Por ejemplo, si está creando una aplicación para ayudar a los conductores a detectar peatones y vehículos, podría elegir las clases 'persona', 'bicicleta', 'coche', 'moto', 'autobús' y 'camión'.
#
# 2. Modifique el script de detección de objetos en tiempo real para que solo detecte las clases que ha seleccionado. Para hacer esto, necesitará crear una lista de los índices de las clases que ha selecciono y luego agregar una condición en el bucle donde se procesan los resultados de la detección para solo procesar las detecciones que corresponden a las clases seleccionadas.
#
# 3. Pruebe su script modificado para asegurarse de que solo está detectando las clases que ha seleccionado.
#
# 4. Piense en una aplicación específica para su detección de objetos. ¿Cómo podría usar la información de las detecciones para ayudar al usuario? Por ejemplo, en la aplicación para conductores, podría alertar al usuario si detecta un peatón o un vehículo en una zona de peligro.

# %% [markdown]
# *Escriba su respuesta aquí..*

# %% [markdown]
# 5. En clase, presente las clases que seleccionó, cómo modificó el script de detección de objetos, los resultados de sus pruebas (video grabado o en tiempo real), la aplicación específica que ha ideado para su detección de objetos, y cómo la aplicación serviría al usuario final u organización.
#
# Genere un PDF y súbalo a la actividad designada en Moodle.
#
# **Tiempo estimado para la actividad:** 20min.
