# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Autor:
# Manuel Eugenio Morocho Cayamcela, PhD

# %% [markdown]
# # **Lectura 1.2:**
# ## Análisis exploratorio de datos de vinos Piedmont

# %% [markdown]
# ### **Introducción:**

# %% [markdown]
# En esta lectura, realizaremos un análisis exploratorio de datos del conjunto de datos de vinos. Este conjunto de datos contiene características químicas de muestras de vinos, clasificadas en tres clases diferentes. Utilizaremos herramientas de visualización y análisis estadístico para comprender mejor la estructura y las relaciones en los datos.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# El conjunto de datos de vino (wine dataset) es un conjunto de datos clásico en el campo del data mining. Contiene 178 muestras de vino cultivadas en la [región Piedmont](https://en.wikipedia.org/wiki/Piedmont) de Italia pero derivadas de tres cultivares diferentes (Barolo, Grignolio and Barbera). Cada muestra de vino tiene 13 características químicas medidas, que son las variables del conjunto de datos. Aquí están las variables:
#
# 1. **Alcohol**: la cantidad de alcohol en el vino.
# 2. **Malic acid**: un ácido orgánico que se encuentra en los vinos.
# 3. **Ash**: una medida de la cantidad total de minerales presentes en el vino.
# 4. **Alcalinity of ash**: una medida de la alcalinidad de los minerales presentes en el vino.
# 5. **Magnesium**: la cantidad de magnesio en el vino.
# 6. **Total phenols**: una medida de los compuestos fenólicos presentes en el vino.
# 7. **Flavanoids**: una clase de fenoles que se encuentran en los vinos.
# 8. **Nonflavanoid phenols**: una medida de los fenoles no flavonoides presentes en el vino.
# 9. **Proanthocyanins**: una clase de fenoles que se encuentran en los vinos.
# 10. **Color intensity**: una medida de la intensidad del color del vino.
# 11. **Hue**: una medida del color del vino.
# 12. **OD280/OD315 of diluted wines**: una medida de la densidad óptica del vino.
# 13. **Proline**: una medida de la cantidad de prolina en el vino, un aminoácido que puede influir en el sabor del vino.
#
# Cada una de estas variables puede influir en la calidad y el sabor del vino, y pueden ser útiles para predecir el cultivar del vino.
#
# Fuente: https://archive.ics.uci.edu/ml/datasets/Wine

# %% [markdown]
# ### **Contenido:**

# %% [markdown]
# Este código carga un archivo Excel llamado 'wine.xlsx' en un DataFrame de pandas y luego imprime las primeras 5 filas del DataFrame.
#
# Instalamos el paquete `openpyxl` que es necesario para leer archivos en Excel con pandas.
#
# Pandas es una biblioteca de Python que proporciona estructuras de datos y herramientas de análisis de datos. `pd.read_excel()` es una función que lee un archivo de Excel y lo convierte en un DataFrame de pandas.
#
# Un DataFrame es una estructura de datos bidimensional, similar a una hoja de cálculo de Excel. Cada fila representa una observación (o instancia) y cada columna representa una variable (o característica).
#
# `print(wine_df.head())` imprime las primeras 5 filas del DataFrame. Esto es útil para obtener una visión rápida de los datos después de cargarlos.

# %%
# !pip install openpyxl
import pandas as pd

# Cargamos el archivo Excel
wine_df = pd.read_excel('/Users/eugenio/Library/CloudStorage/OneDrive-Personal/UIDE/2024 Maestría Ciencia de Datos y Máquinas de Aprendizaje mención IA/Contenidos/Notebooks_DataMining/Bases de Datos/wine.xlsx')

# %% [markdown]
# #### Exploración inicial de datos

# %% [markdown]
# El código `wine_df.head()` muestra las primeras 5 filas del DataFrame `wine_df`. Es útil para obtener una vista rápida de los datos con los que estás trabajando, incluyendo los nombres de las columnas y los primeros valores de cada columna.
#
# Si quisieras ver un número diferente de filas, puedes pasar ese número como argumento a la función `head()`. Por ejemplo, `wine_df.head(10)` mostraría las primeras 10 filas del DataFrame.

# %%
# Mostramos las primeras 5 filas
wine_df.head()
# Out:
#    Class  Alcohol  Malic.acid   Ash  Alcalinity.ash    Magnesium  \
# 0      1    14.23        1.71  2.43              15.6        127
# 1      1    13.20        1.78  2.14              11.2        100
# 2      1    13.16        2.36  2.67              18.6        101
# 3      1    14.37        1.95  2.50              16.8        113
# 4      1    13.24        2.59  2.87              21.0        118
#
#    Total.phenols  Flavanoids  Nonflavanoid.phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color.intensity   Hue  OD280.OD315  Proline
# 0             5.64  1.04         3.92            1065
# 1             4.38  1.05         3.40            1050
# ...

# %% [markdown]
# El método `info()` proporciona un resumen conciso del DataFrame `wine_df`. Este método imprime información sobre el DataFrame incluyendo el índice dtype y las columnas, los valores no nulos y la memoria utilizada.
#
# La salida incluirá lo siguiente:
#
# - El número total de entradas en el DataFrame (por ejemplo, "RangeIndex: 178 entries, 0 to 177").
# - Información sobre cada columna, incluyendo el nombre de la columna, el número de valores no nulos en la columna y el tipo de datos de la columna (por ejemplo, "Alcohol    178 non-null float64").
# - El número total de columnas de cada tipo de datos (por ejemplo, "float64(2), int64(1), object(1)").
# - Una estimación de la cantidad de memoria utilizada por el DataFrame.
#
# Este método es útil para obtener una visión general rápida de los datos, especialmente para entender los tipos de datos de las columnas y si hay valores nulos en las columnas.

# %%
# Mostramos la información del DataFrame
wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Class                 178 non-null    int64
#  1   Alcohol               178 non-null    float64
#  2   Malic.acid            178 non-null    float64
#  3   Ash                   178 non-null    float64
#  4   Alcalinity.ash        178 non-null    float64
#  5   Magnesium             178 non-null    int64
#  6   Total.phenols         178 non-null    float64
#  7   Flavanoids            178 non-null    float64
#  8   Nonflavanoid.phenols  178 non-null    float64
#  9   Proanthocyanins       178 non-null    float64
#  10  Color.intensity       178 non-null    float64
#  11  Hue                   178 non-null    float64
#  12  OD280.OD315           178 non-null    float64
#  13  Proline               178 non-null    int64
# dtypes: float64(11), int64(3)
# ...

# %% [markdown]
# El método `describe()` genera estadísticas descriptivas del DataFrame `wine_df`. Estas estadísticas incluyen el conteo, la media, la desviación estándar, el valor mínimo, los percentiles 25, 50 y 75, y el valor máximo.
#
# Estas estadísticas pueden ayudarte a entender la distribución de los datos en cada columna. Por ejemplo, la media te da una idea del valor "típico" en cada columna, mientras que la desviación estándar te da una idea de cuánto varían los valores en cada columna.
#
# Los percentiles te pueden dar una idea de la distribución de los datos. Por ejemplo, el percentil 50 es la **mediana**, que es el valor que **divide los datos en dos mitades iguales**. Los percentiles 25 y 75 te dan una idea de la **mitad inferior** y la **mitad superior** de los datos, respectivamente.
#
# Finalmente, los valores mínimo y máximo te dan una idea del rango de valores en cada columna.

# %%
# Mostramos la descripción del DataFrame
wine_df.describe()
# Out:
#             Class     Alcohol  Malic.acid         Ash  Alcalinity.ash    \
# count  178.000000  178.000000  178.000000  178.000000        178.000000
# mean     1.938202   13.000618    2.336348    2.366517         19.494944
# std      0.775035    0.811827    1.117146    0.274344          3.339564
# min      1.000000   11.030000    0.740000    1.360000         10.600000
# 25%      1.000000   12.362500    1.602500    2.210000         17.200000
# 50%      2.000000   13.050000    1.865000    2.360000         19.500000
# 75%      3.000000   13.677500    3.082500    2.557500         21.500000
# max      3.000000   14.830000    5.800000    3.230000         30.000000
#
#         Magnesium  Total.phenols  Flavanoids  Nonflavanoid.phenols  \
# count  178.000000     178.000000  178.000000            178.000000
# mean    99.741573       2.295112    2.029270              0.361854
# std     14.282484       0.625851    0.998859              0.124453
# ...

# %% [markdown]
# #### Distribución de clases

# %% [markdown]
# Este código genera un gráfico de barras que muestra la distribución de clases en el DataFrame `wine_df`.
#
# La función `sns.countplot()` de la biblioteca seaborn se utiliza para crear el gráfico de barras. El argumento `x='Class'` especifica que las barras del gráfico deben representar las diferentes clases en la columna 'Class' del DataFrame. El argumento `data=wine_df` especifica que los datos para el gráfico provienen del DataFrame `wine_df`. El argumento `palette='Set2'` especifica que se debe usar la paleta de colores 'Set2' para las barras del gráfico.
#
# Las funciones `plt.title()`, `plt.xlabel()`, y `plt.ylabel()` se utilizan para establecer el título del gráfico y las etiquetas de los ejes x e y, respectivamente.
#
# Finalmente, `plt.show()` se utiliza para mostrar el gráfico.

# %%
# Visualizar la distribución de clases
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración de la visualización
sns.countplot(x='Class', data=wine_df, palette='Set2')

# Configuramos el título y los ejes
plt.title('Distribución de Clases')
plt.xlabel('Clase')
plt.ylabel('Cantidad')
plt.show()
# Out:
# /var/folders/8j/f0xtldm91_1c2bpdr69fxgzw0000gn/T/ipykernel_50856/2143344041.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Class', data=wine_df, palette='Set2')

# %% [markdown]
# #### Matriz de correlación entre características

# %% [markdown]
# La matriz de correlación te permite ver las correlaciones entre las diferentes características en el conjunto de datos `wine_df`. Los valores en la matriz de correlación varían de -1 a 1, donde:
#
# - Un valor cercano a 1 indica una fuerte correlación positiva: si una característica aumenta, la otra también tiende a aumentar.
# - Un valor cercano a -1 indica una fuerte correlación negativa: si una característica aumenta, la otra tiende a disminuir.
# - Un valor cercano a 0 indica que no hay una correlación lineal entre las dos características.

# %% [markdown]
# Primero, se calcula la matriz de correlación utilizando el método `corr()` del DataFrame. Esta matriz de correlación es un DataFrame donde el valor en la i-ésima fila y la j-ésima columna es la correlación entre la i-ésima y la j-ésima columna del DataFrame original.
#
# Luego, se crea una figura con un tamaño específico utilizando `plt.figure(figsize=(10, 8))`.
#
# Después, se utiliza la función `sns.heatmap()` de la biblioteca seaborn para visualizar la matriz de correlación. Los argumentos `annot=True` y `cmap='coolwarm'` especifican que los valores de correlación deben ser anotados en el heatmap y que se debe usar el mapa de colores 'coolwarm', respectivamente.
#
# Finalmente, se establece el título del gráfico con `plt.title('Matriz de Correlación')` y se muestra el gráfico con `plt.show()`.

# %%
# Calcular matriz de correlación
correlation_matrix = wine_df.corr()
print(correlation_matrix)
# Out:
#                          Class   Alcohol  Malic.acid       Ash  \
# Class                 1.000000 -0.328222    0.437776 -0.049643
# Alcohol              -0.328222  1.000000    0.094397  0.211545
# Malic.acid            0.437776  0.094397    1.000000  0.164045
# Ash                  -0.049643  0.211545    0.164045  1.000000
# Alcalinity.ash        0.517859 -0.310235    0.288500  0.443367
# Magnesium            -0.209179  0.270798   -0.054575  0.286587
# Total.phenols        -0.719163  0.289101   -0.335167  0.128980
# Flavanoids           -0.847498  0.236815   -0.411007  0.115077
# Nonflavanoid.phenols  0.489109 -0.155929    0.292977  0.186230
# Proanthocyanins      -0.499130  0.136698   -0.220746  0.009652
# Color.intensity       0.265668  0.546364    0.248985  0.258887
# Hue                  -0.617369 -0.071747   -0.561296 -0.074667
# OD280.OD315          -0.788230  0.072343   -0.368710  0.003911
# Proline              -0.633717  0.643720   -0.192011  0.223626
#
# ...

# %%
# Visualizar matriz de correlación
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Matriz de Correlación')
plt.show()

# %% [markdown]
# Al observar la matriz de correlación, puedes inferir las relaciones entre las diferentes características del vino. Por ejemplo, se puede encontrar una fuerte correlación positiva entre la cantidad de flavonoides y la cantidad de fenoles totales, esto indica que los vinos que tienen altos niveles de fenoles totales también tienden a tener altos niveles de flavonoides.
#
# Por otro lado, se encuentra una correlación negativa entre la alcalinidad de la ceniza y la cantidad de alcohol, esto podría indicar que los vinos con alta alcalinidad de ceniza tienden a tener una menor cantidad de alcohol.
#
# Estas inferencias pueden ser útiles para entender las características del vino y también pueden ser útiles para la construcción y la interpretación de modelos de data mining.

# %% [markdown]
# #### Gráfico de pares entre características

# %% [markdown]
# Generamos un gráfico de pares utilizando la biblioteca seaborn. `sns.pairplot()` es una función que crea una matriz de ejes y muestra la relación para cada par de columnas en un DataFrame. También dibuja el histograma de cada variable en la diagonal de la matriz para ayudar a visualizar la distribución de cada variable.
#
# El argumento `wine_df` es el DataFrame que vamos a visualizar.
#
# El argumento `hue="Class"` significa que los puntos en los gráficos se colorearán de acuerdo con la columna "Class" en el DataFrame. Esto es útil para visualizar cómo se distribuyen las diferentes clases en relación con las otras características.
#
# Esto nos ayudará a visualizar las relaciones entre todas las parejas de características en tu conjunto de datos, así como la distribución de cada característica, todo en un solo gráfico.

# %%
# Grafica de pares
sns.pairplot(wine_df, hue="Class")
# Out:
# /Users/eugenio/Library/CloudStorage/OneDrive-Personal/UIDE/2024 Maestría Ciencia de Datos y Máquinas de Aprendizaje mención IA/Contenidos/Notebooks_DataMining/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/eugenio/Library/CloudStorage/OneDrive-Personal/UIDE/2024 Maestría Ciencia de Datos y Máquinas de Aprendizaje mención IA/Contenidos/Notebooks_DataMining/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# #### Relación entre dos características

# %% [markdown]
# Generamos un gráfico de dispersión utilizando la biblioteca seaborn. El gráfico de dispersión muestra la relación entre las variables 'Alcohol' y 'Flavanoides' en el DataFrame `wine_df`.
#
# La función `sns.scatterplot()` se utiliza para crear el gráfico de dispersión. Los argumentos `x='Alcohol'` y `y='Flavanoides'` especifican las variables que se utilizarán en los ejes x e y del gráfico, respectivamente.
#
# El argumento `hue='Class'` significa que los puntos en el gráfico se colorearán de acuerdo con la columna 'Class' en el DataFrame. Esto puede ayudarte a visualizar cómo se distribuyen las diferentes clases en relación con las variables 'Alcohol' y 'Flavanoides'.
#
# Las funciones `plt.title()`, `plt.xlabel()` y `plt.ylabel()` se utilizan para establecer el título del gráfico y las etiquetas de los ejes x e y, respectivamente.
#
# Finalmente, `plt.show()` se utiliza para mostrar el gráfico.

# %%
# Relación entre 'Alcohol' y 'Flavanoids'
sns.scatterplot(x='Alcohol', y='Flavanoids', hue='Class', data=wine_df)
plt.title('Relación entre Alcohol y Flavanoides')
plt.xlabel('Alcohol')
plt.ylabel('Flavanoides')
plt.show()

# %% [markdown]
# En este gráfico se muestra la relación entre las características 'alcohol' y 'flavanoids' como un ejemplo específico de cómo explorar la relación entre dos variables continuas en el conjunto de datos de vinos. Estas dos características son conocidas por su influencia en la calidad y el sabor del vino, y su relación puede ser de interés para los expertos en vinos.
#
# Sin embargo, el análisis exploratorio de datos es un proceso amplio y flexible, y hay muchas otras relaciones que podrían ser exploradas. La elección de qué características mostrar en la sección de visualización depende del objetivo del análisis y de las preguntas que se quieran responder.
#
# En un análisis más completo, podríamos explorar las relaciones entre otras características del conjunto de datos, como la acidez, el contenido de azúcar, el pH, etc. Estas características también podrían tener una influencia significativa en las propiedades del vino y serían dignas de explorar en un análisis más detallado.
#
# En resumen, la selección de características específicas para explorar en un tutorial como este es una decisión arbitraria y se elige con el propósito de proporcionar ejemplos claros y concisos. Sin embargo, al aplicar el análisis exploratorio de datos en un contexto real, se puede y se debe explorar una variedad más amplia de características para obtener una comprensión completa del conjunto de datos y las relaciones entre sus variables.

# %% [markdown]
# ### **Conclusiones:**
#
# Esta lectura proporciona una introducción al análisis exploratorio de datos del conjunto de datos de vinos Piedmont. Hemos explorado la distribución de clases, la correlación entre características y la relación entre algunas características específicas. Este es solo el comienzo del análisis de este conjunto de datos, y hay muchas más técnicas y enfoques que se pueden aplicar para obtener una comprensión más profunda de los datos.
#
# ¡Espero que hayas encontrado útil este tutorial y te sientas inspirado para continuar explorando y analizando datos por tu cuenta!

# %% [markdown]
# ![image.png](attachment:image.png)
