# %% [markdown]
# ### Caja de definición

# %% [markdown]
# <div style="padding:10px; border-left:4px solid #0a84ff; background:#eef6ff">
# <b>Definición:</b> El perceptrón es un clasificador lineal...
# </div>

# %% [markdown]
# ### Caja de advertencia

# %% [markdown]
# <div style="padding:10px; border-left:4px solid #d14; background:#ffecec">
# ⚠ Asegúrate de normalizar los datos antes de entrenar.
# </div>

# %% [markdown]
# ### Caja de nota

# %% [markdown]
# <div style="padding:10px; border-left:4px solid #0a0; background:#eaffea">
# 💡 Nota: Este modelo converge más rápido si usas learning rate pequeño.
# </div>

# %% [markdown]
# ### Tabla de contenidos

# %% [markdown]
# **Tabla de contenidos**
# - [Introducción](#Introducción)
# - [Dataset](#Dataset)
# - [Modelo](#Modelo)
# - [Resultados](#Resultados)

# %% [markdown]
# ![MLP](5.%20Computer%20Vision/Image%20classification/gato.jpg)

# %% [markdown]
# <details>
# <summary><b>🤓 Ver explicación teórica (click)</b></summary>
#
# Aquí puedes poner:
#
# - una derivación matemática
# - una explicación larga
# - notas metodológicas
# - teoría extendida
#
# </details>

# %% [markdown]
# <div class="tab">
# <button class="tablinks" onclick="openTab(event, 'teoria')">Teoría</button>
# <button class="tablinks" onclick="openTab(event, 'codigo')">Código</button>
# </div>
#
# <div id="teoria" class="tabcontent">
# <p>Aquí va la teoría...</p>
# </div>
#
# <div id="codigo" class="tabcontent">
# <pre><code>
# # aquí va código
# </code></pre>
# </div>
#
# <script>
# function openTab(evt, tabName) {
#   var i, tabcontent, tablinks;
#   tabcontent = document.getElementsByClassName("tabcontent");
#   for (i = 0; i < tabcontent.length; i++) { tabcontent[i].style.display = "none"; }
#   tablinks = document.getElementsByClassName("tablinks");
#   for (i = 0; i < tablinks.length; i++) { tablinks[i].className = tablinks[i].className.replace(" active", ""); }
#   document.getElementById(tabName).style.display = "block";
#   evt.currentTarget.className += " active";
# }
# </script>

# %% [markdown]
# \begin{aligned}
# z &= Wx + b \\
# \hat{y} &= \sigma(z)
# \end{aligned}

# %% [markdown]
# $ z &= Wx + b \\
# \hat{y} &= \sigma(z) $

# %% [markdown]
# La función de activación es $f(x) = \sigma(w x + b)$ y es no lineal.

# %% [markdown]
# $$
# y = f(Wx + b)
# $$

# %% [markdown]
# $$y = f(Wx + b)$$

# %% [markdown]
# \begin{equation}
# y = f(Wx + b)
# \end{equation}

# %% [markdown]
# | Parámetro | Descripción | Valor por defecto |
# |----------|-------------|-------------------|
# | `lr` | Tasa de aprendizaje | `0.001` |
# | `epochs` | Número de iteraciones | `50` |
# | `batch_size` | Tamaño del lote | `32` |

# %% [markdown]
# <div style="padding:10px; border:1px solid #ccc; border-radius:6px">
# <b>Concepto clave:</b><br>
# La matriz de confusión muestra...
# </div>

# %% [markdown]
# [Ir a Resultados](#Resultados)

# %% [markdown]
# ## Resultados

# %% [markdown]
# ⏱ **Tiempo estimado:** 7 minutos
# 🧪 **Nivel:** Intermedio
