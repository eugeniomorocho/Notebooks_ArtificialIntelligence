# %% [markdown]
# Autor:
# Manuel Eugenio Morocho Cayamcela, PhD

# %% [markdown]
# ## Predicción de diabetes utilizando una red neuronal

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### **Introducción:**
#
# En esta lectura, se realiza un análisis y modelado de un conjunto de datos de diabetes. Comienza con el preprocesamiento de datos, donde se reemplazan los valores faltantes (NaN) en el DataFrame `diabetes_df` con la media de cada columna, y se discute la posibilidad de eliminar los valores atípicos. Luego, se realiza un análisis exploratorio de datos utilizando una matriz de correlación y un mapa de calor para visualizar las relaciones entre las diferentes características, y se crea una matriz de gráficos de dispersión para visualizar las relaciones entre pares de características. A continuación, se instalan las bibliotecas scikit-learn y TensorFlow para el modelado de machine learning. Finalmente, se entrena un modelo de red neuronal utilizando TensorFlow en un conjunto de datos de entrenamiento.
#
# Una red neuronal es un modelo de machine learning inspirado en el cerebro humano. Consiste en una serie de nodos, o "neuronas", organizados en capas. Cada neurona recibe una serie de entradas, las pondera en función de unos pesos (que son los parámetros que el modelo aprenderá), y luego pasa la suma ponderada a través de una función de activación para producir una salida.
#
# El entrenamiento de una red neuronal implica ajustar los pesos de la red para minimizar la diferencia entre las predicciones del modelo y los valores reales. Esto se hace a través de un proceso llamado retropropagación y un algoritmo de optimización como el descenso de gradiente.

# %% [markdown]
# ### **Contenido:**

# %% [markdown]
# #### Cargamos el dataset

# %% [markdown]
# 1. Importa la biblioteca pandas, que es una herramienta poderosa para la manipulación, análisis, y minería de datos en Python.
#
# 2. Utiliza la función `read_csv()` de pandas para cargar un archivo CSV llamado 'diabetes.csv' en un DataFrame de pandas. El archivo se encuentra en la ruta especificada.
#
# 3. Utiliza el método `head()` para mostrar las primeras 5 filas del DataFrame. Esto es útil para obtener una vista rápida de los datos después de cargarlos.
#
# El DataFrame resultante, `diabetes_df`, contiene los datos del archivo 'diabetes.csv' y puede ser utilizado para análisis y modelado de datos.

# %%
# Instalamos las librerías necesarias
# %pip install pandas matplotlib seaborn scikit-learn tensorboard
# %pip install tensorflow

# Importamos las librerías necesarias
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: pandas in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv-1/lib/python3.13/site-packages (2.3.2)
# Requirement already satisfied: matplotlib in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv-1/lib/python3.13/site-packages (3.10.6)
# Requirement already satisfied: seaborn in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv-1/lib/python3.13/site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv-1/lib/python3.13/site-packages (1.7.2)
# Requirement already satisfied: tensorboard in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv-1/lib/python3.13/site-packages (2.20.0)
# Requirement already satisfied: numpy>=1.26.0 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv-1/lib/python3.13/site-packages (from pandas) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv-1/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv-1/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv-1/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv-1/lib/python3.13/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv-1/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv-1/lib/python3.13/site-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv-1/lib/python3.13/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv-1/lib/python3.13/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv-1/lib/python3.13/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv-1/lib/python3.13/site-packages (from matplotlib) (3.2.4)
# Requirement already satisfied: scipy>=1.8.0 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv-1/lib/python3.13/site-packages (from scikit-learn) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv-1/lib/python3.13/site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv-1/lib/python3.13/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: absl-py>=0.4 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv-1/lib/python3.13/site-packages (from tensorboard) (2.3.1)
# Requirement already satisfied: grpcio>=1.48.2 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv-1/lib/python3.13/site-packages (from tensorboard) (1.75.1)
# Requirement already satisfied: markdown>=2.6.8 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv-1/lib/python3.13/site-packages (from tensorboard) (3.9)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv-1/lib/python3.13/site-packages (from tensorboard) (6.32.1)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv-1/lib/python3.13/site-packages (from tensorboard) (80.9.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv-1/lib/python3.13/site-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv-1/lib/python3.13/site-packages (from tensorboard) (3.1.3)
# Requirement already satisfied: typing-extensions~=4.12 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv-1/lib/python3.13/site-packages (from grpcio>=1.48.2->tensorboard) (4.15.0)
# Requirement already satisfied: six>=1.5 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv-1/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv-1/lib/python3.13/site-packages (from werkzeug>=1.0.1->tensorboard) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement tensorflow (from versions: none)
# ERROR: No matching distribution found for tensorflow
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 6
#       3 get_ipython().run_line_magic('pip', 'install tensorflow')
#       5 # Importamos las librerías necesarias
# ----> 6 import tensorflow as tf
#       7 import pandas as pd
#       8 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
# Cargamos el dataset diabetes.csv
diabetes_df = pd.read_csv('/Users/eugenio/Documents/Notebooks_ArtificialIntelligence/Datasets/diabetes.csv')
diabetes_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Cargamos el dataset diabetes.csv
# ----> 2 diabetes_df = pd.read_csv('/Users/eugenio/Documents/Notebooks_ArtificialIntelligence/Datasets/diabetes.csv')
#       3 diabetes_df.head()
#
# NameError: name 'pd' is not defined

# %%
# Ploteo el conteo de clases de la base de datos "y_diabetes"
import seaborn as sns

sns.countplot(x='diabetes', data=diabetes_df)
# Out:
# <Axes: xlabel='diabetes', ylabel='count'>

# %% [markdown]
# El conjunto de datos de diabetes contiene las siguientes variables:
#
# 1. `pregnancies`: Número de veces que la persona ha estado embarazada.
# 2. `glucose`: Concentración de glucosa en plasma a 2 horas en una prueba oral de tolerancia a la glucosa.
# 3. `diastolic`: Presión arterial diastólica (mm Hg).
# 4. `triceps`: Espesor del pliegue de la piel del tríceps (mm).
# 5. `insulin`: Suero de insulina de 2 horas (mu U/ml).
# 6. `bmi`: Índice de masa corporal (peso en kg/(altura en m)^2).
# 7. `dpf`: Pedigree de la función de la diabetes, una función que puntúa la probabilidad de diabetes en función de la historia familiar.
# 8. `age`: Edad (años).
# 9. `diabetes`: Variable de clase (0 o 1) donde '1' denota que el paciente tiene diabetes y '0' denota que el paciente no tiene diabetes.
#
# Estas variables se utilizan para predecir si un paciente tiene diabetes o no.

# %% [markdown]
# #### Buscamos si existen valores de tipo 'null' en la base de datos

# %%
diabetes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   pregnancies  768 non-null    int64
#  1   glucose      768 non-null    int64
#  2   diastolic    768 non-null    int64
#  3   triceps      768 non-null    int64
#  4   insulin      768 non-null    int64
#  5   bmi          768 non-null    float64
#  6   dpf          768 non-null    float64
#  7   age          768 non-null    int64
#  8   diabetes     768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# #### Graficamos el rango de valores de cada columna del DataFrame diabetes_df

# %% [markdown]
# 1. Importa la biblioteca matplotlib, que es una biblioteca de Python para la creación de gráficos estáticos, animados e interactivos.
#
# 2. Crea una nueva figura y un conjunto de subtramas. Esto proporciona un lienzo en el que puedes dibujar tus gráficos.
#
# 3. Utiliza el método `boxplot()` del DataFrame `diabetes_df` para crear un gráfico de caja para cada columna. Un gráfico de caja muestra la mediana, los cuartiles y los valores atípicos de cada columna, lo que te permite ver la distribución y el rango de valores de cada columna.
#
# 4. Utiliza `plt.xticks(rotation=90)` para rotar los nombres de las columnas 90 grados. Esto hace que los nombres de las columnas sean más legibles cuando tienes muchas columnas.
#
# 5. Utiliza `plt.show()` para mostrar el gráfico. Esto es necesario porque matplotlib requiere que llames a `show()` para que se muestre el gráfico.

# %%
# Creamos una figura y un conjunto de subtramas 'ax'
fig, ax = plt.subplots()

# Hacemos un gráfico de caja para cada columna y lo mostramos en el conjunto de subtramas 'ax'
diabetes_df.boxplot(ax=ax)

# Rotamos los nombres de las columnas para que sean legibles
plt.xticks(rotation=90)

# Mostramos el gráfico
plt.show()

# %% [markdown]
# #### Reemplazamos los valores 0 por NaN

# %% [markdown]
# Esto se hace porque en este contexto, un valor de 0 en ciertas columnas puede no ser válido o puede indicar datos faltantes. Al reemplazar los 0s por NaNs, estos valores pueden ser tratados adecuadamente como datos faltantes en los análisis posteriores.
#
# En el conjunto de datos de diabetes, un valor de 0 en las columnas 'glucose', 'diastolic', 'triceps', 'insulin', 'bmi' puede no ser válido o puede indicar datos faltantes. Por ejemplo, es poco probable que una persona tenga 0 de presión diastólica o 0 de glucosa, ya que estos son indicadores vitales.
#
# Por otro lado, un valor de 0 en otras columnas como 'pregnancies' puede ser perfectamente válido (una mujer puede no haber estado embarazada nunca) y por lo tanto no debería ser tratado como un valor faltante.
#
# Por lo tanto, se reemplazan los 0s por NaNs solo en las columnas donde un 0 probablemente indica un valor faltante o erróneo.
#
# 1. Importa la biblioteca `numpy`, que es una biblioteca de Python para trabajar con arrays.
#
# 2. Reemplaza los valores 0 por nan (Not a Number) en las columnas 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', y 'BMI' del DataFrame `diabetes_df`.

# %%
# Importamos la librería numpy
import numpy as np

# Reemplazamos los valores 0 por NaN
diabetes_df[['glucose', 'diastolic', 'triceps', 'insulin', 'bmi']] = diabetes_df[['glucose', 'diastolic', 'triceps', 'insulin', 'bmi']].replace(0, np.nan)

# %% [markdown]
# #### Reemplazamos los valores NaN por la media

# %% [markdown]
# 1. Utiliza el método `fillna()` del DataFrame `diabetes_df` para reemplazar todos los valores nan (not a number) en el DataFrame. Los valores nan suelen indicar datos faltantes.
#
# 2. El primer argumento para `fillna()`, `diabetes_df.mean()`, es un DataFrame que contiene la media de cada columna en `diabetes_df`. Por lo tanto, este código reemplaza cada valor nan con la media de su columna.
#
# 3. El argumento `inplace = True` indica que los cambios deben hacerse en el DataFrame `diabetes_df` existente, en lugar de crear un nuevo DataFrame.
#
# Después de ejecutar este código, `diabetes_df` ya no contendrá ningún valor nan. En su lugar, los datos faltantes habrán sido imputados con la media de su respectiva columna.

# %%
# Reemplazamos los valores nan por la media
diabetes_df.fillna(diabetes_df.mean(), inplace = True)

# Mostramos los primeros registros
diabetes_df.head()
# Out:
#    pregnancies  glucose  diastolic   triceps     insulin   bmi    dpf  age  \
# 0            6    148.0       72.0  35.00000  155.548223  33.6  0.627   50
# 1            1     85.0       66.0  29.00000  155.548223  26.6  0.351   31
# 2            8    183.0       64.0  29.15342  155.548223  23.3  0.672   32
# 3            1     89.0       66.0  23.00000   94.000000  28.1  0.167   21
# 4            0    137.0       40.0  35.00000  168.000000  43.1  2.288   33
#
#    diabetes
# 0         1
# 1         0
# 2         1
# 3         0
# 4         1

# %% [markdown]
# #### Eliminación los datos atípicos (outliers)

# %% [markdown]
# La decisión de eliminar o no los valores atípicos depende del contexto y del conocimiento del dominio. En el caso del conjunto de datos de diabetes, los valores atípicos pueden ser legítimos. Por ejemplo, es posible que algunas personas tengan niveles de glucosa o presión arterial significativamente diferentes a la media.
#
# Eliminar estos valores atípicos podría resultar en la pérdida de información importante. Además, algunos modelos de machine learning son sensibles a los valores atípicos, mientras que otros pueden manejarlos bien. Por ejemplo, las redes neuronales, pueden ser bastante resistentes a los valores atípicos.
#
# Por lo tanto, la decisión de eliminar o no los valores atípicos debe basarse en un análisis cuidadoso de los datos y en el conocimiento del dominio. Si se decide eliminar los valores atípicos, debemos asegurarnos de documentar este paso en nuestro proceso de análisis de datos.
#
# Para este ejemplo, no eliminaremos los datos atípicos.

# %% [markdown]
# #### Graficamos la correlación entre variables

# %% [markdown]
# 1. Importa la biblioteca seaborn, que es una biblioteca de visualización de datos en Python basada en matplotlib. Proporciona una interfaz de alto nivel para dibujar gráficos estadísticos atractivos e informativos.
#
# 2. Utiliza el método `corr()` del DataFrame `diabetes_df` para calcular la correlación entre todas las parejas de columnas. Esto devuelve un nuevo DataFrame donde el valor en la i-ésima fila y la j-ésima columna es la correlación entre la i-ésima y la j-ésima columna de `diabetes_df`.
#
# 3. Utiliza `sns.heatmap()` para dibujar un mapa de calor de la matriz de correlación. Un mapa de calor es una representación gráfica de los datos donde los valores individuales de una matriz se representan como colores.
#
# 4. El argumento `annot = True` indica que los valores de correlación deben escribirse en las celdas del mapa de calor.
#
# Después de ejecutar este código, verás un mapa de calor de la matriz de correlación de `diabetes_df`. Esto te permite ver rápidamente qué pares de columnas están fuertemente correlacionados.

# %%
# Importamos la librería seaborn
import seaborn as sns

# Graficamos la matriz de correlación
sns.heatmap(diabetes_df.corr(), annot = True)
# Out:
# <Axes: >

# %% [markdown]
# El análisis de correlación te permite entender las relaciones lineales entre las diferentes características de tu conjunto de datos. Aquí hay algunas cosas que podrías considerar al analizar la matriz de correlación del conjunto de datos de diabetes:
#
# 1. **Correlaciones fuertes entre las características y el objetivo**: Si estás intentando predecir una variable específica (por ejemplo, si un paciente tiene diabetes o no), querrás buscar características que estén fuertemente correlacionadas con esa variable objetivo. Estas podrían ser características importantes para tu modelo.
#
# 2. **Correlaciones fuertes entre las características**: Si dos características están fuertemente correlacionadas entre sí, esto podría indicar multicolinealidad, lo que puede ser problemático para algunos modelos de machine learning. Podrías considerar eliminar una de las características correlacionadas o combinarlas de alguna manera.
#
# 3. **Correlaciones débiles**: Las características que tienen una correlación débil con la variable objetivo podrían no ser muy útiles para tu modelo. Sin embargo, ten cuidado con descartar estas características demasiado rápido. Aunque no tengan una relación lineal fuerte con la variable objetivo, podrían tener una relación no lineal o podrían proporcionar información importante en combinación con otras características.
#
# Recuerda, la correlación no implica causalidad. Solo porque dos características estén correlacionadas, no significa que una cause la otra. Además, este análisis solo considera relaciones lineales entre variables.

# %% [markdown]
# #### Separamos las variables predictoras `X`, de las variables objetivo `y`

# %% [markdown]
# Preparamos el conjunto de datos para el modelado con una red neuronal, eliminamos la columna 'diabetes' es el objetivo o la variable que se está tratando de predecir.
#
# - `diabetes_df.drop('diabetes', axis=1)`: está eliminando la columna 'diabetes' del DataFrame `diabetes_df`. La función `drop` de pandas se utiliza para eliminar filas o columnas. En este caso, estás eliminando una columna, por lo que `axis=1`. Si quisieras eliminar una fila, usarías `axis=0`. El resultado de esta operación es un nuevo DataFrame que no incluye la columna 'diabetes'. Este nuevo DataFrame se lo guarda en la variable `X_diabetes` para usarse como las características (X) en la red neuronal.

# %%
# Seleccionamos las columnas predictoras
X_diabetes = diabetes_df.drop('diabetes', axis=1)
X_diabetes.head()
# Out:
#    pregnancies  glucose  diastolic   triceps     insulin   bmi    dpf  age
# 0            6    148.0       72.0  35.00000  155.548223  33.6  0.627   50
# 1            1     85.0       66.0  29.00000  155.548223  26.6  0.351   31
# 2            8    183.0       64.0  29.15342  155.548223  23.3  0.672   32
# 3            1     89.0       66.0  23.00000   94.000000  28.1  0.167   21
# 4            0    137.0       40.0  35.00000  168.000000  43.1  2.288   33

# %% [markdown]
# Seleccionamos la columna 'diabetes' del DataFrame `diabetes_df` y la asignamos a la variable `y_diabetes`.
#
# - `diabetes_df['diabetes']`: está seleccionando la columna 'diabetes' del DataFrame `diabetes_df`. En pandas, puedes seleccionar una sola columna de un DataFrame utilizando la sintaxis `df['column_name']`.
#
# - Asignamos la columna 'diabetes' a la variable `y_diabetes`. Esta variable se utilizará como la variable objetivo (y) en la red neuronal.

# %%
# Seleccionamos la columna diabetes como variable objetivo
y_diabetes = diabetes_df['diabetes']
y_diabetes.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: diabetes, dtype: int64

# %% [markdown]
# #### Separamos la base de datos en conjuntos de entrenamiento y de prueba

# %% [markdown]
# Utilizamos la función `train_test_split` de la biblioteca sklearn en Python para dividir el conjunto de datos en conjuntos de entrenamiento y prueba.
#
# - `from sklearn.model_selection import train_test_split`: Esta línea está importando la función `train_test_split` de la biblioteca sklearn. Esta función se utiliza para dividir conjuntos de datos en conjuntos de entrenamiento y prueba.
#
# - `X_train, X_test, y_train, y_test = train_test_split(X_diabetes, y_diabetes, test_size=0.3)`: Esta línea está utilizando la función `train_test_split` para dividir `X_diabetes` y `y_diabetes` en conjuntos de entrenamiento y prueba. El argumento `test_size=0.3` indica que el 30% del conjunto de datos se utilizará como conjunto de prueba, y el 70% restante se utilizará como conjunto de entrenamiento.

# %%
# Importamos la función train_test_split de la librería sklearn
from sklearn.model_selection import train_test_split

# Dividimos la base de datos en entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X_diabetes, y_diabetes, test_size=0.3)

# %% [markdown]
# ### Modelado, compilado, y entrenamiento de una red neuronal

# %% [markdown]
# 1. Instala la biblioteca scikit-learn utilizando pip, que es un sistema de gestión de paquetes utilizado para instalar y administrar paquetes de software en Python.
#
# 2. Instala la biblioteca tensorflow utilizando pip. Tensorflow es una biblioteca de código abierto para machine learning y redes neuronales.
#
# 3. Importa tensorflow como tf. Esto significa que puedes acceder a las funciones y clases de tensorflow utilizando el prefijo tf.
#
# 4. Imprime la versión de tensorflow. Esto es útil para comprobar que tensorflow se ha instalado correctamente y para saber qué versión estás utilizando, ya que diferentes versiones pueden tener diferentes características y comportamientos.

# %% [markdown]
# #### Modelamos una red neuronal simple

# %% [markdown]
# Importando dos módulos de la biblioteca TensorFlow, específicamente de su API de alto nivel llamada Keras. Estos módulos son comúnmente utilizados para construir redes neuronales.
#
# Aquí está lo que hace cada parte:
#
# - `from tensorflow.keras.models import Sequential`: Esta línea está importando el módulo `Sequential` de Keras. `Sequential` es una clase que permite crear modelos de redes neuronales donde las capas se añaden una tras otra en secuencia.
#
# - `from tensorflow.keras.layers import Dense`: Esta línea está importando el módulo `Dense` de Keras. `Dense` es una clase que permite crear capas de neuronas completamente conectadas, que son el tipo de capa más común en las redes neuronales.

# %%
# Importamos los módulos necesarios para la creación del modelo
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# Utilizamos la biblioteca TensorFlow para construir una red neuronal secuencial utilizando la API de Keras. Construiremos una red neuronal con una capa de entrada de 8 neuronas, una capa oculta de 12 neuronas, otra capa oculta de 8 neuronas, y una capa de salida de 1 neurona.
#
# Aquí está lo que hace cada parte:
#
# - `model = Sequential()`: Esta línea está creando un nuevo modelo secuencial. Un modelo secuencial es apropiado para una pila simple de capas donde cada capa tiene exactamente un tensor de entrada y un tensor de salida.
#
# - `model.add(Dense(12, input_dim=8, activation='relu'))`: Esta línea está añadiendo una capa densa (completamente conectada) al modelo con 12 neuronas, y está utilizando la función de activación ReLU. `input_dim=8` especifica que el número de entradas a esta capa (es decir, el número de neuronas en la capa anterior) es 8. El numero de neuronas de la capa de entrada debe coincidir con el número de variables predictoras, que en el caso de el dataset de diabetes es 8.
#
# - `model.add(Dense(8, activation='relu'))`: Esta línea está añadiendo otra capa densa al modelo con 8 neuronas, y también está utilizando la función de activación ReLU.
#
# - `model.add(Dense(1, activation='sigmoid'))`: Esta línea está añadiendo una capa densa final al modelo con 1 neurona, y está utilizando la función de activación sigmoide. La función de activación sigmoide es comúnmente utilizada en la capa de salida de un modelo de clasificación binaria.

# %%
# Creamos un modelo secuencial
model = Sequential()

# Añadimos una capa densa con 12 neuronas y función de activación relu. Incluimos la dimensión de entrada con 8 variables predictoras.
model.add(Dense(12, input_dim=8, activation='relu'))

# Añadimos una capa densa con 8 neuronas y función de activación relu
model.add(Dense(8, activation='relu'))

# Añadimos una capa densa con 1 neurona y función de activación sigmoid
model.add(Dense(1, activation='sigmoid'))
# Out:
# /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# #### Compilamos la red neuronal

# %% [markdown]
# Utilizaremos la función `compile` de Keras para configurar el proceso de aprendizaje de la red neuronal. Configuramos el modelo para que se entrene utilizando el optimizador Adam, la función de pérdida de entropía cruzada binaria, y para que se evalúe utilizando la precisión.
#
# - `optimizer = 'adam'`: Esta línea está estableciendo el optimizador del modelo a 'adam'. Adam es un método de optimización que se utiliza comúnmente en redes neuronales. Ajusta la tasa de aprendizaje adaptativamente para cada parámetro.
#
# - `loss = 'binary_crossentropy'`: Esta línea está estableciendo la función de pérdida del modelo a 'binary_crossentropy'. La entropía cruzada binaria es una función de pérdida que se utiliza en problemas de clasificación binaria. Mide la "distancia" entre las predicciones y los verdaderos resultados.
#
# - `metrics=['accuracy']`: Esta línea está estableciendo la métrica que se utilizará para evaluar el rendimiento del modelo a 'accuracy'. La precisión es la proporción de predicciones correctas sobre el total de predicciones.

# %%
# Compilamos el modelo con el optimizador adam, la función de pérdida binary_crossentropy, y las metricas accuracy
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# #### Resumen del modelo de red neuronal

# %% [markdown]
# El método `model.summary()` en Keras proporciona una representación textual del modelo. Muestra las capas de la red neuronal, la forma de salida de cada capa y el número de parámetros (pesos y sesgos) en cada capa. También muestra el total de parámetros en el modelo.
#
# En este ejemplo, puedes ver que el modelo tiene tres capas. La primera capa tiene 12 neuronas y 108 parámetros, la segunda capa tiene 8 neuronas y 104 parámetros, y la tercera capa tiene 1 neurona y 9 parámetros. El total de parámetros en el modelo es 221.

# %%
# Visualizamos un resumen del modelo creado 
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 12)             │           108 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │           104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 221 (884.00 B)
#  Trainable params: 221 (884.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# Mostramos la forma de la salida del modelo
model.output_shape
# Out:
# (None, 1)

# %% [markdown]
# #### Entrenamos la red neuronal

# %% [markdown]
# 1. `model.fit()` es el método que entrena el modelo. Los argumentos `X_train` y `y_train` son los datos de entrenamiento y las etiquetas correspondientes.
#
# 2. `epochs = 150` significa que el conjunto de datos completo se pasará por la red neuronal 150 veces. Cada pasada por todo el conjunto de datos se llama una época.
#
# 3. `batch_size = 32` significa que los datos de entrenamiento se dividen en lotes de 32 ejemplos y el modelo se actualiza después de cada lote. Los lotes más pequeños pueden hacer que el modelo aprenda más rápido, pero también pueden hacer que el aprendizaje sea menos estable. Los lotes más grandes pueden hacer que el aprendizaje sea más estable, pero también pueden hacer que el aprendizaje sea más lento.
#
# Después de ejecutar este código, el modelo habrá sido entrenado en los datos de `X_train` y `y_train` durante 150 épocas, y estará listo para hacer predicciones.

# %%
# Entrenamos el modelo con los datos de entrenamiento, especificando el número de épocas y el tamaño del batch
model.fit(X_train, y_train, epochs = 300, batch_size = 32)
# Out:
# Epoch 1/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7225 - loss: 0.5536
# Epoch 2/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7620 - loss: 0.5228
# Epoch 3/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7729 - loss: 0.5166
# Epoch 4/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7169 - loss: 0.5622
# Epoch 5/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7155 - loss: 0.5597
# Epoch 6/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6886 - loss: 0.6204
# Epoch 7/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7099 - loss: 0.5623
# Epoch 8/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7124 - loss: 0.5440
# Epoch 9/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7485 - loss: 0.5405
# Epoch 10/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7593 - loss: 0.5156
# Epoch 11/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7569 - loss: 0.5232
# Epoch 12/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7531 - loss: 0.5356
# Epoch 13/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7623 - loss: 0.5123
# Epoch 14/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7588 - loss: 0.5322
# Epoch 15/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7280 - loss: 0.5409
# Epoch 16/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7292 - loss: 0.5431
# Epoch 17/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7592 - loss: 0.5157
# Epoch 18/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7179 - loss: 0.5574
# Epoch 19/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7407 - loss: 0.5634
# Epoch 20/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7055 - loss: 0.5597
# Epoch 21/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7660 - loss: 0.5195
# Epoch 22/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7410 - loss: 0.5209
# Epoch 23/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7292 - loss: 0.5166
# Epoch 24/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7377 - loss: 0.5358
# Epoch 25/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6953 - loss: 0.5724
# Epoch 26/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7314 - loss: 0.5783
# Epoch 27/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7512 - loss: 0.5228
# Epoch 28/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7035 - loss: 0.5621
# Epoch 29/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7457 - loss: 0.5354
# Epoch 30/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7465 - loss: 0.5242
# Epoch 31/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7396 - loss: 0.5100
# Epoch 32/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7644 - loss: 0.5116
# Epoch 33/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7605 - loss: 0.5063
# Epoch 34/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7237 - loss: 0.5409
# Epoch 35/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7201 - loss: 0.5372
# Epoch 36/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7025 - loss: 0.5659
# Epoch 37/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7035 - loss: 0.5531
# Epoch 38/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7614 - loss: 0.5292
# Epoch 39/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7401 - loss: 0.5423
# Epoch 40/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7546 - loss: 0.5370
# Epoch 41/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7314 - loss: 0.5503
# Epoch 42/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7534 - loss: 0.5311
# Epoch 43/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7411 - loss: 0.5245
# Epoch 44/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7319 - loss: 0.5386
# Epoch 45/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7047 - loss: 0.5577
# Epoch 46/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7519 - loss: 0.5209
# Epoch 47/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7468 - loss: 0.5096
# Epoch 48/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7518 - loss: 0.5137
# Epoch 49/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7591 - loss: 0.5253
# Epoch 50/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7383 - loss: 0.5507
# Epoch 51/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7154 - loss: 0.5683
# Epoch 52/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7564 - loss: 0.5241
# Epoch 53/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7247 - loss: 0.5542
# Epoch 54/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7752 - loss: 0.5200
# Epoch 55/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7387 - loss: 0.5447
# Epoch 56/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7173 - loss: 0.5263
# Epoch 57/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7658 - loss: 0.5029
# Epoch 58/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7338 - loss: 0.5400
# Epoch 59/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7245 - loss: 0.5506
# Epoch 60/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7313 - loss: 0.5349
# Epoch 61/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7376 - loss: 0.5503
# Epoch 62/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7499 - loss: 0.5316
# Epoch 63/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7478 - loss: 0.5218
# Epoch 64/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7455 - loss: 0.5078
# Epoch 65/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7663 - loss: 0.5270
# Epoch 66/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7416 - loss: 0.5286
# Epoch 67/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7805 - loss: 0.5031
# Epoch 68/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8005 - loss: 0.4889
# Epoch 69/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7191 - loss: 0.5478
# Epoch 70/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7458 - loss: 0.5136
# Epoch 71/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7528 - loss: 0.5075
# Epoch 72/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7713 - loss: 0.4940
# Epoch 73/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7201 - loss: 0.5561
# Epoch 74/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7291 - loss: 0.5293
# Epoch 75/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7212 - loss: 0.5695
# Epoch 76/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7313 - loss: 0.5609
# Epoch 77/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7770 - loss: 0.5373
# Epoch 78/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7132 - loss: 0.5686
# Epoch 79/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7281 - loss: 0.5555
# Epoch 80/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7713 - loss: 0.4876
# Epoch 81/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7323 - loss: 0.5461
# Epoch 82/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7348 - loss: 0.5045
# Epoch 83/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7078 - loss: 0.5738
# Epoch 84/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7246 - loss: 0.5522
# Epoch 85/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7287 - loss: 0.5438
# Epoch 86/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7780 - loss: 0.4874
# Epoch 87/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7382 - loss: 0.4977
# Epoch 88/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7256 - loss: 0.5525
# Epoch 89/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7464 - loss: 0.5108
# Epoch 90/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7048 - loss: 0.5783
# Epoch 91/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7714 - loss: 0.5404
# Epoch 92/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7657 - loss: 0.5132
# Epoch 93/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7625 - loss: 0.5034
# Epoch 94/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7713 - loss: 0.5024
# Epoch 95/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7626 - loss: 0.5053
# Epoch 96/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7734 - loss: 0.4993
# Epoch 97/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7534 - loss: 0.4995
# Epoch 98/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7568 - loss: 0.5043
# Epoch 99/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7718 - loss: 0.5263
# Epoch 100/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7628 - loss: 0.4805
# Epoch 101/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7286 - loss: 0.5193
# Epoch 102/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7673 - loss: 0.4940
# Epoch 103/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7227 - loss: 0.5474
# Epoch 104/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7767 - loss: 0.4856
# Epoch 105/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7824 - loss: 0.4878
# Epoch 106/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7660 - loss: 0.5027
# Epoch 107/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7622 - loss: 0.4938
# Epoch 108/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7593 - loss: 0.5124
# Epoch 109/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7765 - loss: 0.4959
# Epoch 110/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7704 - loss: 0.4762
# Epoch 111/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7409 - loss: 0.5394
# Epoch 112/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7370 - loss: 0.5558
# Epoch 113/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7680 - loss: 0.5069
# Epoch 114/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7195 - loss: 0.5364
# Epoch 115/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7201 - loss: 0.5773
# Epoch 116/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7906 - loss: 0.4788
# Epoch 117/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7413 - loss: 0.5210
# Epoch 118/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7836 - loss: 0.4843
# Epoch 119/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.7374 - loss: 0.5093
# Epoch 120/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8072 - loss: 0.4510
# Epoch 121/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7476 - loss: 0.4972
# Epoch 122/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7864 - loss: 0.4857
# Epoch 123/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7668 - loss: 0.5078
# Epoch 124/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7163 - loss: 0.5545
# Epoch 125/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7786 - loss: 0.4774
# Epoch 126/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.7427 - loss: 0.5406
# Epoch 127/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7158 - loss: 0.5622
# Epoch 128/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7570 - loss: 0.5107
# Epoch 129/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7726 - loss: 0.5091
# Epoch 130/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7211 - loss: 0.5244
# Epoch 131/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7592 - loss: 0.4930
# Epoch 132/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7324 - loss: 0.5356
# Epoch 133/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7139 - loss: 0.5582
# Epoch 134/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7590 - loss: 0.4989
# Epoch 135/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7507 - loss: 0.4971
# Epoch 136/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7526 - loss: 0.5093
# Epoch 137/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7684 - loss: 0.5156
# Epoch 138/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7280 - loss: 0.5419
# Epoch 139/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7810 - loss: 0.4946
# Epoch 140/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7276 - loss: 0.5653
# Epoch 141/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7751 - loss: 0.4932
# Epoch 142/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7336 - loss: 0.5430
# Epoch 143/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7449 - loss: 0.5308
# Epoch 144/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7699 - loss: 0.4890
# Epoch 145/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7714 - loss: 0.5221
# Epoch 146/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7847 - loss: 0.4808
# Epoch 147/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7457 - loss: 0.5042
# Epoch 148/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7679 - loss: 0.4970
# Epoch 149/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7767 - loss: 0.5102
# Epoch 150/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7753 - loss: 0.4859
# Epoch 151/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7197 - loss: 0.5275
# Epoch 152/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7191 - loss: 0.5560
# Epoch 153/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7665 - loss: 0.5091
# Epoch 154/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7679 - loss: 0.4775
# Epoch 155/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7615 - loss: 0.5019
# Epoch 156/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7675 - loss: 0.4907
# Epoch 157/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7550 - loss: 0.4865
# Epoch 158/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7818 - loss: 0.4895
# Epoch 159/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7627 - loss: 0.4882
# Epoch 160/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7824 - loss: 0.5069
# Epoch 161/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7628 - loss: 0.4950
# Epoch 162/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7490 - loss: 0.5220
# Epoch 163/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7704 - loss: 0.4854
# Epoch 164/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7715 - loss: 0.4910
# Epoch 165/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7489 - loss: 0.5084
# Epoch 166/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7957 - loss: 0.4777
# Epoch 167/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7373 - loss: 0.5225
# Epoch 168/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7883 - loss: 0.4778
# Epoch 169/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7898 - loss: 0.4735
# Epoch 170/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7432 - loss: 0.5067
# Epoch 171/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7738 - loss: 0.5119
# Epoch 172/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8013 - loss: 0.4959
# Epoch 173/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7776 - loss: 0.5097
# Epoch 174/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8019 - loss: 0.4718
# Epoch 175/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7512 - loss: 0.5029
# Epoch 176/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7502 - loss: 0.5058
# Epoch 177/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7505 - loss: 0.5249
# Epoch 178/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7717 - loss: 0.4844
# Epoch 179/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7429 - loss: 0.5326
# Epoch 180/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7801 - loss: 0.4914
# Epoch 181/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7656 - loss: 0.5038
# Epoch 182/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7680 - loss: 0.4942
# Epoch 183/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7814 - loss: 0.4914
# Epoch 184/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7696 - loss: 0.5165
# Epoch 185/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7974 - loss: 0.4650
# Epoch 186/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7364 - loss: 0.5241
# Epoch 187/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7721 - loss: 0.4760
# Epoch 188/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7879 - loss: 0.4732
# Epoch 189/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7495 - loss: 0.4943
# Epoch 190/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7509 - loss: 0.5273
# Epoch 191/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7363 - loss: 0.5063
# Epoch 192/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7619 - loss: 0.5093
# Epoch 193/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7912 - loss: 0.4784
# Epoch 194/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7510 - loss: 0.5007
# Epoch 195/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7818 - loss: 0.5051
# Epoch 196/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7564 - loss: 0.5052
# Epoch 197/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7902 - loss: 0.4911
# Epoch 198/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7852 - loss: 0.4991
# Epoch 199/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7272 - loss: 0.5501
# Epoch 200/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7452 - loss: 0.5345
# Epoch 201/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7724 - loss: 0.5025
# Epoch 202/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7738 - loss: 0.4752
# Epoch 203/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7572 - loss: 0.5019
# Epoch 204/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7557 - loss: 0.4988
# Epoch 205/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7559 - loss: 0.5347
# Epoch 206/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7796 - loss: 0.4948
# Epoch 207/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7743 - loss: 0.5169
# Epoch 208/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7832 - loss: 0.4611
# Epoch 209/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8037 - loss: 0.4476
# Epoch 210/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7804 - loss: 0.4850
# Epoch 211/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7847 - loss: 0.4748
# Epoch 212/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7682 - loss: 0.4899
# Epoch 213/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7422 - loss: 0.5235
# Epoch 214/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7204 - loss: 0.5609
# Epoch 215/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7443 - loss: 0.5406
# Epoch 216/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7961 - loss: 0.4776
# Epoch 217/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7663 - loss: 0.4962
# Epoch 218/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7416 - loss: 0.5358
# Epoch 219/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7612 - loss: 0.5126
# Epoch 220/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7602 - loss: 0.4997
# Epoch 221/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7656 - loss: 0.4814
# Epoch 222/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7585 - loss: 0.4935
# Epoch 223/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7430 - loss: 0.5240
# Epoch 224/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7289 - loss: 0.5226
# Epoch 225/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7805 - loss: 0.4789
# Epoch 226/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7515 - loss: 0.5226
# Epoch 227/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7598 - loss: 0.5021
# Epoch 228/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7632 - loss: 0.5233
# Epoch 229/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7607 - loss: 0.4967
# Epoch 230/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7356 - loss: 0.5472
# Epoch 231/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8010 - loss: 0.4652
# Epoch 232/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7710 - loss: 0.4783
# Epoch 233/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8012 - loss: 0.4601
# Epoch 234/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8001 - loss: 0.4877
# Epoch 235/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7858 - loss: 0.4866
# Epoch 236/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7959 - loss: 0.4636
# Epoch 237/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7562 - loss: 0.4799
# Epoch 238/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7758 - loss: 0.4975
# Epoch 239/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7501 - loss: 0.5175
# Epoch 240/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7608 - loss: 0.5129
# Epoch 241/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7726 - loss: 0.4877
# Epoch 242/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7764 - loss: 0.4733
# Epoch 243/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7538 - loss: 0.4952
# Epoch 244/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7647 - loss: 0.4860
# Epoch 245/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8167 - loss: 0.4660
# Epoch 246/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7861 - loss: 0.4595
# Epoch 247/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7775 - loss: 0.4632
# Epoch 248/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7701 - loss: 0.4879
# Epoch 249/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7639 - loss: 0.5001
# Epoch 250/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7534 - loss: 0.4901
# Epoch 251/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7826 - loss: 0.4738
# Epoch 252/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7767 - loss: 0.4855
# Epoch 253/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7685 - loss: 0.4790
# Epoch 254/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7411 - loss: 0.5276
# Epoch 255/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7929 - loss: 0.4622
# Epoch 256/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7832 - loss: 0.4783
# Epoch 257/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7933 - loss: 0.4731
# Epoch 258/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7749 - loss: 0.5156
# Epoch 259/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7735 - loss: 0.4865
# Epoch 260/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7332 - loss: 0.5439
# Epoch 261/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6888 - loss: 0.5990
# Epoch 262/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7738 - loss: 0.4657
# Epoch 263/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7675 - loss: 0.4996
# Epoch 264/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7967 - loss: 0.4720
# Epoch 265/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7674 - loss: 0.4924
# Epoch 266/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7866 - loss: 0.4845
# Epoch 267/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7659 - loss: 0.4825
# Epoch 268/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7687 - loss: 0.4817
# Epoch 269/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7872 - loss: 0.4558
# Epoch 270/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7796 - loss: 0.5001
# Epoch 271/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7804 - loss: 0.4640
# Epoch 272/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7843 - loss: 0.4705
# Epoch 273/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8014 - loss: 0.4511
# Epoch 274/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7758 - loss: 0.4789
# Epoch 275/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7395 - loss: 0.5241
# Epoch 276/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7756 - loss: 0.4895
# Epoch 277/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7715 - loss: 0.4976
# Epoch 278/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7547 - loss: 0.5226
# Epoch 279/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7814 - loss: 0.4665
# Epoch 280/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8027 - loss: 0.4597
# Epoch 281/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7173 - loss: 0.5387
# Epoch 282/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7431 - loss: 0.5330
# Epoch 283/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7834 - loss: 0.4571
# Epoch 284/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7924 - loss: 0.4767
# Epoch 285/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7678 - loss: 0.4748
# Epoch 286/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7838 - loss: 0.4858
# Epoch 287/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8007 - loss: 0.4663
# Epoch 288/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7808 - loss: 0.4916
# Epoch 289/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7848 - loss: 0.4856
# Epoch 290/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8091 - loss: 0.4578
# Epoch 291/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7853 - loss: 0.5041
# Epoch 292/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7881 - loss: 0.4877
# Epoch 293/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8073 - loss: 0.4654
# Epoch 294/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7606 - loss: 0.5216
# Epoch 295/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7721 - loss: 0.4781
# Epoch 296/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7659 - loss: 0.4920
# Epoch 297/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7676 - loss: 0.4723
# Epoch 298/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7954 - loss: 0.4548
# Epoch 299/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7536 - loss: 0.5136
# Epoch 300/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7748 - loss: 0.4825

# %%
# Mostramos los pesos del modelo
model.get_weights()
# Out:
# [array([[-0.00242325, -0.0183143 , -0.4887275 , -0.46166795,  0.3103312 ,
#           0.2522838 ,  0.0263361 ,  0.62657684, -0.3367006 , -0.04288975,
#           0.06319059,  0.4066575 ],
#         [ 0.04018947, -0.5278664 , -0.34386954, -0.2400217 , -0.43695843,
#           0.00179279,  0.08861619,  0.09792376,  0.5062137 , -0.15692182,
#           0.36793792,  0.29885095],
#         [-0.38990724, -0.45974874,  0.5741538 , -0.28208295,  0.35016206,
#           0.08960352,  0.18881513,  0.48873988,  0.45305687, -0.14373574,
#          -0.20081954, -0.31625542],
#         [-0.0239481 ,  0.4314728 ,  0.1141386 ,  0.43806052, -0.3187165 ,
#          -0.11698921,  0.27361065,  0.02895802,  0.3638436 ,  0.2752528 ,
#           0.01534702,  0.1474327 ],
#         [ 0.5139339 ,  0.3170776 ,  0.10958568, -0.00110984,  0.338173  ,
#           0.33208904,  0.34638834, -0.17041095, -0.3471183 ,  0.4052197 ,
#           0.45647165,  0.05691867],
#         [ 0.16152598, -0.01243993, -0.27722776, -0.11375743,  0.36718825,
#          -0.46626803, -0.6050985 , -0.37855536,  0.4851774 ,  0.43015862,
#          -0.41976234, -0.28713527],
#         [ 0.1589039 , -0.08040428,  0.31542337, -0.25021794,  0.30074447,
#          -0.4953441 , -0.04200459,  0.08267263, -0.68219393, -0.26485282,
#           0.13676947, -0.00582413],
#         [-0.24559368,  0.3461252 ,  0.4191859 , -0.10835201,  0.2824346 ,
#          -0.29744333, -0.47997501,  0.15142274,  0.09493573, -0.27019387,
#          -0.39545628, -0.16383706]], dtype=float32),
#  array([ 0.38479388, -0.20992044,  0.37553772,  0.        , -0.30370918,
#          0.39848638,  0.11831313, -0.21751419,  0.40991575, -0.26590624,
#         -0.3989939 , -0.29085144], dtype=float32),
#  array([[-0.16266927, -0.35946018,  0.12644047,  0.399193  ,  0.15954265,
#           0.45387363, -0.1810246 ,  0.48188743],
#         [ 0.17654778, -0.50458336,  0.5402397 ,  0.23323673, -0.31811622,
#           0.07542017,  0.01221405, -0.5175844 ],
#         [-0.14409742, -0.26141822, -0.19898075, -0.5715863 , -0.31072256,
#          -0.0142354 ,  0.10159303,  0.01682146],
#         [-0.16272882, -0.15940446, -0.11404875, -0.38230577,  0.25763386,
#          -0.50868666, -0.5441327 ,  0.30497944],
#         [ 0.34350932,  0.38891074, -0.06756127, -0.40546736,  0.3734984 ,
#           0.17492218, -0.20603468,  0.45348236],
#         [ 0.00763394, -0.11525629,  0.09357584, -0.14148422, -0.4732742 ,
#           0.33730432,  0.34057623,  0.3760543 ],
#         [-0.2616193 , -0.4495124 , -0.52030647,  0.33139783, -0.15397176,
#          -0.5362966 ,  0.53180975, -0.23495984],
#         [ 0.08102646, -0.29712367, -0.304443  , -0.3492216 , -0.41532612,
#           0.11553607, -0.12992653,  0.38030258],
#         [-0.15620635, -0.18453775, -0.07667181, -0.2956218 , -0.18566798,
#          -0.07830314,  0.12341908, -0.5345669 ],
#         [ 0.33952302,  0.48576635, -0.47496158,  0.06010236,  0.43761435,
#           0.06567486,  0.18205151,  0.20177937],
#         [ 0.46321344,  0.17797494, -0.0569666 , -0.4403855 , -0.3383546 ,
#           0.19138964, -0.390298  , -0.03353915],
#         [ 0.33935574,  0.19598974, -0.20701876, -0.37527338,  0.39409772,
#           0.40426332, -0.20250127, -0.42304918]], dtype=float32),
#  array([-0.44385314, -0.02571208,  0.        , -0.04126565, -0.01573641,
#          0.47023293,  0.38564223,  0.25487575], dtype=float32),
#  array([[ 0.67862076],
#         [ 0.6914193 ],
#         [ 0.00920564],
#         [-0.56872344],
#         [ 0.42242968],
#         [-0.5751768 ],
#         [-0.34582165],
#         [-0.05955152]], dtype=float32),
#  array([-0.40259477], dtype=float32)]

# %%
# Mostramos los bias del modelo
model.layers[0].get_weights()[1]
# Out:
# array([ 0.38479388, -0.20992044,  0.37553772,  0.        , -0.30370918,
#         0.39848638,  0.11831313, -0.21751419,  0.40991575, -0.26590624,
#        -0.3989939 , -0.29085144], dtype=float32)

# %%
# Mostrar la precisión del modelo con los datos de prueba
# El primer valor es la pérdida y el segundo la precisión del modelo con los datos de prueba
scores = model.evaluate(X_test, y_test)
scores
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7443 - loss: 0.5222
# [0.5341970324516296, 0.7229437232017517]

# %%
# Evaluación del modelo con los datos de entrenamiento
scores = model.evaluate(X_train, y_train, verbose=False)
print("Precisión en la fase de entrenamiento: %.2f%%" % (scores[1]*100))

# Evaluación del modelo con los datos de prueba
scores = model.evaluate(X_test, y_test, verbose=False)
print("Precisión en la fase de prueba: %.2f%%" % (scores[1]*100))
# Out:
# Precisión en la fase de entrenamiento: 78.40%
# Precisión en la fase de prueba: 75.76%

# %% [markdown]
# #### Entrenar con Early Stopping (para evitar el sobreajuste -overfitting-)

# %%
# Compilamos el modelo con el optimizador adam, la función de pérdida binary_crossentropy, y las metricas accuracy
model.compile(optimizer = 'sgd', loss = 'binary_crossentropy', metrics=['accuracy'])

# Definimos la función de parada temprana (early stopping) para evitar el sobreajuste del modelo y restaurar los mejores pesos
early_stopping = tf.keras.callbacks.EarlyStopping(patience=30, monitor='val_loss', restore_best_weights=True)

# Entrenamos el modelo con los datos de entrenamiento, especificando el número de épocas, el tamaño del batch y los datos de validación
history = model.fit(X_train, y_train, epochs=300, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.6492 - loss: 0.6468 - val_accuracy: 0.6667 - val_loss: 0.6338
# Epoch 2/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6283 - loss: 0.6619 - val_accuracy: 0.6667 - val_loss: 0.6328
# Epoch 3/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6475 - loss: 0.6506 - val_accuracy: 0.6710 - val_loss: 0.6337
# Epoch 4/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6707 - loss: 0.6305 - val_accuracy: 0.6667 - val_loss: 0.6329
# Epoch 5/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6492 - loss: 0.6499 - val_accuracy: 0.6753 - val_loss: 0.6354
# Epoch 6/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6279 - loss: 0.6595 - val_accuracy: 0.6667 - val_loss: 0.6338
# Epoch 7/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6408 - loss: 0.6471 - val_accuracy: 0.6753 - val_loss: 0.6353
# Epoch 8/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6365 - loss: 0.6561 - val_accuracy: 0.6710 - val_loss: 0.6333
# Epoch 9/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6283 - loss: 0.6567 - val_accuracy: 0.6710 - val_loss: 0.6337
# Epoch 10/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6602 - loss: 0.6377 - val_accuracy: 0.6753 - val_loss: 0.6347
# Epoch 11/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6619 - loss: 0.6376 - val_accuracy: 0.6710 - val_loss: 0.6333
# Epoch 12/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6248 - loss: 0.6602 - val_accuracy: 0.6710 - val_loss: 0.6335
# Epoch 13/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6391 - loss: 0.6485 - val_accuracy: 0.6710 - val_loss: 0.6338
# Epoch 14/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6435 - loss: 0.6504 - val_accuracy: 0.6710 - val_loss: 0.6344
# Epoch 15/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6515 - loss: 0.6462 - val_accuracy: 0.6667 - val_loss: 0.6331
# Epoch 16/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6470 - loss: 0.6513 - val_accuracy: 0.6753 - val_loss: 0.6350
# Epoch 17/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6329 - loss: 0.6572 - val_accuracy: 0.6667 - val_loss: 0.6341
# Epoch 18/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6505 - loss: 0.6467 - val_accuracy: 0.6710 - val_loss: 0.6338
# Epoch 19/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6492 - loss: 0.6462 - val_accuracy: 0.6710 - val_loss: 0.6334
# Epoch 20/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6298 - loss: 0.6590 - val_accuracy: 0.6710 - val_loss: 0.6338
# Epoch 21/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6531 - loss: 0.6428 - val_accuracy: 0.6667 - val_loss: 0.6334
# Epoch 22/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6558 - loss: 0.6443 - val_accuracy: 0.6667 - val_loss: 0.6333
# Epoch 23/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6426 - loss: 0.6538 - val_accuracy: 0.6667 - val_loss: 0.6333
# Epoch 24/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6379 - loss: 0.6543 - val_accuracy: 0.6710 - val_loss: 0.6335
# Epoch 25/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6607 - loss: 0.6406 - val_accuracy: 0.6710 - val_loss: 0.6340
# Epoch 26/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6588 - loss: 0.6408 - val_accuracy: 0.6667 - val_loss: 0.6343
# Epoch 27/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6194 - loss: 0.6664 - val_accuracy: 0.6710 - val_loss: 0.6346
# Epoch 28/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6157 - loss: 0.6685 - val_accuracy: 0.6667 - val_loss: 0.6333
# Epoch 29/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6476 - loss: 0.6462 - val_accuracy: 0.6710 - val_loss: 0.6338
# Epoch 30/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6685 - loss: 0.6300 - val_accuracy: 0.6667 - val_loss: 0.6343
# Epoch 31/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6545 - loss: 0.6448 - val_accuracy: 0.6710 - val_loss: 0.6339
# Epoch 32/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6327 - loss: 0.6540 - val_accuracy: 0.6710 - val_loss: 0.6340

# %% [markdown]
# ### Evaluación del modelo

# %% [markdown]
# #### Evaluación de la precisión del modelo
#
# Evaluamos el rendimiento de un modelo de red neuronal en Keras tanto en los datos de entrenamiento como en los datos de prueba e imprimos la precisión de la clasificación en ambos conjuntos de datos.
#
# - `scores = model.evaluate(X_train, y_train, verbose=False)`: Esta línea está evaluando el modelo en los datos de entrenamiento. `model.evaluate` devuelve la pérdida del modelo y las métricas en los datos proporcionados.
#
#     En este caso, `scores[0]` sería la pérdida y `scores[1]` sería la precisión, ya que se especificó `metrics=['accuracy']` durante la compilación del modelo.
#
# - `print("Precisión en la fase de entrenamiento: %.2f%%" % (scores[1]*100))`: Esta línea está imprimiendo la precisión del modelo en los datos de entrenamiento representado en una cadena de formato. El `%` indica un punto de inserción para un valor. El `.2f` especifica un número de punto flotante con dos decimales. El `%%` se utiliza para imprimir un solo signo de porcentaje.
#
# - `scores = model.evaluate(X_test, y_test, verbose=False)`: Esta línea está evaluando el modelo en los datos de prueba.
#
# - `print("Precisión en la fase de prueba: %.2f%%" % (scores[1]*100))`: Esta línea está imprimiendo la precisión del modelo en los datos de prueba.

# %%
# Evaluación del modelo con los datos de entrenamiento
scores = model.evaluate(X_train, y_train, verbose=False)
print("Precisión en la fase de entrenamiento: %.2f%%" % (scores[1]*100))

# Evaluación del modelo con los datos de prueba
scores = model.evaluate(X_test, y_test, verbose=False)
print("Precisión en la fase de prueba: %.2f%%" % (scores[1]*100))
# Out:
# Precisión en la fase de entrenamiento: 64.25%
# Precisión en la fase de prueba: 66.67%

# %% [markdown]
# #### Usamos el modelo para hacer predicciones

# %% [markdown]
# Seleccionamos una fila específica de un DataFrame de pandas para realizar una predicción.
#
# - `iloc[9]` selecciona la décima fila del DataFrame `X_test` (la indexación en Python comienza en 0), y la asigna a la variable `persona_de_prueba`.

# %%
# Seleccionamos una persona de la base de datos de prueba para realizar una predicción
persona_de_prueba = X_test.iloc[9]
persona_de_prueba
# Out:
# pregnancies     10.000000
# glucose         90.000000
# diastolic       85.000000
# triceps         32.000000
# insulin        155.548223
# bmi             34.900000
# dpf              0.825000
# age             56.000000
# Name: 542, dtype: float64

# %% [markdown]
# Utilizamos el modelo de la red neuronal entrenada para hacer una predicción basada en los datos de una "persona de prueba".
#
# - `persona_de_prueba.values` convierte la fila del DataFrame de pandas en un array de numpy. `reshape(1,8)` cambia la forma del array a un array bidimensional con 1 fila y 8 columnas. Esto se hace porque el método `predict` de Keras espera un array bidimensional (es decir, un array de arrays), donde cada sub-array es un conjunto de características para hacer una predicción.
#
# - `prediccion = model.predict(...)`: Esta línea utiliza el método `predict` del modelo para hacer una predicción basada en las características de la "persona de prueba". La predicción se asigna a la variable `prediccion`.

# %%
# Hacemos una predicción con el modelo entrenado
prediccion = model.predict(persona_de_prueba.values.reshape(1,8))
prediccion
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step
# array([[0.3260981]], dtype=float32)

# %% [markdown]
# Comparamos la predicción de un modelo de aprendizaje automático con los datos reales para una "persona de prueba".
#
# - `if prediccion >= 0.5:`: Aquí, `prediccion` es la salida de un modelo de aprendizaje automático. Si la salida es mayor o igual a 0.5, se interpreta como una predicción de que la persona tiene diabetes.
#
# - `print('Según la predicción de la red neuronal: La persona tiene diabetes')`: Esta línea se ejecuta si la condición del `if` es verdadera, es decir, si la predicción es mayor o igual a 0.5.
#
# - `else:`: Esta parte del código se ejecuta si la condición del `if` es falsa, es decir, si la predicción es menor a 0.5.
#
# - `print('Según la predicción de la red neuronal: La persona no tiene diabetes')`: Esta línea se ejecuta si la condición del `if` es falsa.
#
# - `if y_test.iloc[9] == 1:`: Aquí, `y_test` es un DataFrame de pandas que contiene los datos reales. `y_test.iloc[9]` selecciona la décima fila del DataFrame. Si el valor en esta fila es 1, se interpreta como que la persona tiene diabetes.
#
# - `print('Según la base de datos de prueba: La persona tiene diabetes')`: Esta línea se ejecuta si la condición del `if` es verdadera, es decir, si el valor en la décima fila de `y_test` es 1.
#
# - `else:`: Esta parte del código se ejecuta si la condición del `if` es falsa, es decir, si el valor en la décima fila de `y_test` no es 1.
#
# - `print('Según la base de datos de prueba: La persona no tiene diabetes')`: Esta línea se ejecuta si la condición del `if` es falsa.

# %%
# Comprobamos si la persona tiene diabetes o no según la predicción
if prediccion >= 0.5:
    print('Según la predicción de la red neuronal: La persona tiene diabetes')
else:
    print('Según la predicción de la red neuronal: La persona no tiene diabetes')
    
# Comprobamos si la persona tiene diabetes o no según la base de datos
if y_test.iloc[9] == 1:
    print('Según la base de datos de prueba: La persona tiene diabetes')
else:
    print('Según la base de datos de prueba: La persona no tiene diabetes')
# Out:
# Según la predicción de la red neuronal: La persona no tiene diabetes
# Según la base de datos de prueba: La persona tiene diabetes

# %% [markdown]
# #### Guardamos el modelo para usarlo en producción

# %%
# Guardamos el modelo en un archivo
model.save('modelo_diabetes.keras')

# %%
# Cargamos el modelo desde el archivo
from tensorflow.keras.models import load_model
modelo_cargado = load_model('modelo_diabetes.keras')

# %%
# Hacemos una predicción con el modelo cargado
prediccion_modelo_cargado = modelo_cargado.predict(persona_de_prueba.values.reshape(1,8))

# Comprobamos si la persona tiene diabetes o no según la predicción del modelo cargado
if prediccion_modelo_cargado >= 0.5:
    print('Según la predicción del modelo cargado: La persona tiene diabetes')
else:
    print('Según la predicción del modelo cargado: La persona no tiene diabetes')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Según la predicción del modelo cargado: La persona no tiene diabetes

# %% [markdown]
# ## **Actividad:** Optimización de la Arquitectura de la Red Neuronal Artificial
#
# #### Objetivo
# Trabajar en grupos de 2 para optimizar la arquitectura de una red neuronal utilizando técnicas de búsqueda de hiperparámetros. El objetivo es encontrar los mejores valores para el número de capas y neuronas en cada capa para mejorar el rendimiento del modelo en la predicción de diabetes.
#
# #### Instrucciones
#
# 1. **Formar Grupos**: Formar grupos de 1 o 2 estudiantes.
#
# 2. **Preparar el Entorno**:
#     - Asegúrate de tener instaladas las siguientes librerías:
#       ```python
#       !pip install tensorflow keras scikit-learn
#       ```
#
# 3. **Definir el Modelo**:
#     - Crear una función que defina el modelo de la red neuronal con parámetros para el **número de capas** y **neuronas en cada capa**.
#     - Justificar la selcción de la función de activación de acuerdo a las lecturas realizadas en clase (50%).
#
# 4. **Implementar la Búsqueda de Hiperparámetros**:
#     - Utilizar `GridSearchCV` de `scikit-learn`, `Keras Tuner`, o `Optuna` para realizar la búsqueda de los mejores hiperparámetros (50%).
#
# 5. **Evaluar el Modelo**:
#     - Evaluar el modelo con los mejores hiperparámetros encontrados y reportar los resultados. Responder lo siguiente:

# %% [markdown]
# 1. ¿Qué búsqueda de parámetros usaste?
# 2. ¿Qué parámetros buscaste?
# 3. ¿Cómo se diferencian las métricas de tu red neuronal optimizada en relación con la red neuronal sin optimizar?
# 4. ¿Qué más probarías si tuvieras más tiempo?
