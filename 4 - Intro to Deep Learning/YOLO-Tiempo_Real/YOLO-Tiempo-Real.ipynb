# %% [markdown]
# Author:
# Manuel Eugenio Morocho Cayamcela, PhD

# %% [markdown]
# # YOLO en Tiempo Real: Detección de Objetos
#
# En este cuaderno de Jupyter exploraremos la tarea de la detección de objetos en tiempo real utilizando YOLO (You Only Look Once), una técnica avanzada de visión por computadora.
#
# Aprenderemos a utilizar YOLO para identificar y localizar diversos objetos en imágenes y secuencias de video. Esta habilidad es esencial en una amplia gama de aplicaciones, desde la conducción autónoma hasta la vigilancia de seguridad, y representa uno de los avances más emocionantes en el campo de la inteligencia artificial y la visión por computadora.
#
# A lo largo de este tutorial, explorarás conceptos clave como:
#
# - Detección de objetos en tiempo real.
# - Configuración de modelos YOLO pre-entrenados.
# - Interpretación de resultados de detección.
# - Aplicaciones prácticas de la detección de objetos.

# %% [markdown]
# Utilizaremos el comando `!pip` para instalar dos paquetes de Python: `opencv-python` y `ultralytics`.
#
# - `opencv-python`: Es un paquete para tareas de visión por computador en Python. Proporciona una variedad de funciones para el procesamiento de imágenes y videos, incluyendo detección de objetos, manipulación de imágenes y extracción de características.
#
# - `ultralytics`: Es un paquete construido sobre PyTorch, que se enfoca principalmente en tareas de visión por computadora como detección de objetos y clasificación de imágenes. Proporciona interfaces fáciles de usar para entrenar y evaluar modelos de aprendizaje profundo para estas tareas.
#
# Al ejecutar este comando, estás instalando estos paquetes en tu entorno de Python para que puedas usarlos en tu código.

# %%
# Instalamos las librerías necesarias
# %pip install opencv-python ultralytics

# %% [markdown]
# Importamos las siguientes bibliotecas en Python:
#
# 1. `ultralytics`: Esta es una biblioteca que proporciona una interfaz para usar modelos de detección de objetos YOLO (You Only Look Once). Permite entrenar, evaluar y utilizar modelos de detección de objetos de manera eficiente.
#
# 2. `cv2` (OpenCV): Esta es una biblioteca popular para el procesamiento de imágenes y videos en Python. Proporciona una amplia gama de funciones para trabajar con imágenes y videos, incluyendo cargar imágenes, realizar operaciones de procesamiento de imágenes, y mostrar imágenes en una ventana, entre otros.
#
# 3. `math`: Este es un módulo estándar de Python que proporciona funciones matemáticas comunes, como funciones trigonométricas, logarítmicas y aritméticas.

# %%
# Importamos las librerías necesarias
from ultralytics import YOLO
import cv2
import math

# %% [markdown]
# Para este tutorial, usaremos un modelo de YOLO preentrenado en una base de datos que contiene imagenes con sus respectivas cordenadas de cuadros delimitadores y etiquetas por cada objeto. La base de datos con la que el modelo fue preentrenado es COCO de Microsoft.

# %%
# Cargamos el modelo YOLO pre-entrenado en COCO dataset
model = YOLO("yolo-Weights/yolov8n.pt")

# %%
# Revisamos las clases que puede detectar el modelo
model.names
# Out:
# {0: 'person',
#  1: 'bicycle',
#  2: 'car',
#  3: 'motorcycle',
#  4: 'airplane',
#  5: 'bus',
#  6: 'train',
#  7: 'truck',
#  8: 'boat',
#  9: 'traffic light',
#  10: 'fire hydrant',
#  11: 'stop sign',
#  12: 'parking meter',
#  13: 'bench',
#  14: 'bird',
#  15: 'cat',
#  16: 'dog',
#  17: 'horse',
#  18: 'sheep',
#  19: 'cow',
#  20: 'elephant',
#  21: 'bear',
#  22: 'zebra',
#  23: 'giraffe',
#  24: 'backpack',
#  25: 'umbrella',
#  26: 'handbag',
#  27: 'tie',
#  28: 'suitcase',
#  29: 'frisbee',
#  30: 'skis',
#  31: 'snowboard',
#  32: 'sports ball',
#  33: 'kite',
#  34: 'baseball bat',
#  35: 'baseball glove',
#  36: 'skateboard',
#  37: 'surfboard',
#  38: 'tennis racket',
#  39: 'bottle',
#  40: 'wine glass',
#  41: 'cup',
#  42: 'fork',
#  43: 'knife',
#  44: 'spoon',
#  45: 'bowl',
#  46: 'banana',
#  47: 'apple',
#  48: 'sandwich',
#  49: 'orange',
#  50: 'broccoli',
#  51: 'carrot',
#  52: 'hot dog',
#  53: 'pizza',
#  54: 'donut',
#  55: 'cake',
#  56: 'chair',
#  57: 'couch',
#  58: 'potted plant',
#  59: 'bed',
#  60: 'dining table',
#  61: 'toilet',
#  62: 'tv',
#  63: 'laptop',
#  64: 'mouse',
#  65: 'remote',
#  66: 'keyboard',
#  67: 'cell phone',
#  68: 'microwave',
#  69: 'oven',
#  70: 'toaster',
#  71: 'sink',
#  72: 'refrigerator',
#  73: 'book',
#  74: 'clock',
#  75: 'vase',
#  76: 'scissors',
#  77: 'teddy bear',
#  78: 'hair drier',
#  79: 'toothbrush'}

# %%
# Definimos una lista de nombres con todas las clases para identificar objetos detectados
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ] # Aquí se enumeran todas las clases

# %%
# Configuramos la captura de video desde la cámara
captura = cv2.VideoCapture(0) # Se abre la cámara por defecto

# Establecemos el ancho y alto de la imagen
captura.set(cv2.CAP_PROP_FRAME_WIDTH, 640) # Ancho de la imagen
captura.set(cv2.CAP_PROP_FRAME_HEIGHT, 480) # Alto de la imagen

# Iniciamos un bucle para procesar los fotogramas de la cámara
while True:
    success, img = captura.read() # Capturamos un fotograma

    # Realizamos la detección de objetos en la imagen capturada (usando el modelo de YOLO pre-entrenado que cargamos anteriormente)
    results = model(img, stream=True)

   # Procesamos los resultados de la detección
    for r in results:
        boxes = r.boxes

        # Iteramos sobre las cajas delimitadoras detectadas
        for box in boxes:
            # Obtenemos las coordenadas de la caja delimitadora
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # Convertimos a valores enteros

            # Dibujamos la caja delimitadora en la imagen
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 1)

            # Obtenemos la confianza de la detección
            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->",confidence)

            # Obtenemos el nombre de la clase detectada
            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            # Mostramos el nombre de la clase junto a la caja delimitadora
            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0) # Color: Azul (formato BGR)
            thickness = 1
            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    # Mostramos la imagen con las detecciones
    cv2.imshow('Webcam', img)

    # Salimos del bucle si se presiona la tecla 'q'
    #if cv2.waitKey(1) == ord('q'):
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

# Liberamos la cámara y cerramos todas las ventanas
captura.release()
cv2.destroyAllWindows()
# Out:
# 2024-09-19 17:16:51.447 Python[3274:119577] WARNING: AVCaptureDeviceTypeExternal is deprecated for Continuity Cameras. Please use AVCaptureDeviceTypeContinuityCamera and add NSCameraUseContinuityCameraDeviceType to your Info.plist.
# 0: 480x640 1 person, 110.5ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 6.4ms preprocess, 110.5ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 112.3ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 3.5ms preprocess, 112.3ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 110.1ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 3.8ms preprocess, 110.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 447.5ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 62.7ms preprocess, 447.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 93.3ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 1.9ms preprocess, 93.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 127.3ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.6ms preprocess, 127.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# 2024-09-19 17:17:01.063 Python[3274:119577] +[IMKClient subclass]: chose IMKClient_Legacy
# 2024-09-19 17:17:01.064 Python[3274:119577] +[IMKInputSession subclass]: chose IMKInputSession_Legacy
# 0: 480x640 1 person, 107.4ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.0ms preprocess, 107.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 249.8ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.4ms preprocess, 249.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 142.0ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.4ms preprocess, 142.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 115.7ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.4ms preprocess, 115.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 87.5ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.2ms preprocess, 87.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 84.7ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.3ms preprocess, 84.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 86.3ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.3ms preprocess, 86.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 87.7ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.2ms preprocess, 87.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 84.7ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.3ms preprocess, 84.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 86.8ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.2ms preprocess, 86.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 86.4ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.6ms preprocess, 86.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 95.1ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.2ms preprocess, 95.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.9ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.3ms preprocess, 121.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 85.6ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.9ms preprocess, 85.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 83.4ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 1.3ms preprocess, 83.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 87.8ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.3ms preprocess, 87.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 94.7ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.4ms preprocess, 94.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 79.2ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 1.3ms preprocess, 79.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 77.7ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 1.3ms preprocess, 77.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 76.5ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 1.3ms preprocess, 76.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 76.4ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 1.3ms preprocess, 76.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 76.6ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 1.4ms preprocess, 76.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 75.3ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 1.3ms preprocess, 75.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.2ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 1.3ms preprocess, 125.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 101.4ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 1.6ms preprocess, 101.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 84.0ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 1.2ms preprocess, 84.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 88.7ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 1.3ms preprocess, 88.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 133.7ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.7ms preprocess, 133.7ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 86.8ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.8ms preprocess, 86.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 85.5ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.5ms preprocess, 85.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 91.5ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.5ms preprocess, 91.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 88.0ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.2ms preprocess, 88.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 78.9ms
# Confidence ---> 0.75
# Class name --> person
# Speed: 1.3ms preprocess, 78.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 81.9ms
# Confidence ---> 0.75
# Class name --> person
# Speed: 1.4ms preprocess, 81.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 1 cell phone, 79.4ms
# Confidence ---> 0.77
# Class name --> cell phone
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.31
# Class name --> remote
# Speed: 1.3ms preprocess, 79.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 1 cell phone, 78.7ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.74
# Class name --> cell phone
# Confidence ---> 0.31
# Class name --> remote
# Speed: 1.2ms preprocess, 78.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 79.2ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.74
# Class name --> cell phone
# Speed: 1.2ms preprocess, 79.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 86.3ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.78
# Class name --> cell phone
# Speed: 3.5ms preprocess, 86.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 1 cell phone, 78.4ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.75
# Class name --> cell phone
# Confidence ---> 0.34
# Class name --> remote
# Speed: 1.3ms preprocess, 78.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 1 cell phone, 81.5ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.71
# Class name --> cell phone
# Confidence ---> 0.32
# Class name --> remote
# Speed: 1.4ms preprocess, 81.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 79.9ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.7
# Class name --> cell phone
# Speed: 1.4ms preprocess, 79.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 1 cell phone, 80.3ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.54
# Class name --> cell phone
# Confidence ---> 0.3
# Class name --> remote
# Speed: 1.3ms preprocess, 80.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 135.6ms
# Confidence ---> 0.78
# Class name --> cell phone
# Confidence ---> 0.76
# Class name --> person
# Speed: 2.1ms preprocess, 135.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 120.8ms
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Speed: 2.4ms preprocess, 120.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 100.2ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.5
# Class name --> person
# Speed: 1.4ms preprocess, 100.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 94.5ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.5ms preprocess, 94.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 91.6ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.6ms preprocess, 91.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 87.1ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 1.6ms preprocess, 87.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 82.0ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 1.4ms preprocess, 82.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 80.3ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 1.3ms preprocess, 80.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 81.7ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 1.3ms preprocess, 81.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 82.8ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 1.4ms preprocess, 82.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 85.5ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 1.5ms preprocess, 85.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 84.8ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 1.7ms preprocess, 84.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 82.9ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 1.5ms preprocess, 82.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 86.0ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 1.3ms preprocess, 86.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 85.2ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 1.6ms preprocess, 85.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 132.0ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.2ms preprocess, 132.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.2ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 2.7ms preprocess, 124.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 98.8ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.7ms preprocess, 98.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 99.1ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.9ms preprocess, 99.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 102.8ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.7ms preprocess, 102.8ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 87.7ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.6ms preprocess, 87.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 89.7ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.7ms preprocess, 89.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 91.8ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.8ms preprocess, 91.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 90.0ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 2.3ms preprocess, 90.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 90.6ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.7ms preprocess, 90.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 146.1ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.7ms preprocess, 146.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 86.5ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.6ms preprocess, 86.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 84.1ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.5ms preprocess, 84.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 84.1ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 1.6ms preprocess, 84.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 113.6ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.4ms preprocess, 113.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 133.7ms
# Confidence ---> 0.67
# Class name --> person
# Speed: 2.0ms preprocess, 133.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 95.0ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Speed: 2.0ms preprocess, 95.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tennis racket, 95.6ms
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.26
# Class name --> tennis racket
# Speed: 1.8ms preprocess, 95.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 tennis racket, 97.6ms
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.67
# Class name --> tennis racket
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Speed: 1.9ms preprocess, 97.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 92.4ms
# Confidence ---> 0.68
# Class name --> person
# Speed: 1.9ms preprocess, 92.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 83.7ms
# Confidence ---> 0.67
# Class name --> person
# Speed: 1.5ms preprocess, 83.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tennis racket, 83.1ms
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.3
# Class name --> tennis racket
# Speed: 1.7ms preprocess, 83.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 84.8ms
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Speed: 1.5ms preprocess, 84.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 104.5ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.6ms preprocess, 104.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 85.1ms
# Confidence ---> 0.77
# Class name --> person
# Speed: 1.6ms preprocess, 85.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 83.8ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 1.6ms preprocess, 83.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 book, 84.4ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.33
# Class name --> book
# Speed: 1.6ms preprocess, 84.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 83.5ms
# Confidence ---> 0.79
# Class name --> person
# Speed: 1.7ms preprocess, 83.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 83.5ms
# Confidence ---> 0.68
# Class name --> person
# Speed: 1.6ms preprocess, 83.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 106.8ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.49
# Class name --> chair
# Speed: 1.6ms preprocess, 106.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tennis racket, 1 chair, 132.8ms
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.54
# Class name --> chair
# Confidence ---> 0.28
# Class name --> tennis racket
# Speed: 2.0ms preprocess, 132.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 97.4ms
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.4
# Class name --> chair
# Confidence ---> 0.33
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 2.3ms preprocess, 97.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 95.5ms
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Speed: 1.8ms preprocess, 95.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 169.3ms
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Speed: 2.1ms preprocess, 169.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 87.8ms
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Speed: 1.7ms preprocess, 87.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 84.0ms
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Speed: 1.7ms preprocess, 84.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 84.3ms
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Speed: 1.5ms preprocess, 84.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 85.4ms
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 1.8ms preprocess, 85.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 82.7ms
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.34
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Speed: 1.5ms preprocess, 82.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 83.4ms
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 1.5ms preprocess, 83.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 baseball bat, 94.4ms
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.34
# Class name --> person
# Confidence ---> 0.26
# Class name --> baseball bat
# Speed: 1.5ms preprocess, 94.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 83.8ms
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Speed: 1.5ms preprocess, 83.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bed, 84.1ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.33
# Class name --> bed
# Speed: 1.4ms preprocess, 84.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 86.7ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 1.4ms preprocess, 86.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 133.7ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 2.3ms preprocess, 133.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 140.3ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 2.6ms preprocess, 140.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 91.1ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Speed: 1.6ms preprocess, 91.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 book, 90.7ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.36
# Class name --> book
# Speed: 1.7ms preprocess, 90.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.7ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.8ms preprocess, 96.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 86.8ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.5ms preprocess, 86.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 93.6ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.5ms preprocess, 93.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 83.5ms
# Confidence ---> 0.83
# Class name --> person
# Speed: 1.4ms preprocess, 83.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 86.5ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.4ms preprocess, 86.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 82.3ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.5ms preprocess, 82.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 84.2ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.6ms preprocess, 84.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 82.1ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.5ms preprocess, 82.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 134.2ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.4ms preprocess, 134.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 84.3ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 1.5ms preprocess, 84.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 84.3ms
# Confidence ---> 0.73
# Class name --> person
# Speed: 1.4ms preprocess, 84.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 131.5ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.7ms preprocess, 131.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 book, 112.0ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.26
# Class name --> cell phone
# Speed: 3.1ms preprocess, 112.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 book, 90.9ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.32
# Class name --> book
# Speed: 1.5ms preprocess, 90.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 book, 92.0ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.46
# Class name --> book
# Speed: 1.5ms preprocess, 92.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 book, 90.7ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.48
# Class name --> book
# Speed: 1.5ms preprocess, 90.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 book, 85.1ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.43
# Class name --> book
# Speed: 1.5ms preprocess, 85.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 book, 88.5ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.45
# Class name --> book
# Speed: 1.3ms preprocess, 88.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 book, 84.5ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.58
# Class name --> book
# Speed: 1.4ms preprocess, 84.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 book, 83.2ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.51
# Class name --> book
# Speed: 1.5ms preprocess, 83.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 book, 83.1ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.41
# Class name --> book
# Speed: 1.4ms preprocess, 83.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 book, 82.7ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.41
# Class name --> book
# Speed: 1.4ms preprocess, 82.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 book, 86.2ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.36
# Class name --> book
# Speed: 1.4ms preprocess, 86.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 book, 83.2ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.5
# Class name --> book
# Speed: 1.4ms preprocess, 83.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 83.1ms
# Confidence ---> 0.72
# Class name --> person
# Speed: 1.3ms preprocess, 83.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 83.3ms
# Confidence ---> 0.8
# Class name --> person
# Speed: 1.3ms preprocess, 83.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 138.1ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 1.6ms preprocess, 138.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 114.9ms
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Speed: 2.1ms preprocess, 114.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 91.2ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.4ms preprocess, 91.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 94.0ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.6ms preprocess, 94.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 90.9ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.6ms preprocess, 90.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 107.0ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 32.4ms preprocess, 107.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 83.7ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.4ms preprocess, 83.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 82.8ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.3ms preprocess, 82.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 95.9ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.4ms preprocess, 95.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 85.5ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 2.0ms preprocess, 85.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 82.6ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.5ms preprocess, 82.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 85.6ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.7ms preprocess, 85.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 86.5ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.3ms preprocess, 86.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 83.7ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.4ms preprocess, 83.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 85.0ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.4ms preprocess, 85.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 132.5ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.7ms preprocess, 132.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 130.8ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 2.0ms preprocess, 130.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 101.1ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.8ms preprocess, 101.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 108.3ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 2.4ms preprocess, 108.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 114.9ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.6ms preprocess, 114.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 91.1ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.6ms preprocess, 91.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 84.6ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.6ms preprocess, 84.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 82.9ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.3ms preprocess, 82.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 84.5ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.4ms preprocess, 84.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 85.7ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.4ms preprocess, 85.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 82.8ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.3ms preprocess, 82.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 83.7ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.4ms preprocess, 83.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 84.9ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.5ms preprocess, 84.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 95.6ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.6ms preprocess, 95.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 99.4ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.4ms preprocess, 99.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 150.6ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 3.2ms preprocess, 150.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 94.8ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.6ms preprocess, 94.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 98.7ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.5ms preprocess, 98.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 100.9ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.3ms preprocess, 100.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 94.4ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.7ms preprocess, 94.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tie, 87.7ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Confidence ---> 0.27
# Class name --> tie
# Speed: 1.9ms preprocess, 87.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 83.7ms
# Confidence ---> 0.77
# Class name --> person
# Speed: 1.3ms preprocess, 83.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 82.6ms
# Confidence ---> 0.68
# Class name --> person
# Speed: 1.4ms preprocess, 82.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tie, 87.0ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.26
# Class name --> tie
# Speed: 2.0ms preprocess, 87.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 83.4ms
# Confidence ---> 0.77
# Class name --> person
# Speed: 1.4ms preprocess, 83.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 84.3ms
# Confidence ---> 0.79
# Class name --> person
# Speed: 1.4ms preprocess, 84.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 86.1ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 1.3ms preprocess, 86.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 82.4ms
# Confidence ---> 0.79
# Class name --> person
# Speed: 1.3ms preprocess, 82.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 88.2ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.4ms preprocess, 88.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 94.0ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 1.4ms preprocess, 94.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 143.0ms
# Confidence ---> 0.73
# Class name --> person
# Speed: 2.0ms preprocess, 143.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 97.1ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 2.9ms preprocess, 97.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 93.9ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.5ms preprocess, 93.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 92.6ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.7ms preprocess, 92.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 94.3ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.5ms preprocess, 94.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 84.9ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.5ms preprocess, 84.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 84.5ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.3ms preprocess, 84.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 82.7ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.4ms preprocess, 82.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 85.2ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.3ms preprocess, 85.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 83.7ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.3ms preprocess, 83.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 84.6ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.4ms preprocess, 84.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 80.9ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.4ms preprocess, 80.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 83.0ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.9ms preprocess, 83.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 83.3ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.4ms preprocess, 83.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 82.6ms
# Confidence ---> 0.71
# Class name --> person
# Speed: 1.5ms preprocess, 82.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 135.5ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.9ms preprocess, 135.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 175.2ms
# Confidence ---> 0.73
# Class name --> person
# Speed: 2.0ms preprocess, 175.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 92.9ms
# Confidence ---> 0.63
# Class name --> person
# Speed: 1.5ms preprocess, 92.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 95.9ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.5ms preprocess, 95.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 91.1ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 2.3ms preprocess, 91.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 93.5ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.5ms preprocess, 93.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 84.4ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.4ms preprocess, 84.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 83.4ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.4ms preprocess, 83.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 83.8ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.4ms preprocess, 83.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 85.9ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.5ms preprocess, 85.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tie, 84.5ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.29
# Class name --> tie
# Speed: 1.4ms preprocess, 84.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tie, 84.1ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.33
# Class name --> tie
# Speed: 1.5ms preprocess, 84.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 82.1ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.4ms preprocess, 82.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 88.9ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.5ms preprocess, 88.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 98.5ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.4ms preprocess, 98.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 154.3ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 2.5ms preprocess, 154.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 92.3ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 1.5ms preprocess, 92.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 93.9ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.5ms preprocess, 93.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 93.2ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.6ms preprocess, 93.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 147.0ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 1.5ms preprocess, 147.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 82.8ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.3ms preprocess, 82.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 82.5ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.6ms preprocess, 82.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 81.1ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.4ms preprocess, 81.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 87.7ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Speed: 1.5ms preprocess, 87.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 82.3ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Speed: 3.1ms preprocess, 82.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 bottle, 91.3ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.33
# Class name --> bottle
# Speed: 2.0ms preprocess, 91.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 93.4ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Speed: 1.6ms preprocess, 93.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 82.1ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Speed: 1.3ms preprocess, 82.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tie, 1 cell phone, 87.1ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.32
# Class name --> tie
# Confidence ---> 0.26
# Class name --> cell phone
# Speed: 2.1ms preprocess, 87.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 104.8ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.29
# Class name --> bottle
# Speed: 1.3ms preprocess, 104.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tie, 1 bottle, 130.6ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.37
# Class name --> tie
# Confidence ---> 0.27
# Class name --> bottle
# Speed: 3.4ms preprocess, 130.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tie, 1 bottle, 92.2ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.37
# Class name --> bottle
# Confidence ---> 0.33
# Class name --> tie
# Speed: 3.3ms preprocess, 92.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tie, 91.8ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.29
# Class name --> tie
# Speed: 1.6ms preprocess, 91.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tie, 1 bottle, 94.8ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.32
# Class name --> bottle
# Confidence ---> 0.29
# Class name --> tie
# Speed: 1.7ms preprocess, 94.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tie, 1 bottle, 97.8ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.3
# Class name --> bottle
# Confidence ---> 0.28
# Class name --> tie
# Speed: 1.9ms preprocess, 97.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 91.9ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.26
# Class name --> bottle
# Speed: 1.4ms preprocess, 91.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tie, 132.6ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.29
# Class name --> tie
# Speed: 1.7ms preprocess, 132.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tie, 1 bottle, 81.3ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.47
# Class name --> bottle
# Confidence ---> 0.27
# Class name --> tie
# Speed: 1.5ms preprocess, 81.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tie, 1 bottle, 84.0ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.42
# Class name --> bottle
# Confidence ---> 0.27
# Class name --> tie
# Speed: 1.7ms preprocess, 84.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tie, 1 bottle, 83.3ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.5
# Class name --> bottle
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.38
# Class name --> tie
# Speed: 1.5ms preprocess, 83.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tie, 83.7ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Confidence ---> 0.29
# Class name --> tie
# Speed: 1.5ms preprocess, 83.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tie, 83.5ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.28
# Class name --> tie
# Speed: 1.5ms preprocess, 83.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tie, 82.4ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.26
# Class name --> tie
# Speed: 1.4ms preprocess, 82.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 82.9ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.7ms preprocess, 82.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tie, 99.3ms
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.35
# Class name --> tie
# Speed: 1.5ms preprocess, 99.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 146.4ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 3.8ms preprocess, 146.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 94.0ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.1ms preprocess, 94.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 90.5ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.5ms preprocess, 90.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 90.5ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.6ms preprocess, 90.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 90.1ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 1.5ms preprocess, 90.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 84.0ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 1.4ms preprocess, 84.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 84.0ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 1.8ms preprocess, 84.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 82.7ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.4ms preprocess, 82.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 149.0ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.3ms preprocess, 149.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 83.0ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.5ms preprocess, 83.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 85.4ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.7ms preprocess, 85.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 83.2ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 1.6ms preprocess, 83.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 83.2ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 1.5ms preprocess, 83.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tie, 83.9ms
# Confidence ---> 0.96
# Class name --> person
# Confidence ---> 0.29
# Class name --> tie
# Speed: 1.6ms preprocess, 83.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 112.3ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 1.8ms preprocess, 112.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 146.3ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 2.2ms preprocess, 146.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 90.8ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 1.9ms preprocess, 90.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 92.3ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.8ms preprocess, 92.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 90.4ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.0ms preprocess, 90.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 115.0ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.1ms preprocess, 115.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tie, 90.3ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.33
# Class name --> tie
# Speed: 1.6ms preprocess, 90.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 89.3ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.8ms preprocess, 89.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 90.4ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.1ms preprocess, 90.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 89.2ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.4ms preprocess, 89.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 92.2ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.5ms preprocess, 92.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 150.4ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.4ms preprocess, 150.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 88.9ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.4ms preprocess, 88.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 89.8ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.1ms preprocess, 89.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tie, 91.6ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.29
# Class name --> tie
# Speed: 1.4ms preprocess, 91.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tie, 146.1ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.26
# Class name --> tie
# Speed: 2.7ms preprocess, 146.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# **Tarea: Aplicación de detección de objetos específicos con YOLO**
#
# Objetivo: Investiga cómo modificar el script de detección de objetos en tiempo real con YOLO para que solo detecte ciertas clases de objetos. Luego, darle una aplicación específica a esta detección.
#
# Instrucciones:
#
# 1. Elija un subconjunto de las 80 clases disponibles en YOLO que sean relevantes para una aplicación específica. Por ejemplo, si está creando una aplicación para ayudar a los conductores a detectar peatones y vehículos, podría elegir las clases 'persona', 'bicicleta', 'coche', 'moto', 'autobús' y 'camión'.
#
# 2. Modifique el script de detección de objetos en tiempo real para que solo detecte las clases que ha seleccionado. Para hacer esto, necesitará crear una lista de los índices de las clases que ha selecciono y luego agregar una condición en el bucle donde se procesan los resultados de la detección para solo procesar las detecciones que corresponden a las clases seleccionadas.
#
# 3. Pruebe su script modificado para asegurarse de que solo está detectando las clases que ha seleccionado.
#
# 4. Piense en una aplicación específica para su detección de objetos. ¿Cómo podría usar la información de las detecciones para ayudar al usuario? Por ejemplo, en la aplicación para conductores, podría alertar al usuario si detecta un peatón o un vehículo en una zona de peligro.
#
# 5. En clase, presente las clases que seleccionó, cómo modificó el script de detección de objetos, los resultados de sus pruebas, la aplicación específica que ha ideado para su detección de objetos, y cómo la aplicación serviría al usuario final u organización.
