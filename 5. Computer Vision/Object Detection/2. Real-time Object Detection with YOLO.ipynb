# %% [markdown]
# # **Tutorial:** Real-time Object Detection with YOLO

# %% [markdown]
# In this tutorial, you will learn how to use the YOLOv11 model with OpenCV to automatically detect and draw bounding boxes around objects in an image.

# %% [markdown]
# ### **Step 1: Install Required Packages**

# %% [markdown]
# Install the necessary packages including OpenCV and other dependencies:

# %%
# %pip install --upgrade ultralytics
# %pip install opencv-python
# %pip install matplotlib
# %pip install numpy==1.26.4 --force-reinstall
# Out:
# Requirement already satisfied: ultralytics in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (8.3.221)
# Collecting ultralytics
#   Downloading ultralytics-8.3.225-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from ultralytics) (2.2.6)
# Requirement already satisfied: matplotlib>=3.3.0 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from ultralytics) (3.10.7)
# Requirement already satisfied: opencv-python>=4.6.0 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from ultralytics) (12.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: torchvision>=0.9.0 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from ultralytics) (0.17.2)
# Requirement already satisfied: psutil in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from ultralytics) (7.1.1)
# Requirement already satisfied: polars in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from ultralytics) (1.34.0)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=3 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (2025.10.5)
# Requirement already satisfied: filelock in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: sympy in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (2025.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Requirement already satisfied: polars-runtime-32==1.34.0 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from polars->ultralytics) (1.34.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Downloading ultralytics-8.3.225-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 7.3 MB/s  0:00:00 eta 0:00:01
# Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Installing collected packages: ultralytics-thop, ultralytics
#   Attempting uninstall: ultralytics-thop
#     Found existing installation: ultralytics-thop 2.0.17
#     Uninstalling ultralytics-thop-2.0.17:
#       Successfully uninstalled ultralytics-thop-2.0.17
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.3.221
#     Uninstalling ultralytics-8.3.221:
#       Successfully uninstalled ultralytics-8.3.221
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [ultralytics] [ultralytics]
# Successfully installed ultralytics-8.3.225 ultralytics-thop-2.0.18
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: opencv-python in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from opencv-python) (2.2.6)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting numpy==1.26.4
#   Using cached numpy-1.26.4-cp311-cp311-macosx_10_9_x86_64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp311-cp311-macosx_10_9_x86_64.whl (20.6 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:
#       Successfully uninstalled numpy-2.2.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# ydata-profiling 4.17.0 requires matplotlib<=3.10,>=3.5, but you have matplotlib 3.10.7 which is incompatible.
# Successfully installed numpy-1.26.4
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Verify the installations:

# %%
# %pip show opencv-python ultralytics

# %% [markdown]
# ### **Step 2: Import Required Libraries**

# %% [markdown]
# Import the libraries you will use:

# %%
import numpy as np
import math
import cv2
from ultralytics import YOLO
from matplotlib import pyplot as plt

# %% [markdown]
# ### **Step 3: Load the YOLOv11 Model**

# %% [markdown]
# Load the pre-trained YOLOv11 model (automatically downloads if not available):

# %%
# Load a pretrained YOLO model version 11, nano (n) size
model = YOLO('yolo11n.pt')  # Using nano version for speed, other options: yolov11s.pt (small), yolov11m.pt (medium), yolov11l.pt (large), yolov11x.pt (extra large)

# %%
# Show class names the model can detect 
model.names
# Out:
# {0: 'person',
#  1: 'bicycle',
#  2: 'car',
#  3: 'motorcycle',
#  4: 'airplane',
#  5: 'bus',
#  6: 'train',
#  7: 'truck',
#  8: 'boat',
#  9: 'traffic light',
#  10: 'fire hydrant',
#  11: 'stop sign',
#  12: 'parking meter',
#  13: 'bench',
#  14: 'bird',
#  15: 'cat',
#  16: 'dog',
#  17: 'horse',
#  18: 'sheep',
#  19: 'cow',
#  20: 'elephant',
#  21: 'bear',
#  22: 'zebra',
#  23: 'giraffe',
#  24: 'backpack',
#  25: 'umbrella',
#  26: 'handbag',
#  27: 'tie',
#  28: 'suitcase',
#  29: 'frisbee',
#  30: 'skis',
#  31: 'snowboard',
#  32: 'sports ball',
#  33: 'kite',
#  34: 'baseball bat',
#  35: 'baseball glove',
#  36: 'skateboard',
#  37: 'surfboard',
#  38: 'tennis racket',
#  39: 'bottle',
#  40: 'wine glass',
#  41: 'cup',
#  42: 'fork',
#  43: 'knife',
#  44: 'spoon',
#  45: 'bowl',
#  46: 'banana',
#  47: 'apple',
#  48: 'sandwich',
#  49: 'orange',
#  50: 'broccoli',
#  51: 'carrot',
#  52: 'hot dog',
#  53: 'pizza',
#  54: 'donut',
#  55: 'cake',
#  56: 'chair',
#  57: 'couch',
#  58: 'potted plant',
#  59: 'bed',
#  60: 'dining table',
#  61: 'toilet',
#  62: 'tv',
#  63: 'laptop',
#  64: 'mouse',
#  65: 'remote',
#  66: 'keyboard',
#  67: 'cell phone',
#  68: 'microwave',
#  69: 'oven',
#  70: 'toaster',
#  71: 'sink',
#  72: 'refrigerator',
#  73: 'book',
#  74: 'clock',
#  75: 'vase',
#  76: 'scissors',
#  77: 'teddy bear',
#  78: 'hair drier',
#  79: 'toothbrush'}

# %% [markdown]
# ### **Step 4.1: Run YOLO on your webcam video (the simple way)**

# %%
# Run YOLO model on your webcam
results = model.predict(source=0, show=True, stream=True)  # source=0 uses the default webcam; use source=1 for an external camera, stream=True for real-time processing

# %% [markdown]
# ### **Step 4.2: Run YOLO on your webcam video (the complete way)**

# %%
# Configure video capture from the camera
capture = cv2.VideoCapture(0)  # Open the default camera

# Define class names (YOLO COCO dataset classes)
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"]

# Set the image width and height
capture.set(cv2.CAP_PROP_FRAME_WIDTH, 640)  # Image width
capture.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)  # Image height

# Start a loop to process camera frames
while True:
    success, img = capture.read()  # Capture a frame

    # Perform object detection on the captured image (using the pre-trained YOLO model we loaded earlier)
    results = model(img, stream=True)  # Stream generator to process detection results in real time

    # Process the detection results (we can have multiple objects detected in a single frame)
    for r in results:
        boxes = r.boxes

        # Iterate over the detected bounding boxes
        for box in boxes:
            # Get the bounding box coordinates in xyxy format
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)  # Convert to integer values

            # Draw the bounding box on the image
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 1)

            # Get the detection confidence (value between 0 and 1) and round to two decimal places
            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->", confidence)

            # Get the numeric identifier of the detected class name
            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            # Display the class name next to the bounding box
            org = [x1, y1]  # Coordinates of the top-left corner for the text
            font = cv2.FONT_HERSHEY_SIMPLEX # Font type
            fontScale = 1  # Font scale
            color = (255, 0, 0)  # Color: Blue (BGR format)
            thickness = 1  # Text line thickness
            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    # Display the image with a window name and the processed image with detections
    cv2.imshow('YOLO Detection', img)

    # Exit the loop if the 'q' key is pressed
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

# Release the camera and close all windows
capture.release()
cv2.destroyAllWindows()
# Out:
# 2025-11-06 20:45:43.201 Python[48155:6119402] WARNING: AVCaptureDeviceTypeExternal is deprecated for Continuity Cameras. Please use AVCaptureDeviceTypeContinuityCamera and add NSCameraUseContinuityCameraDeviceType to your Info.plist.
# 0: 480x640 1 bottle, 5 books, 332.7ms
# Confidence ---> 0.5
# Class name --> bottle
# Confidence ---> 0.46
# Class name --> book
# Confidence ---> 0.4
# Class name --> book
# Confidence ---> 0.39
# Class name --> book
# Confidence ---> 0.38
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Speed: 8.9ms preprocess, 332.7ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 1 laptop, 5 books, 256.7ms
# Confidence ---> 0.51
# Class name --> bottle
# Confidence ---> 0.41
# Class name --> book
# Confidence ---> 0.4
# Class name --> book
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Confidence ---> 0.26
# Class name --> laptop
# Speed: 12.0ms preprocess, 256.7ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 5 books, 522.7ms
# Confidence ---> 0.51
# Class name --> bottle
# Confidence ---> 0.48
# Class name --> book
# Confidence ---> 0.46
# Class name --> book
# Confidence ---> 0.38
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Speed: 44.9ms preprocess, 522.7ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 7 books, 148.4ms
# Confidence ---> 0.57
# Class name --> book
# Confidence ---> 0.44
# Class name --> book
# Confidence ---> 0.44
# Class name --> bottle
# Confidence ---> 0.38
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 1.7ms preprocess, 148.4ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 8 books, 279.7ms
# Confidence ---> 0.54
# Class name --> book
# Confidence ---> 0.42
# Class name --> bottle
# Confidence ---> 0.38
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 2.2ms preprocess, 279.7ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 6 books, 142.5ms
# Confidence ---> 0.5
# Class name --> book
# Confidence ---> 0.48
# Class name --> book
# Confidence ---> 0.37
# Class name --> book
# Confidence ---> 0.34
# Class name --> bottle
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 1.5ms preprocess, 142.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 5 books, 132.8ms
# Confidence ---> 0.52
# Class name --> book
# Confidence ---> 0.47
# Class name --> book
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.27
# Class name --> bottle
# Speed: 2.1ms preprocess, 132.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 7 books, 148.9ms
# Confidence ---> 0.49
# Class name --> book
# Confidence ---> 0.47
# Class name --> bottle
# Confidence ---> 0.42
# Class name --> book
# Confidence ---> 0.36
# Class name --> book
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 2.9ms preprocess, 148.9ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 123.7ms
# Confidence ---> 0.4
# Class name --> book
# Confidence ---> 0.39
# Class name --> book
# Confidence ---> 0.37
# Class name --> bottle
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Speed: 2.1ms preprocess, 123.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 6 books, 123.6ms
# Confidence ---> 0.5
# Class name --> book
# Confidence ---> 0.45
# Class name --> bottle
# Confidence ---> 0.43
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 3.8ms preprocess, 123.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 6 books, 107.9ms
# Confidence ---> 0.51
# Class name --> book
# Confidence ---> 0.45
# Class name --> book
# Confidence ---> 0.38
# Class name --> bottle
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 2.3ms preprocess, 107.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 6 books, 117.0ms
# Confidence ---> 0.5
# Class name --> book
# Confidence ---> 0.44
# Class name --> bottle
# Confidence ---> 0.42
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 1.4ms preprocess, 117.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 6 books, 117.9ms
# Confidence ---> 0.62
# Class name --> book
# Confidence ---> 0.39
# Class name --> book
# Confidence ---> 0.34
# Class name --> bottle
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 1.5ms preprocess, 117.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 6 books, 106.5ms
# Confidence ---> 0.53
# Class name --> book
# Confidence ---> 0.44
# Class name --> book
# Confidence ---> 0.44
# Class name --> book
# Confidence ---> 0.34
# Class name --> bottle
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 3.1ms preprocess, 106.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 5 books, 130.5ms
# Confidence ---> 0.53
# Class name --> bottle
# Confidence ---> 0.48
# Class name --> book
# Confidence ---> 0.45
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Speed: 1.5ms preprocess, 130.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 1 laptop, 5 books, 110.5ms
# Confidence ---> 0.48
# Class name --> bottle
# Confidence ---> 0.41
# Class name --> book
# Confidence ---> 0.4
# Class name --> book
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.26
# Class name --> laptop
# Speed: 2.9ms preprocess, 110.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 7 books, 109.2ms
# Confidence ---> 0.59
# Class name --> book
# Confidence ---> 0.49
# Class name --> bottle
# Confidence ---> 0.47
# Class name --> book
# Confidence ---> 0.37
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 2.0ms preprocess, 109.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 laptop, 7 books, 107.1ms
# Confidence ---> 0.63
# Class name --> book
# Confidence ---> 0.43
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.26
# Class name --> laptop
# Speed: 1.8ms preprocess, 107.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 108.8ms
# Confidence ---> 0.63
# Class name --> book
# Confidence ---> 0.49
# Class name --> bottle
# Confidence ---> 0.41
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 1.4ms preprocess, 108.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 3 books, 106.2ms
# Confidence ---> 0.54
# Class name --> book
# Confidence ---> 0.47
# Class name --> book
# Confidence ---> 0.45
# Class name --> bottle
# Confidence ---> 0.31
# Class name --> book
# Speed: 4.0ms preprocess, 106.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 3 books, 113.1ms
# Confidence ---> 0.57
# Class name --> bottle
# Confidence ---> 0.53
# Class name --> book
# Confidence ---> 0.46
# Class name --> book
# Confidence ---> 0.36
# Class name --> book
# Speed: 2.3ms preprocess, 113.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 1 laptop, 7 books, 105.4ms
# Confidence ---> 0.65
# Class name --> book
# Confidence ---> 0.47
# Class name --> book
# Confidence ---> 0.42
# Class name --> bottle
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.32
# Class name --> laptop
# Confidence ---> 0.28
# Class name --> book
# Speed: 1.4ms preprocess, 105.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 116.6ms
# Confidence ---> 0.56
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.26
# Class name --> bottle
# Speed: 2.1ms preprocess, 116.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 5 books, 116.0ms
# Confidence ---> 0.67
# Class name --> book
# Confidence ---> 0.51
# Class name --> book
# Confidence ---> 0.38
# Class name --> book
# Confidence ---> 0.33
# Class name --> bottle
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 2.3ms preprocess, 116.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 5 books, 109.1ms
# Confidence ---> 0.6
# Class name --> book
# Confidence ---> 0.37
# Class name --> book
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.34
# Class name --> bottle
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Speed: 1.6ms preprocess, 109.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 5 books, 112.4ms
# Confidence ---> 0.62
# Class name --> book
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.32
# Class name --> bottle
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 2.0ms preprocess, 112.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 books, 123.8ms
# Confidence ---> 0.59
# Class name --> book
# Confidence ---> 0.36
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 2.9ms preprocess, 123.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 5 books, 129.2ms
# Confidence ---> 0.63
# Class name --> book
# Confidence ---> 0.37
# Class name --> book
# Confidence ---> 0.31
# Class name --> bottle
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 1.6ms preprocess, 129.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 tv, 4 books, 123.5ms
# Confidence ---> 0.55
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.3
# Class name --> tvmonitor
# Speed: 3.7ms preprocess, 123.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 3 books, 118.6ms
# Confidence ---> 0.64
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.29
# Class name --> bottle
# Speed: 5.5ms preprocess, 118.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 3 books, 119.2ms
# Confidence ---> 0.56
# Class name --> book
# Confidence ---> 0.47
# Class name --> bottle
# Confidence ---> 0.45
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 2.0ms preprocess, 119.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 books, 117.3ms
# Confidence ---> 0.58
# Class name --> book
# Confidence ---> 0.38
# Class name --> book
# Confidence ---> 0.36
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Speed: 2.9ms preprocess, 117.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 books, 110.8ms
# Confidence ---> 0.36
# Class name --> book
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Speed: 3.2ms preprocess, 110.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 5 books, 124.4ms
# Confidence ---> 0.61
# Class name --> book
# Confidence ---> 0.43
# Class name --> bottle
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 1.6ms preprocess, 124.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 6 books, 114.0ms
# Confidence ---> 0.67
# Class name --> book
# Confidence ---> 0.5
# Class name --> bottle
# Confidence ---> 0.48
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 2.0ms preprocess, 114.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 5 books, 119.3ms
# Confidence ---> 0.6
# Class name --> book
# Confidence ---> 0.46
# Class name --> book
# Confidence ---> 0.4
# Class name --> bottle
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 1.9ms preprocess, 119.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 5 books, 118.1ms
# Confidence ---> 0.66
# Class name --> book
# Confidence ---> 0.41
# Class name --> bottle
# Confidence ---> 0.36
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 3.5ms preprocess, 118.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 5 books, 112.3ms
# Confidence ---> 0.62
# Class name --> book
# Confidence ---> 0.44
# Class name --> book
# Confidence ---> 0.39
# Class name --> bottle
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 1.5ms preprocess, 112.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 6 books, 102.8ms
# Confidence ---> 0.64
# Class name --> book
# Confidence ---> 0.5
# Class name --> book
# Confidence ---> 0.31
# Class name --> bottle
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 1.6ms preprocess, 102.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 105.3ms
# Confidence ---> 0.64
# Class name --> book
# Confidence ---> 0.43
# Class name --> bottle
# Confidence ---> 0.4
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 1.5ms preprocess, 105.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 1 laptop, 3 books, 103.0ms
# Confidence ---> 0.61
# Class name --> book
# Confidence ---> 0.32
# Class name --> bottle
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.27
# Class name --> laptop
# Speed: 1.5ms preprocess, 103.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 117.7ms
# Confidence ---> 0.65
# Class name --> book
# Confidence ---> 0.4
# Class name --> bottle
# Confidence ---> 0.37
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 1.6ms preprocess, 117.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 5 books, 149.3ms
# Confidence ---> 0.59
# Class name --> book
# Confidence ---> 0.47
# Class name --> bottle
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 4.1ms preprocess, 149.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 books, 132.3ms
# Confidence ---> 0.65
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 1.8ms preprocess, 132.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 316.2ms
# Confidence ---> 0.67
# Class name --> book
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.27
# Class name --> bottle
# Speed: 1.8ms preprocess, 316.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 books, 125.2ms
# Confidence ---> 0.63
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 2.1ms preprocess, 125.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 1 laptop, 4 books, 107.0ms
# Confidence ---> 0.66
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.28
# Class name --> laptop
# Confidence ---> 0.28
# Class name --> bottle
# Speed: 1.2ms preprocess, 107.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 3 books, 123.1ms
# Confidence ---> 0.65
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.31
# Class name --> bottle
# Speed: 4.6ms preprocess, 123.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 3 books, 113.6ms
# Confidence ---> 0.6
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.31
# Class name --> bottle
# Confidence ---> 0.26
# Class name --> book
# Speed: 1.4ms preprocess, 113.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 5 books, 96.7ms
# Confidence ---> 0.69
# Class name --> book
# Confidence ---> 0.37
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.29
# Class name --> bottle
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 1.3ms preprocess, 96.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 books, 110.7ms
# Confidence ---> 0.64
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 1.3ms preprocess, 110.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 104.9ms
# Confidence ---> 0.64
# Class name --> book
# Confidence ---> 0.36
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.26
# Class name --> bottle
# Speed: 1.5ms preprocess, 104.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 5 books, 110.4ms
# Confidence ---> 0.68
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.28
# Class name --> bottle
# Speed: 2.0ms preprocess, 110.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 111.0ms
# Confidence ---> 0.61
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.3
# Class name --> bottle
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 2.6ms preprocess, 111.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 105.1ms
# Confidence ---> 0.65
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.27
# Class name --> bottle
# Confidence ---> 0.26
# Class name --> book
# Speed: 2.2ms preprocess, 105.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 113.8ms
# Confidence ---> 0.65
# Class name --> book
# Confidence ---> 0.43
# Class name --> bottle
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Speed: 1.5ms preprocess, 113.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 5 books, 111.9ms
# Confidence ---> 0.61
# Class name --> book
# Confidence ---> 0.38
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.26
# Class name --> bottle
# Speed: 1.2ms preprocess, 111.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 books, 134.9ms
# Confidence ---> 0.62
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 1.3ms preprocess, 134.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 5 books, 122.6ms
# Confidence ---> 0.6
# Class name --> book
# Confidence ---> 0.35
# Class name --> bottle
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 2.2ms preprocess, 122.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 137.7ms
# Confidence ---> 0.6
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.29
# Class name --> bottle
# Confidence ---> 0.26
# Class name --> book
# Speed: 1.4ms preprocess, 137.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 5 books, 119.7ms
# Confidence ---> 0.67
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.29
# Class name --> bottle
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 1.8ms preprocess, 119.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 1 laptop, 4 books, 115.0ms
# Confidence ---> 0.56
# Class name --> book
# Confidence ---> 0.38
# Class name --> book
# Confidence ---> 0.34
# Class name --> bottle
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.27
# Class name --> laptop
# Speed: 1.7ms preprocess, 115.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 5 books, 108.4ms
# Confidence ---> 0.62
# Class name --> book
# Confidence ---> 0.5
# Class name --> bottle
# Confidence ---> 0.44
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 1.5ms preprocess, 108.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 3 books, 102.5ms
# Confidence ---> 0.65
# Class name --> book
# Confidence ---> 0.37
# Class name --> book
# Confidence ---> 0.36
# Class name --> bottle
# Confidence ---> 0.31
# Class name --> book
# Speed: 1.9ms preprocess, 102.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 5 books, 107.8ms
# Confidence ---> 0.68
# Class name --> book
# Confidence ---> 0.44
# Class name --> bottle
# Confidence ---> 0.36
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 1.6ms preprocess, 107.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 5 books, 103.3ms
# Confidence ---> 0.65
# Class name --> book
# Confidence ---> 0.48
# Class name --> book
# Confidence ---> 0.38
# Class name --> bottle
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 1.7ms preprocess, 103.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 3 books, 107.8ms
# Confidence ---> 0.57
# Class name --> book
# Confidence ---> 0.46
# Class name --> book
# Confidence ---> 0.46
# Class name --> bottle
# Confidence ---> 0.31
# Class name --> book
# Speed: 2.2ms preprocess, 107.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 3 books, 109.6ms
# Confidence ---> 0.61
# Class name --> book
# Confidence ---> 0.42
# Class name --> book
# Confidence ---> 0.4
# Class name --> bottle
# Confidence ---> 0.33
# Class name --> book
# Speed: 1.6ms preprocess, 109.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 5 books, 108.2ms
# Confidence ---> 0.59
# Class name --> book
# Confidence ---> 0.44
# Class name --> book
# Confidence ---> 0.33
# Class name --> bottle
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 1.7ms preprocess, 108.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 102.1ms
# Confidence ---> 0.62
# Class name --> book
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.31
# Class name --> bottle
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 2.0ms preprocess, 102.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 105.1ms
# Confidence ---> 0.67
# Class name --> book
# Confidence ---> 0.56
# Class name --> book
# Confidence ---> 0.37
# Class name --> bottle
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 1.7ms preprocess, 105.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 1 laptop, 7 books, 110.4ms
# Confidence ---> 0.67
# Class name --> book
# Confidence ---> 0.58
# Class name --> book
# Confidence ---> 0.4
# Class name --> book
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.34
# Class name --> bottle
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.27
# Class name --> laptop
# Speed: 1.4ms preprocess, 110.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 5 books, 106.1ms
# Confidence ---> 0.61
# Class name --> book
# Confidence ---> 0.56
# Class name --> book
# Confidence ---> 0.47
# Class name --> bottle
# Confidence ---> 0.45
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Speed: 1.7ms preprocess, 106.1ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 105.2ms
# Confidence ---> 0.56
# Class name --> book
# Confidence ---> 0.53
# Class name --> book
# Confidence ---> 0.43
# Class name --> book
# Confidence ---> 0.41
# Class name --> bottle
# Confidence ---> 0.32
# Class name --> book
# Speed: 3.3ms preprocess, 105.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 1 laptop, 6 books, 108.5ms
# Confidence ---> 0.6
# Class name --> bottle
# Confidence ---> 0.57
# Class name --> laptop
# Confidence ---> 0.54
# Class name --> book
# Confidence ---> 0.42
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Speed: 1.6ms preprocess, 108.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 5 books, 114.9ms
# Confidence ---> 0.52
# Class name --> book
# Confidence ---> 0.5
# Class name --> book
# Confidence ---> 0.44
# Class name --> bottle
# Confidence ---> 0.37
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Speed: 2.2ms preprocess, 114.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 103.4ms
# Confidence ---> 0.67
# Class name --> book
# Confidence ---> 0.52
# Class name --> book
# Confidence ---> 0.45
# Class name --> bottle
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Speed: 3.9ms preprocess, 103.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 105.6ms
# Confidence ---> 0.64
# Class name --> book
# Confidence ---> 0.53
# Class name --> book
# Confidence ---> 0.37
# Class name --> bottle
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Speed: 1.6ms preprocess, 105.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 1 tv, 4 books, 103.2ms
# Confidence ---> 0.67
# Class name --> book
# Confidence ---> 0.48
# Class name --> bottle
# Confidence ---> 0.44
# Class name --> book
# Confidence ---> 0.37
# Class name --> tvmonitor
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Speed: 1.7ms preprocess, 103.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 103.3ms
# Confidence ---> 0.66
# Class name --> book
# Confidence ---> 0.53
# Class name --> book
# Confidence ---> 0.39
# Class name --> bottle
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Speed: 2.0ms preprocess, 103.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 106.1ms
# Confidence ---> 0.62
# Class name --> book
# Confidence ---> 0.5
# Class name --> book
# Confidence ---> 0.42
# Class name --> bottle
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Speed: 1.8ms preprocess, 106.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 108.0ms
# Confidence ---> 0.48
# Class name --> book
# Confidence ---> 0.48
# Class name --> book
# Confidence ---> 0.41
# Class name --> bottle
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Speed: 2.0ms preprocess, 108.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 5 books, 113.2ms
# Confidence ---> 0.61
# Class name --> book
# Confidence ---> 0.54
# Class name --> book
# Confidence ---> 0.49
# Class name --> bottle
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 2.2ms preprocess, 113.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 1 laptop, 6 books, 108.4ms
# Confidence ---> 0.61
# Class name --> book
# Confidence ---> 0.53
# Class name --> book
# Confidence ---> 0.5
# Class name --> bottle
# Confidence ---> 0.38
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.3
# Class name --> laptop
# Confidence ---> 0.27
# Class name --> book
# Speed: 1.9ms preprocess, 108.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 5 books, 107.9ms
# Confidence ---> 0.59
# Class name --> book
# Confidence ---> 0.51
# Class name --> bottle
# Confidence ---> 0.51
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 1.5ms preprocess, 107.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 1 laptop, 5 books, 107.9ms
# Confidence ---> 0.58
# Class name --> bottle
# Confidence ---> 0.55
# Class name --> book
# Confidence ---> 0.55
# Class name --> book
# Confidence ---> 0.35
# Class name --> laptop
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 2.3ms preprocess, 107.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 1 laptop, 4 books, 114.5ms
# Confidence ---> 0.63
# Class name --> book
# Confidence ---> 0.59
# Class name --> bottle
# Confidence ---> 0.55
# Class name --> book
# Confidence ---> 0.53
# Class name --> laptop
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 1.6ms preprocess, 114.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 1 laptop, 4 books, 124.7ms
# Confidence ---> 0.66
# Class name --> book
# Confidence ---> 0.55
# Class name --> book
# Confidence ---> 0.55
# Class name --> bottle
# Confidence ---> 0.52
# Class name --> laptop
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Speed: 2.1ms preprocess, 124.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 1 laptop, 4 books, 128.1ms
# Confidence ---> 0.68
# Class name --> book
# Confidence ---> 0.59
# Class name --> bottle
# Confidence ---> 0.54
# Class name --> book
# Confidence ---> 0.48
# Class name --> laptop
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Speed: 6.0ms preprocess, 128.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 1 tv, 1 laptop, 4 books, 115.7ms
# Confidence ---> 0.66
# Class name --> book
# Confidence ---> 0.52
# Class name --> bottle
# Confidence ---> 0.41
# Class name --> book
# Confidence ---> 0.33
# Class name --> laptop
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.27
# Class name --> tvmonitor
# Speed: 1.6ms preprocess, 115.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 1 laptop, 6 books, 116.1ms
# Confidence ---> 0.58
# Class name --> book
# Confidence ---> 0.57
# Class name --> book
# Confidence ---> 0.54
# Class name --> bottle
# Confidence ---> 0.41
# Class name --> book
# Confidence ---> 0.39
# Class name --> laptop
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 2.9ms preprocess, 116.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 7 books, 110.6ms
# Confidence ---> 0.68
# Class name --> book
# Confidence ---> 0.64
# Class name --> book
# Confidence ---> 0.45
# Class name --> bottle
# Confidence ---> 0.42
# Class name --> book
# Confidence ---> 0.42
# Class name --> book
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 2.7ms preprocess, 110.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 6 books, 110.9ms
# Confidence ---> 0.6
# Class name --> book
# Confidence ---> 0.58
# Class name --> book
# Confidence ---> 0.43
# Class name --> bottle
# Confidence ---> 0.36
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 1.6ms preprocess, 110.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 7 books, 114.4ms
# Confidence ---> 0.69
# Class name --> book
# Confidence ---> 0.62
# Class name --> book
# Confidence ---> 0.41
# Class name --> bottle
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 2.0ms preprocess, 114.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 6 books, 114.7ms
# Confidence ---> 0.65
# Class name --> book
# Confidence ---> 0.61
# Class name --> book
# Confidence ---> 0.49
# Class name --> bottle
# Confidence ---> 0.36
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 2.8ms preprocess, 114.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 130.5ms
# Confidence ---> 0.67
# Class name --> book
# Confidence ---> 0.39
# Class name --> bottle
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 13.0ms preprocess, 130.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 3 books, 108.8ms
# Confidence ---> 0.63
# Class name --> book
# Confidence ---> 0.45
# Class name --> book
# Confidence ---> 0.36
# Class name --> bottle
# Confidence ---> 0.3
# Class name --> book
# Speed: 2.5ms preprocess, 108.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 104.3ms
# Confidence ---> 0.61
# Class name --> book
# Confidence ---> 0.5
# Class name --> book
# Confidence ---> 0.33
# Class name --> bottle
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Speed: 1.7ms preprocess, 104.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 136.4ms
# Confidence ---> 0.63
# Class name --> book
# Confidence ---> 0.36
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.28
# Class name --> bottle
# Speed: 1.6ms preprocess, 136.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 99.5ms
# Confidence ---> 0.68
# Class name --> book
# Confidence ---> 0.36
# Class name --> bottle
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Speed: 1.6ms preprocess, 99.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 113.2ms
# Confidence ---> 0.63
# Class name --> book
# Confidence ---> 0.38
# Class name --> bottle
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 1.3ms preprocess, 113.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 116.2ms
# Confidence ---> 0.66
# Class name --> book
# Confidence ---> 0.38
# Class name --> book
# Confidence ---> 0.35
# Class name --> bottle
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Speed: 1.2ms preprocess, 116.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 3 books, 101.1ms
# Confidence ---> 0.64
# Class name --> book
# Confidence ---> 0.38
# Class name --> bottle
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Speed: 1.9ms preprocess, 101.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 111.4ms
# Confidence ---> 0.58
# Class name --> book
# Confidence ---> 0.36
# Class name --> book
# Confidence ---> 0.31
# Class name --> bottle
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 1.7ms preprocess, 111.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 151.0ms
# Confidence ---> 0.64
# Class name --> book
# Confidence ---> 0.4
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.29
# Class name --> bottle
# Speed: 1.7ms preprocess, 151.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 6 books, 122.7ms
# Confidence ---> 0.65
# Class name --> book
# Confidence ---> 0.36
# Class name --> book
# Confidence ---> 0.34
# Class name --> bottle
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 1.7ms preprocess, 122.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 192.1ms
# Confidence ---> 0.63
# Class name --> book
# Confidence ---> 0.36
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.29
# Class name --> bottle
# Speed: 1.8ms preprocess, 192.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 124.9ms
# Confidence ---> 0.63
# Class name --> book
# Confidence ---> 0.37
# Class name --> book
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.32
# Class name --> bottle
# Confidence ---> 0.27
# Class name --> book
# Speed: 1.3ms preprocess, 124.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 139.4ms
# Confidence ---> 0.66
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.32
# Class name --> bottle
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 1.8ms preprocess, 139.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 books, 136.4ms
# Confidence ---> 0.64
# Class name --> book
# Confidence ---> 0.41
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 2.1ms preprocess, 136.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 127.8ms
# Confidence ---> 0.68
# Class name --> book
# Confidence ---> 0.41
# Class name --> book
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.32
# Class name --> bottle
# Confidence ---> 0.28
# Class name --> book
# Speed: 1.8ms preprocess, 127.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 147.6ms
# Confidence ---> 0.68
# Class name --> book
# Confidence ---> 0.37
# Class name --> book
# Confidence ---> 0.35
# Class name --> bottle
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Speed: 3.5ms preprocess, 147.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 books, 115.3ms
# Confidence ---> 0.7
# Class name --> book
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Speed: 1.6ms preprocess, 115.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 1 laptop, 3 books, 142.6ms
# Confidence ---> 0.67
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.3
# Class name --> laptop
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.29
# Class name --> bottle
# Speed: 3.1ms preprocess, 142.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 1 laptop, 4 books, 119.7ms
# Confidence ---> 0.71
# Class name --> book
# Confidence ---> 0.41
# Class name --> book
# Confidence ---> 0.35
# Class name --> laptop
# Confidence ---> 0.34
# Class name --> bottle
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Speed: 1.7ms preprocess, 119.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 1 laptop, 4 books, 113.4ms
# Confidence ---> 0.65
# Class name --> book
# Confidence ---> 0.37
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.27
# Class name --> laptop
# Confidence ---> 0.26
# Class name --> bottle
# Speed: 4.1ms preprocess, 113.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 3 books, 173.5ms
# Confidence ---> 0.61
# Class name --> book
# Confidence ---> 0.43
# Class name --> book
# Confidence ---> 0.39
# Class name --> bottle
# Confidence ---> 0.36
# Class name --> book
# Speed: 11.6ms preprocess, 173.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 5 books, 128.9ms
# Confidence ---> 0.59
# Class name --> book
# Confidence ---> 0.36
# Class name --> bottle
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 2.9ms preprocess, 128.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 3 books, 129.3ms
# Confidence ---> 0.62
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.28
# Class name --> bottle
# Speed: 1.4ms preprocess, 129.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 139.5ms
# Confidence ---> 0.67
# Class name --> book
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.28
# Class name --> bottle
# Speed: 2.0ms preprocess, 139.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 1 laptop, 5 books, 116.7ms
# Confidence ---> 0.7
# Class name --> book
# Confidence ---> 0.32
# Class name --> bottle
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.29
# Class name --> laptop
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 2.5ms preprocess, 116.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 171.7ms
# Confidence ---> 0.64
# Class name --> book
# Confidence ---> 0.37
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.28
# Class name --> bottle
# Confidence ---> 0.26
# Class name --> book
# Speed: 1.6ms preprocess, 171.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 5 books, 116.2ms
# Confidence ---> 0.68
# Class name --> book
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.34
# Class name --> bottle
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 1.3ms preprocess, 116.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 3 books, 143.9ms
# Confidence ---> 0.66
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.26
# Class name --> bottle
# Confidence ---> 0.26
# Class name --> book
# Speed: 1.8ms preprocess, 143.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 500.2ms
# Confidence ---> 0.59
# Class name --> book
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.29
# Class name --> bottle
# Confidence ---> 0.27
# Class name --> book
# Speed: 4.3ms preprocess, 500.2ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 laptop, 4 books, 374.8ms
# Confidence ---> 0.65
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.29
# Class name --> laptop
# Speed: 21.4ms preprocess, 374.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 3 books, 135.4ms
# Confidence ---> 0.54
# Class name --> book
# Confidence ---> 0.35
# Class name --> bottle
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 1.5ms preprocess, 135.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 5 books, 167.2ms
# Confidence ---> 0.62
# Class name --> book
# Confidence ---> 0.35
# Class name --> bottle
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 2.9ms preprocess, 167.2ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 3 books, 131.4ms
# Confidence ---> 0.6
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.28
# Class name --> bottle
# Confidence ---> 0.26
# Class name --> book
# Speed: 1.7ms preprocess, 131.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 105.7ms
# Confidence ---> 0.62
# Class name --> book
# Confidence ---> 0.41
# Class name --> book
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.33
# Class name --> bottle
# Confidence ---> 0.28
# Class name --> book
# Speed: 1.7ms preprocess, 105.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 3 books, 180.3ms
# Confidence ---> 0.62
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.29
# Class name --> bottle
# Speed: 1.6ms preprocess, 180.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 5 books, 125.3ms
# Confidence ---> 0.67
# Class name --> book
# Confidence ---> 0.38
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.29
# Class name --> bottle
# Confidence ---> 0.26
# Class name --> book
# Speed: 2.3ms preprocess, 125.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 5 books, 144.1ms
# Confidence ---> 0.69
# Class name --> book
# Confidence ---> 0.41
# Class name --> book
# Confidence ---> 0.32
# Class name --> bottle
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 1.6ms preprocess, 144.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 6 books, 296.0ms
# Confidence ---> 0.71
# Class name --> book
# Confidence ---> 0.42
# Class name --> book
# Confidence ---> 0.34
# Class name --> bottle
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 6.9ms preprocess, 296.0ms inference, 5.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 184.6ms
# Confidence ---> 0.59
# Class name --> book
# Confidence ---> 0.34
# Class name --> bottle
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 3.5ms preprocess, 184.6ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 5 books, 162.7ms
# Confidence ---> 0.64
# Class name --> book
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.31
# Class name --> bottle
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 3.2ms preprocess, 162.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 3 books, 149.3ms
# Confidence ---> 0.62
# Class name --> book
# Confidence ---> 0.37
# Class name --> bottle
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 1.3ms preprocess, 149.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 5 books, 223.4ms
# Confidence ---> 0.66
# Class name --> book
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.32
# Class name --> bottle
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 212.3ms preprocess, 223.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Speed: 16.0ms preprocess, 148.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# Speed: 1.8ms preprocess, 156.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Speed: 1.9ms preprocess, 142.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 5 books, 144.0ms
# Confidence ---> 0.68
# Class name --> book
# Confidence ---> 0.31
# Class name --> bottle
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 2.2ms preprocess, 144.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 119.1ms
# Confidence ---> 0.64
# Class name --> book
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.3
# Class name --> bottle
# Speed: 3.7ms preprocess, 119.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 6 books, 118.4ms
# Confidence ---> 0.67
# Class name --> book
# Confidence ---> 0.38
# Class name --> bottle
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 1.7ms preprocess, 118.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# Speed: 1.6ms preprocess, 118.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Speed: 2.4ms preprocess, 126.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Speed: 6.7ms preprocess, 125.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Speed: 3.4ms preprocess, 143.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# Speed: 3.1ms preprocess, 129.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Speed: 2.5ms preprocess, 126.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Speed: 1.9ms preprocess, 113.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### **Step 5.1: Run YOLO on an Image (the simple way)**

# %%
# Run yolo model on an image
results = model.predict(source="/Users/eugenio/Documents/Notebooks_ArtificialIntelligence/5. Computer Vision/Object Detection/cat.jpg", show=True)
# Out:
# image 1/1 /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/5. Computer Vision/Object Detection/cat.jpg: 640x640 1 cat, 892.5ms
# Speed: 81.1ms preprocess, 892.5ms inference, 90.9ms postprocess per image at shape (1, 3, 640, 640)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### **Step 5.2: Run YOLO on an Image (the complete way)**

# %% [markdown]
# Load your image and prepare it for inference:

# %%
# Load an image (change the path to your image file)
image_bgr = cv2.imread('/Users/eugenio/Documents/Notebooks_ArtificialIntelligence/5. Computer Vision/Object Detection/cat.jpg')

# %% [markdown]
# Run inference

# %%
# Run inference
results = model(image_bgr)
# Out:
# 0: 640x640 1 cat, 194.7ms
# Speed: 35.0ms preprocess, 194.7ms inference, 14.3ms postprocess per image at shape (1, 3, 640, 640)

# %%
# Extract detection results
boxes = results[0].boxes  # Bounding boxes
scores = boxes.conf       # Confidence scores
class_ids = boxes.cls     # Class IDs

# Create a copy of the original image to draw on
image_with_boxes = image_bgr.copy()

# Define colors for different classes
colors = [(0, 255, 0), (0, 0, 255), (255, 0, 0), (255, 255, 0), 
          (0, 255, 255), (255, 0, 255), (255, 165, 0), (128, 0, 128)]

# Draw bounding boxes and labels for each detection
for i, (box, score, class_id) in enumerate(zip(boxes.xyxy, scores, class_ids)):
    # Convert tensor to numpy array
    x1, y1, x2, y2 = box.cpu().numpy()
    class_id = int(class_id.cpu().numpy())
    score = float(score.cpu().numpy())
    
    # Get class name and color
    class_name = model.names[class_id]
    color = colors[class_id % len(colors)]
    
    # Draw bounding box
    cv2.rectangle(image_with_boxes, (int(x1), int(y1)), (int(x2), int(y2)), color, 5)
    
    # Create label text
    label = f"{class_name}: {score:.2f}"
    
    # Calculate text position
    label_size = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 1, 2)[0]
    label_y = max(int(y1) - 10, label_size[1] + 10)
    
    # Draw text background
    cv2.rectangle(image_with_boxes, 
                 (int(x1), label_y - label_size[1] - 10),
                 (int(x1) + label_size[0], label_y + 5),
                 color, -1)
    
    # Draw text
    cv2.putText(image_with_boxes, label, 
               (int(x1), label_y - 5), 
               cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)
    
# Convert from BGR to RGB for matplotlib
image_with_boxes_rgb = cv2.cvtColor(image_with_boxes, cv2.COLOR_BGR2RGB)

# Display the result
plt.figure(figsize=(12, 10))
plt.imshow(image_with_boxes_rgb)
plt.title('Object Detection with YOLOv11')
plt.axis('off')
plt.show()

# Print detection summary
print(f"Detected {len(boxes)} objects:")
for i, (class_id, score) in enumerate(zip(class_ids, scores)):
    class_id = int(class_id.cpu().numpy())
    score = float(score.cpu().numpy())
    print(f"  {i+1}. {model.names[class_id]} (confidence: {score:.2f})")

# %% [markdown]
# ### **Step 6.1: Run Object Detection on a saved video (the simple way)**

# %% [markdown]
# Inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos.

# %%
# YOLO on a saved video
results = model.predict(source='/Users/eugenio/Documents/Notebooks_ArtificialIntelligence/5. Computer Vision/Object Detection/car-detection.mp4', show=True, stream=True)

# %% [markdown]
# ### **Step 6.2: Run Object Detection on a saved video (the complete way)**

# %%
# Load YOLO model
model = YOLO('yolov8n.pt')

# Configure your video path
video_path = "/Users/eugenio/Documents/Notebooks_ArtificialIntelligence/5. Computer Vision/Object Detection/race_car.mp4"

# Open video
cap = cv2.VideoCapture(video_path)

# Verify video opened correctly
if not cap.isOpened():
    print("Error: Could not open video. Check the path.")
else:
    print("Video loaded successfully. Press 'q' to exit.")
    
    # Process each video frame
    while True:
        ret, frame = cap.read()
        
        if not ret:
            break  # Finish when video ends
            
        # Run detection with YOLO
        results = model(frame)
        
        # Draw bounding boxes
        for result in results:
            boxes = result.boxes
            for box in boxes:
                x1, y1, x2, y2 = map(int, box.xyxy[0].cpu().numpy())
                confidence = float(box.conf[0].cpu().numpy())
                class_id = int(box.cls[0].cpu().numpy())
                
                # Only show detections with confidence > 50%
                if confidence > 0.5:
                    # Draw rectangle
                    cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                    
                    # Show label
                    label = f"{model.names[class_id]}: {confidence:.2f}"
                    cv2.putText(frame, label, (x1, y1-10), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
        
        # Show frame with detections
        cv2.imshow('Object Detection', frame)
        
        # Exit with 'q' key
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

# Release resources
cap.release()
cv2.destroyAllWindows()
print("Processing completed.")

# %% [markdown]
# ## **Activity**
#
# ### **Option 1: Mathematics Track**
#
# Clone your repository from GitHub and run the system directly on the Jetson Nano.
#
# #### Access to the Jetson Nano
#
# You will be provided with:
# - Username
# - Jetson Nano IP address
# - Password
#
# Use your computer's terminal to connect:
#
# `ssh username@jetson_ip`
#
# #### 1. Clone the repository
# `git clone https://github.com/user/repository.git`
#
# #### 2. Access the project directory
# `cd repository`
#
# #### 3. Create virtual environment and install dependencies
# `python3 -m venv env`
# `source env/bin/activate`
# `pip install -r requirements.txt`
#
# #### 4. Run the virtual environment
# `python YOLO-Real-Time.py`
#
# ### **Grading Rubric**
#
# | **Criteria** | **Points** | **Description** |
# |-------------|-----------|----------------|
# | **1. SSH Connection** | 2 | Successfully establishes SSH connection to Jetson Nano. Properly handles authentication and connection setup. |
# | **2. Environment Setup** | 3 | Creates virtual environment and installs all dependencies correctly. Resolves any platform-specific issues. |
# | **3. Application Execution** | 3 | Runs YOLO real-time detection successfully on Jetson Nano. Handles hardware acceleration properly. |
# | **4. Performance Optimization** | 2 | Implements optimizations for Jetson Nano hardware. Maintains acceptable frame rate for real-time detection. |
#
# Total: 10 points

# %%
# Write your code here...

# %% [markdown]
# ### **Option 2: Computer Science Track**
#
# Create a Dockerfile in your Jetson Nano folder:
#
# #### Dockerfile
#
# `FROM nvcr.io/nvidia/l4t-pytorch:r32.7.1-pth1.11-py3`
# `RUN apt-get update && apt-get install -y python3-pip libopencv-dev`
# `RUN pip3 install ultralytics opencv-python`
#
# `COPY . /app`
# `WORKDIR /app`
#
# `CMD ["python3", "YOLO-Real-Time.py"]`
#
# #### 1. Clone your repository
# `git clone https://github.com/user/repository.git`
# `cd repository`
#
# #### 2. Build the Docker image
# `sudo docker build -t yolov8-detector .`
#
# #### 3. Run the container
# `sudo docker run --rm -it --net=host --device=/dev/video0 yolov8-detector`
#
# ### Steps to build and run:
#
# #### 1. Clone your repository
# `git clone https://github.com/user/repository.git`
# `cd repository`
#
# #### 2. Build the Docker image
# `sudo docker build -t yolov8-detector .`
#
# #### 3. Run the container
# `sudo docker run --rm -it --net=host --device=/dev/video0 yolov8-detector`
#
# ### **Grading Rubric**
#
# | **Criteria** | **Points** | **Description** |
# |-------------|-----------|----------------|
# | **1. Repository Setup** | 2 | Successfully clones repository and sets up environment. All dependencies installed correctly without errors. |
# | **2. Docker Implementation** | 3 | Dockerfile is properly configured with all necessary dependencies. Image builds successfully without errors. |
# | **3. Container Execution** | 3 | Container runs successfully with camera access. Real-time detection works properly in Docker environment. |
# | **4. System Performance** | 2 | Application runs smoothly with acceptable frame rate. Handles video streaming without crashes or major issues. |
#
# Total: 10 points

# %%
# Write your code here...

# %% [markdown]
# ### **Option 3: Master's in Artificial Intelligence / Data Science**
#
# In this option, the work will be developed **locally on your personal computers**.
#
# #### Objective
# Design a **specific object detection application** using YOLO (You Only Look Once), focused on **a limited subset of classes**. The system must show that **it only detects the activated classes**, visually ignoring objects belonging to deactivated classes (even if they are present in the image).
#
# #### Instructions
#
# 1. **Define a concrete application and the problem it solves**, for example: vehicle detection, fruits detection, etc.
# 2. **Select between 2 and 4 classes** from the YOLOv8 model to detect.
# 3. **Modify the model logic** or post-processing so that **only the selected classes are shown**.
# 4. Run the application on video where **objects from non-activated classes** are also present to demonstrate that the system **ignores those classes**.
# 5. Show the results clearly, visually indicating the detected and non-detected objects.
#
# #### Technical Requirements
#
# - Use `ultralytics` with `YOLO` in any version.
# - You can use your webcam video or local video (no static images allowed).
#
# #### Deliverable
#
# Must be uploaded to the virtual classroom:
#
# - **Jupyter Notebook in PDF format** containing:
# - Commented code
# - Application title and the problem it solves
# - List of activated classes
# - Screenshots or test images with results showing:
#   - Objects *correctly detected* according to the activated classes.
#   - Objects *not detected* because they belong to deactivated classes (even if present in the image).
#
# ### **Grading Rubric**
#
# | **Criteria** | **Points** | **Description** |
# |-------------|-----------|----------------|
# | **1. Application Definition and Problem Statement** | 1 | Clearly defines a specific object detection application and its practical use case. Selects appropriate classes for the application context. |
# | **2. Class Selection and Justification** | 1 | Selects between 2-4 relevant classes from YOLOv8 model. Demonstrates thoughtful choice of classes for the specific application. |
# | **3. Implementation** | 4 | Successfully modifies the model logic or post-processing to only show selected classes. Code is functional and properly ignores non-selected classes. |
# | **4. Testing & Evidence** | 3 | Provides a clear test showing both detected (activated classes) and ignored (deactivated classes) objects. Evidence demonstrates the filtering works correctly. |
# | **5. Documentation** | 1 | Delivers complete documentation including PDF notebook, application title, class list, and proper screenshots. Submission is well-organized and professional. |
#
# Total: 10 points

# %%
# Write your code here..

# %% [markdown]
# <p style="text-align: right; font-size:14px; color:gray;">
# <b>Prepared by:</b><br>
# Manuel Eugenio Morocho-Cayamcela
# </p>
