# %% [markdown]
# # **Tutorial:** Custom YOLO Object Detection with RoboFlow
#
# In this tutorial, you'll learn how to create a custom YOLO object detection model using your own classes and annotations with RoboFlow.

# %% [markdown]
# ### **Step 1: Install Required Dependencies**

# %%
# %pip install --upgrade ultralytics
# %pip install opencv-python
# %pip install roboflow
# %pip install matplotlib
# %pip install numpy==1.26.4 --force-reinstall

# %% [markdown]
# ### **Step 2: Import Required Libraries**

# %%
import cv2
from roboflow import Roboflow
from ultralytics import YOLO
import matplotlib.pyplot as plt
import numpy as np
import os
from IPython.display import Image, display

# %% [markdown]
# ### **Step 3: Set Up RoboFlow Account**

# %% [markdown]
# 1. Go to RoboFlow and create a free account
# 2. Create a new project and select "Object Detection" as project type
# 3. Choose "YOLOv8" as the model format

# %% [markdown]
# ### **Step 4: Upload and Annotate Your Images**

# %% [markdown]
# #### Using RoboFlow Web Interface:
#
# 1. Click "Upload" to add your images
# 2. Use the annotation tool to draw bounding boxes around objects
# 3. Assign the correct class labels to each bounding box
# 4. Apply preprocessing and augmentation as needed

# %% [markdown]
# ### **Step 5. Download your Custom your Dataset**

# %% [markdown]
# 1. In RoboFlow, go to your project dashboard
# 2. Click "Generate" to create a dataset version
# 3. Apply any desired augmentations
# 4. Click "Export" and select "YOLOv**x**" format (**x** the version you are using)
# 5. Copy the download code

# %%
# Initialize RoboFlow (you'll need your API key)

# !pip install roboflow
from roboflow import Roboflow
rf = Roboflow(api_key="uugD71oI3JrBihabx7vV")
project = rf.workspace("eugenio-tblbg").project("yolo_custom-0zplf")
version = project.version(3)
dataset = version.download("yolov11")

# %% [markdown]
# ### **Step 6: Train Your Custom YOLO Model**

# %%
# Load the YOLO model with custom configuration
model = YOLO('yolo11n.pt')  # Using nano version as base

# Train the model on your custom dataset
results = model.train(
    data=f'{dataset.location}/data.yaml',  # Path to dataset config
    epochs=20,  # Number of training epochs
    imgsz=640,  # Image size
    batch=16,   # Batch size
    name='custom_yolo_model'  # Name for the training run
)
# Out:
# Ultralytics 8.3.221 🚀 Python-3.11.14 torch-2.2.2 CPU (Intel Core i5-8257U 1.40GHz)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/Users/eugenio/Documents/Notebooks_ArtificialIntelligence/5. Computer Vision/Object Detection/YOLO_custom-3/data.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=custom_yolo_model, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/Users/eugenio/Documents/Notebooks_ArtificialIntelligence/runs/detect/custom_yolo_model, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Unable to revert mtime: /Library/Fonts
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    430867  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,590,035 parameters, 2,590,019 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 392.1±127.0 MB/s, size: 208.4 KB)
# train: Scanning /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/5. Computer Vision/Object Detection/YOLO_custom-3/train/labels... 9 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 9/9 283.0it/s 0.0s
# train: New cache created: /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/5. Computer Vision/Object Detection/YOLO_custom-3/train/labels.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 397.4±0.0 MB/s, size: 211.9 KB)
# val: Scanning /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/5. Computer Vision/Object Detection/YOLO_custom-3/valid/labels... 1 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1/1 282.1it/s 0.0s
# val: New cache created: /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/5. Computer Vision/Object Detection/YOLO_custom-3/valid/labels.cache
# Plotting labels to /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/runs/detect/custom_yolo_model/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/runs/detect/custom_yolo_model
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50         0G      1.437      2.799      2.037         18        640: 100% ━━━━━━━━━━━━ 1/1 0.1it/s 7.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.7it/s 0.3s
#                    all          1          1    0.00333          1      0.995      0.547
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50         0G      1.369      2.926          2         18        640: 100% ━━━━━━━━━━━━ 1/1 0.2it/s 5.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.5it/s 0.4s
#                    all          1          1    0.00333          1      0.995      0.547
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50         0G      1.327      2.777      2.115         18        640: 100% ━━━━━━━━━━━━ 1/1 0.1it/s 8.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.9it/s 0.3s
#                    all          1          1    0.00333          1      0.995      0.547
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50         0G      1.226      2.581       1.72         26        640: 100% ━━━━━━━━━━━━ 1/1 0.2it/s 5.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.4it/s 0.2s
#                    all          1          1    0.00333          1      0.995      0.497
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50         0G     0.8388      2.584      1.509         22        640: 100% ━━━━━━━━━━━━ 1/1 0.2it/s 5.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.1it/s 0.2s
#                    all          1          1    0.00333          1      0.995      0.796
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50         0G      1.223      2.544      1.768         28        640: 100% ━━━━━━━━━━━━ 1/1 0.1it/s 9.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.1it/s 0.2s
#                    all          1          1    0.00333          1      0.995      0.796
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50         0G       1.08      2.545      1.676         26        640: 100% ━━━━━━━━━━━━ 1/1 0.1it/s 7.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.0it/s 0.2s
#                    all          1          1    0.00333          1      0.995      0.697
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50         0G     0.9144      2.469      1.458         26        640: 100% ━━━━━━━━━━━━ 1/1 0.1it/s 10.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.3it/s 0.2s
#                    all          1          1    0.00333          1      0.995      0.697
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50         0G     0.8071      2.447      1.418         22        640: 100% ━━━━━━━━━━━━ 1/1 0.1it/s 7.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.0it/s 0.3s
#                    all          1          1    0.00333          1      0.995      0.697
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50         0G      1.058      2.427      1.594         25        640: 100% ━━━━━━━━━━━━ 1/1 0.1it/s 19.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.8it/s 0.6s
#                    all          1          1    0.00333          1      0.995      0.597
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50         0G      1.061      2.473      1.563         20        640: 100% ━━━━━━━━━━━━ 1/1 0.1it/s 10.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.1it/s 0.3s
#                    all          1          1    0.00333          1      0.995      0.597
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50         0G     0.8922      2.298      1.497         20        640: 100% ━━━━━━━━━━━━ 1/1 0.1it/s 13.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.1it/s 0.3s
#                    all          1          1    0.00333          1      0.995      0.597
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50         0G     0.8372      2.238      1.405         28        640: 100% ━━━━━━━━━━━━ 1/1 0.1it/s 7.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.9it/s 0.3s
#                    all          1          1    0.00333          1      0.995      0.597
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50         0G     0.9037      2.173      1.425         23        640: 100% ━━━━━━━━━━━━ 1/1 0.1it/s 11.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.9it/s 0.3s
#                    all          1          1    0.00333          1      0.995      0.796
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50         0G     0.8291      2.117      1.426         23        640: 100% ━━━━━━━━━━━━ 1/1 0.1it/s 7.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.5it/s 0.3s
#                    all          1          1    0.00333          1      0.995      0.895
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50         0G     0.7739      2.094       1.29         23        640: 100% ━━━━━━━━━━━━ 1/1 0.1it/s 9.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.7it/s 0.3s
#                    all          1          1    0.00333          1      0.995      0.895
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50         0G     0.7243        2.1      1.286         20        640: 100% ━━━━━━━━━━━━ 1/1 0.2it/s 6.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.0it/s 0.3s
#                    all          1          1    0.00333          1      0.995      0.895
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50         0G      0.865      2.041      1.519         22        640: 100% ━━━━━━━━━━━━ 1/1 0.1it/s 7.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.4it/s 0.3s
#                    all          1          1    0.00333          1      0.995      0.895
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50         0G     0.6981      1.956      1.266         23        640: 100% ━━━━━━━━━━━━ 1/1 0.2it/s 6.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.5it/s 0.2s
#                    all          1          1    0.00333          1      0.995      0.895
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50         0G     0.8075      1.846      1.196         31        640: 100% ━━━━━━━━━━━━ 1/1 0.1it/s 9.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.6it/s 0.3s
#                    all          1          1    0.00333          1      0.995      0.895
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50         0G     0.7797      1.938      1.317         21        640: 100% ━━━━━━━━━━━━ 1/1 0.2it/s 5.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.7it/s 0.3s
#                    all          1          1    0.00333          1      0.995      0.895
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50         0G     0.7673      1.956      1.447         18        640: 100% ━━━━━━━━━━━━ 1/1 0.2it/s 5.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.4it/s 0.3s
#                    all          1          1    0.00333          1      0.995      0.895
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50         0G     0.7353       1.77      1.237         27        640: 100% ━━━━━━━━━━━━ 1/1 0.1it/s 11.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.8it/s 0.4s
#                    all          1          1    0.00333          1      0.995      0.895
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50         0G     0.9345      1.876       1.39         21        640: 100% ━━━━━━━━━━━━ 1/1 0.1it/s 7.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.7it/s 0.4s
#                    all          1          1    0.00333          1      0.995      0.895
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50         0G     0.8042      1.752      1.262         26        640: 100% ━━━━━━━━━━━━ 1/1 0.1it/s 13.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.2it/s 0.3s
#                    all          1          1    0.00333          1      0.995      0.895
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50         0G     0.9021      1.739      1.318         24        640: 100% ━━━━━━━━━━━━ 1/1 0.1it/s 9.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.9it/s 0.5s
#                    all          1          1    0.00333          1      0.995      0.895
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50         0G     0.7756      1.822      1.376         22        640: 100% ━━━━━━━━━━━━ 1/1 0.1it/s 7.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.5it/s 0.3s
#                    all          1          1    0.00333          1      0.995      0.796
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50         0G     0.7469      1.717        1.3         24        640: 100% ━━━━━━━━━━━━ 1/1 0.1it/s 9.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.9it/s 0.3s
#                    all          1          1    0.00333          1      0.995      0.796
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50         0G     0.7099      1.635      1.251         22        640: 100% ━━━━━━━━━━━━ 1/1 0.1it/s 17.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.0it/s 0.5s
#                    all          1          1    0.00333          1      0.995      0.796
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50         0G     0.6575      1.534      1.166         28        640: 100% ━━━━━━━━━━━━ 1/1 0.1it/s 9.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.0it/s 0.3s
#                    all          1          1    0.00333          1      0.995      0.796
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50         0G     0.7877      1.624      1.329         22        640: 100% ━━━━━━━━━━━━ 1/1 0.1it/s 8.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.9it/s 0.5s
#                    all          1          1    0.00333          1      0.995      0.796
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50         0G     0.7152      1.494      1.169         30        640: 100% ━━━━━━━━━━━━ 1/1 0.1it/s 10.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.1it/s 0.3s
#                    all          1          1    0.00333          1      0.995      0.796
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50         0G     0.8257      1.568      1.238         32        640: 100% ━━━━━━━━━━━━ 1/1 0.2it/s 6.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.9it/s 0.3s
#                    all          1          1    0.00333          1      0.995      0.895
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50         0G     0.7354      1.471      1.146         35        640: 100% ━━━━━━━━━━━━ 1/1 0.1it/s 8.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.3it/s 0.4s
#                    all          1          1    0.00333          1      0.995      0.895
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50         0G      0.661      1.468      1.186         28        640: 100% ━━━━━━━━━━━━ 1/1 0.1it/s 9.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.1it/s 0.2s
#                    all          1          1    0.00333          1      0.995      0.796
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50         0G     0.7228      1.414      1.135         35        640: 100% ━━━━━━━━━━━━ 1/1 0.0it/s 35.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 0.6it/s 1.7s
#                    all          1          1    0.00333          1      0.995      0.796
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50         0G     0.6385      1.351      1.166         23        640: 100% ━━━━━━━━━━━━ 1/1 0.0it/s 41.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.7it/s 0.6s
#                    all          1          1    0.00333          1      0.995      0.796
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50         0G      0.743      1.453      1.276         24        640: 100% ━━━━━━━━━━━━ 1/1 0.1it/s 10.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.9it/s 0.5s
#                    all          1          1    0.00333          1      0.995      0.796
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50         0G     0.7406      1.423      1.293         24        640: 100% ━━━━━━━━━━━━ 1/1 0.1it/s 15.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.6it/s 0.6s
#                    all          1          1    0.00333          1      0.995      0.796
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50         0G     0.7522      1.353      1.306         25        640: 100% ━━━━━━━━━━━━ 1/1 0.1it/s 9.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.5it/s 0.4s
#                    all          1          1    0.00333          1      0.995      0.796
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50         0G     0.8344      1.974      1.375          9        640: 100% ━━━━━━━━━━━━ 1/1 0.1it/s 10.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.2it/s 0.5s
#                    all          1          1    0.00333          1      0.995      0.895
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50         0G      0.848      1.863      1.707          9        640: 100% ━━━━━━━━━━━━ 1/1 0.1it/s 16.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.0it/s 0.5s
#                    all          1          1    0.00333          1      0.995      0.895
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50         0G     0.8313       1.86      1.757          9        640: 100% ━━━━━━━━━━━━ 1/1 0.1it/s 6.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.0it/s 0.5s
#                    all          1          1    0.00333          1      0.995      0.895
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50         0G     0.5858      1.622       1.23          9        640: 100% ━━━━━━━━━━━━ 1/1 0.1it/s 14.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.0it/s 0.5s
#                    all          1          1    0.00333          1      0.995      0.895
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50         0G     0.7389      1.785      1.395          9        640: 100% ━━━━━━━━━━━━ 1/1 0.1it/s 6.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.5it/s 0.3s
#                    all          1          1    0.00333          1      0.995      0.895
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50         0G     0.4953      1.587      1.138          9        640: 100% ━━━━━━━━━━━━ 1/1 0.1it/s 15.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.0it/s 1.0s
#                    all          1          1    0.00333          1      0.995      0.895
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50         0G     0.4658      1.567      1.115          9        640: 100% ━━━━━━━━━━━━ 1/1 0.0it/s 40.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 0.4it/s 2.4s
#                    all          1          1    0.00333          1      0.995      0.895
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50         0G     0.5587      1.569       1.19          9        640: 100% ━━━━━━━━━━━━ 1/1 0.0it/s 45.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.2it/s 0.8s
#                    all          1          1    0.00333          1      0.995      0.895
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50         0G      0.447      1.507      1.069          9        640: 100% ━━━━━━━━━━━━ 1/1 0.0it/s 27.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 0.8it/s 1.2s
#                    all          1          1    0.00333          1      0.995      0.895
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50         0G     0.5776      1.583      1.133          9        640: 100% ━━━━━━━━━━━━ 1/1 0.0it/s 23.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 0.4it/s 2.6s
#                    all          1          1    0.00333          1      0.995      0.895
#
# 50 epochs completed in 0.193 hours.
# Optimizer stripped from /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/runs/detect/custom_yolo_model/weights/last.pt, 5.5MB
# Optimizer stripped from /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/runs/detect/custom_yolo_model/weights/best.pt, 5.5MB
#
# Validating /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/runs/detect/custom_yolo_model/weights/best.pt...
# Ultralytics 8.3.221 🚀 Python-3.11.14 torch-2.2.2 CPU (Intel Core i5-8257U 1.40GHz)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 0.2it/s 5.9s
#                    all          1          1    0.00333          1      0.995      0.895
# Speed: 66.0ms preprocess, 5061.3ms inference, 0.0ms loss, 27.2ms postprocess per image
# Results saved to /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/runs/detect/custom_yolo_model

# %% [markdown]
# ### **Step 7: Evaluate Your Model**

# %%
# Evaluate model performance
metrics = model.val()  # Validate the model
print(f"mAP50-95: {metrics.box.map}")
print(f"mAP50: {metrics.box.map50}")

# Show some validation results
# !yolo task=detect mode=val model=runs/detect/custom_yolo_model/weights/best.pt data={dataset.location}/data.yaml
# Out:
# Ultralytics 8.3.221 🚀 Python-3.11.14 torch-2.2.2 CPU (Intel Core i5-8257U 1.40GHz)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 315.4±0.0 MB/s, size: 211.9 KB)
# val: Scanning /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/5. Computer Vision/Object Detection/YOLO_custom-3/valid/labels.cache... 1 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1/1 1.1Kit/s 0.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.2it/s 0.3s
#                    all          1          1    0.00333          1      0.995      0.895
# Speed: 3.6ms preprocess, 182.6ms inference, 0.0ms loss, 15.7ms postprocess per image
# Results saved to /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/runs/detect/val
# mAP50-95: 0.8955
# mAP50: 0.995
# Traceback (most recent call last):
#   File "/Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/bin/yolo", line 7, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages/ultralytics/cfg/__init__.py", line 913, in entrypoint
#     check_dict_alignment(full_args_dict, {a: ""})
#   File "/Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages/ultralytics/cfg/__init__.py", line 504, in check_dict_alignment
#     raise SyntaxError(string + CLI_HELP_MSG) from e
# SyntaxError: 'Computer' is not a valid YOLO argument.
#
#     Arguments received: ['yolo', 'task=detect', 'mode=val', 'model=runs/detect/custom_yolo_model/weights/best.pt', 'data=/Users/eugenio/Documents/Notebooks_ArtificialIntelligence/5.', 'Computer', 'Vision/Object', 'Detection/YOLO_custom-3/data.yaml']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
#         Where   TASK (optional) is one of ['segment', 'pose', 'detect', 'obb', 'classify']
#                 MODE (required) is one of ['predict', 'benchmark', 'track', 'train', 'export', 'val']
#                 ARGS (optional) are any number of custom 'arg=value' pairs like 'imgsz=320' that override defaults.
#                     See all ARGS at https://docs.ultralytics.com/usage/cfg or with 'yolo cfg'
#
#     1. Train a detection model for 10 epochs with an initial learning_rate of 0.01
#         yolo train data=coco8.yaml model=yolo11n.pt epochs=10 lr0=0.01
#
#     2. Predict a YouTube video using a pretrained segmentation model at image size 320:
#         yolo predict model=yolo11n-seg.pt source='https://youtu.be/LNwODJXcvt4' imgsz=320
#
#     3. Val a pretrained detection model at batch-size 1 and image size 640:
#         yolo val model=yolo11n.pt data=coco8.yaml batch=1 imgsz=640
#
#     4. Export a YOLO11n classification model to ONNX format at image size 224 by 128 (no TASK required)
#         yolo export model=yolo11n-cls.pt format=onnx imgsz=224,128
#
#     5. Ultralytics solutions usage
#         yolo solutions count or in ['crop', 'blur', 'workout', 'heatmap', 'isegment', 'visioneye', 'speed', 'queue', 'analytics', 'inference', 'trackzone'] source="path/to/video.mp4"
#
#     6. Run special commands:
#         yolo help
#         yolo checks
#         yolo version
#         yolo settings
#         yolo copy-cfg
#         yolo cfg
#         yolo solutions help
#
#     Docs: https://docs.ultralytics.com
#     Solutions: https://docs.ultralytics.com/solutions/
#     Community: https://community.ultralytics.com
#     GitHub: https://github.com/ultralytics/ultralytics

# %% [markdown]
# ### **Step 8: Test Your Custom Model on an Image**

# %%
# Load your custom trained model
custom_model = YOLO('/Users/eugenio/Documents/Notebooks_ArtificialIntelligence/runs/detect/custom_yolo_model/weights/best.pt')

# Test on a sample image
results = custom_model('/Users/eugenio/Documents/Notebooks_ArtificialIntelligence/5. Computer Vision/Object Detection/taza_test.jpg', conf=0.03)

# Display results
# %matplotlib inline
for result in results:
    img = result.plot()  # Plot detections
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(12, 8))
    plt.imshow(img_rgb)
    plt.axis('off')
    plt.show()

# %% [markdown]
# ### **Step 9: Test Your Custom Model on Video**

# %%
# Write your code here..

# %% [markdown]
# ## **Activity: Create Your Custom Detector**
#
# 1. **Create a RoboFlow account** and set up a new project
# 2. **Upload at least 20 images** of your custom objects
# 3. **Annotate all images** with bounding boxes and class labels
# 4. **Train a YOLO model** on your custom dataset
# 5. **Test your model** on new images and evaluate its performance
# 6. **Implement real-time detection** with your custom classes
#
# ## **Grading Rubric:**
#
# | **Criteria** | **Points** | **Description** |
# |-------------|-----------|----------------|
# | **1. Dataset Creation** | 3 | Successfully creates and annotates a custom dataset with at least 50 images and multiple classes in RoboFlow. |
# | **2. Model Training** | 3 | Properly trains a YOLOv8 model on the custom dataset with appropriate hyperparameters. |
# | **3. Model Evaluation** | 2 | Evaluates model performance with appropriate metrics and provides analysis of results. |
# | **4. Custom Detection** | 2 | Implements real-time detection with custom classes and displays results correctly. |
# | **5. Documentation** | 1 | Provides clear documentation of the process, including dataset details and model performance. |
#
# **Total: 10 points**
#
# ## **Tips for Success:**
#
# - **Quality over quantity**: Well-annotated images are more important than many poorly annotated ones
# - **Class balance**: Try to have a similar number of examples for each class
# - **Variety**: Include different angles, lighting conditions, and backgrounds
# - **Augmentation**: Use RoboFlow's augmentation features to expand your dataset

# %% [markdown]
# <p style="text-align: right; font-size:14px; color:gray;">
# <b>Prepared by:</b><br>
# Manuel Eugenio Morocho-Cayamcela
# </p>
