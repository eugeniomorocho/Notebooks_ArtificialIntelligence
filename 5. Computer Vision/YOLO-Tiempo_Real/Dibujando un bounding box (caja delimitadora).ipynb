# %% [markdown]
# Author:
# Manuel Eugenio Morocho Cayamcela, PhD

# %% [markdown]
# # **Tutorial:** Uso de OpenCV para cargar una imagen y dibujar un bounding box (caja delimitadora)
#
# En este tutorial, aprenderás cómo usar la biblioteca OpenCV en Python para cargar una imagen y dibujar un bounding box (caja delimitadora) en ella.
#
# ### **Paso 1: Instalación de OpenCV**
#
# Si aún no tienes instalada la biblioteca OpenCV, puedes instalarla usando pip:

# %%
# %pip install opencv-python

# %% [markdown]
# ### **Paso 2: Importar las bibliotecas necesarias**
#
# Primero, necesitamos importar las bibliotecas que vamos a usar:

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ### **Paso 3: Cargar la imagen**
#
# Usaremos la función `imread` de OpenCV para cargar la imagen:

# %%
# Cargar la imagen
imagenBGR = cv2.imread('/Users/eugenio/Documents/Notebooks_ArtificialIntelligence/5. Computer Vision/YOLO-Tiempo_Real/gato2.jpg')

# %%
# Mostramos el tamaño de la imagen
print('Tamaño de la imagen: ', imagenBGR.shape)

# %% [markdown]
# ### **Paso 4: Dibujar el bounding box**
#
# Para dibujar el bounding box, usaremos la función `rectangle` de OpenCV. Necesitamos especificar las coordenadas del punto **superior izquierdo** $(x_1, y_1)$, y el punto **inferior derecho** $(x_2, y_2)$ del bounding box. En este ejemplo, vamos a dibujar un bounding box alrededor del objeto que está en el centro de la imagen:

# %%
# Definir las coordenadas del bounding box (x1, y1) y (x2, y2) en la imagen (en píxeles)
x1, y1 = 250, 200  # Punto superior izquierdo
x2, y2 = 700, 900  # Punto inferior derecho

# Dibujar el bounding box en la imagen de entrada (imagen) con el método cv2.rectangle (imagen, (x1, y1), (x2, y2), color, grosor)
imagenBGRbox = cv2.rectangle(imagenBGR, (x1, y1), (x2, y2), (0, 255, 0), 15)  # El último argumento es el grosor de la línea

# %% [markdown]
# ### **Paso 5: Mostrar la imagen**
#
# Finalmente, usaremos matplotlib para mostrar la imagen con el bounding box:

# %%
# Convertir la imagen de BGR a RGB
imagenRGBbox = cv2.cvtColor(imagenBGRbox, cv2.COLOR_BGR2RGB)

# Mostrar la imagen
plt.imshow(imagenRGBbox)
plt.show()

# %% [markdown]
# Y eso es todo. Ahora deberías ver tu imagen con un bounding box dibujado en ella. Puedes ajustar las coordenadas del bounding box según sea necesario para que se ajuste al objeto que estás intentando delimitar.

# %% [markdown]
# #### **Actividad**
#
# 1. Carga una imagen que contenga un objeto en ella (mascota, fruta, persona, etc.) usando `cv2.imread` de OpenCV.
# 2. Define las coordenadas $(x_1, y_1)$ y $(x_2, y_2)$ manualmente.
# 3. Dibuja una caja delimitadora **color amarillo** y **grosor de línea** 5, usando el método `cv2.rectangle` de OpenCV.
