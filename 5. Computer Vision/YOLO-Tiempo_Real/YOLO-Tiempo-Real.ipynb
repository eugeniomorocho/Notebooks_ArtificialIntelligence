# %% [markdown]
# Author:
# Manuel Eugenio Morocho Cayamcela, PhD

# %% [markdown]
# # YOLO en Tiempo Real: Detección de Objetos
#
# En este cuaderno de Jupyter exploraremos la tarea de la detección de objetos en tiempo real utilizando YOLO (You Only Look Once), una técnica avanzada de visión por computadora.
#
# Aprenderemos a utilizar YOLO para identificar y localizar diversos objetos en imágenes y secuencias de video. Esta habilidad es esencial en una amplia gama de aplicaciones, desde la conducción autónoma hasta la vigilancia de seguridad, y representa uno de los avances más emocionantes en el campo de la inteligencia artificial y la visión por computadora.
#
# A lo largo de este tutorial, explorarás conceptos clave como:
#
# - Detección de objetos en tiempo real.
# - Configuración de modelos YOLO pre-entrenados.
# - Interpretación de resultados de detección.
# - Aplicaciones prácticas de la detección de objetos.

# %% [markdown]
# Utilizaremos el comando `!pip` para instalar dos paquetes de Python: `opencv-python` y `ultralytics`.
#
# - `opencv-python`: Es un paquete para tareas de visión por computador en Python. Proporciona una variedad de funciones para el procesamiento de imágenes y videos, incluyendo detección de objetos, manipulación de imágenes y extracción de características.
#
# - `ultralytics`: Es un paquete construido sobre PyTorch, que se enfoca principalmente en tareas de visión por computadora como detección de objetos y clasificación de imágenes. Proporciona interfaces fáciles de usar para entrenar y evaluar modelos de aprendizaje profundo para estas tareas.
#
# Al ejecutar este comando, estás instalando estos paquetes en tu entorno de Python para que puedas usarlos en tu código.

# %%
# Instalamos las librerías necesarias
# %pip install opencv-python ultralytics
# Out:
# Requirement already satisfied: opencv-python in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (4.10.0.84)
# Requirement already satisfied: ultralytics in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (8.2.93)
# Requirement already satisfied: numpy>=1.21.2 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from ultralytics) (3.7.5)
# Requirement already satisfied: pillow>=7.1.2 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from ultralytics) (10.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from ultralytics) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: torchvision>=0.9.0 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from ultralytics) (0.17.2)
# Requirement already satisfied: tqdm>=4.64.0 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from ultralytics) (4.66.5)
# Requirement already satisfied: psutil in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from ultralytics) (6.0.0)
# Requirement already satisfied: py-cpuinfo in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from ultralytics) (2.1.4)
# Requirement already satisfied: seaborn>=0.11.0 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from ultralytics) (2.0.6)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (2024.8.30)
# Requirement already satisfied: filelock in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.16.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: sympy in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (1.13.2)
# Requirement already satisfied: networkx in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (2024.9.0)
# Requirement already satisfied: six>=1.5 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Importamos las siguientes bibliotecas en Python:
#
# 1. `ultralytics`: Esta es una biblioteca que proporciona una interfaz para usar modelos de detección de objetos YOLO (You Only Look Once). Permite entrenar, evaluar y utilizar modelos de detección de objetos de manera eficiente.
#
# 2. `cv2` (OpenCV): Esta es una biblioteca popular para el procesamiento de imágenes y videos en Python. Proporciona una amplia gama de funciones para trabajar con imágenes y videos, incluyendo cargar imágenes, realizar operaciones de procesamiento de imágenes, y mostrar imágenes en una ventana, entre otros.
#
# 3. `math`: Este es un módulo estándar de Python que proporciona funciones matemáticas comunes, como funciones trigonométricas, logarítmicas y aritméticas.

# %%
# Importamos las librerías necesarias
from ultralytics import YOLO
import cv2
import math

# %% [markdown]
# Para este tutorial, usaremos un modelo de YOLO preentrenado en una base de datos que contiene imagenes con sus respectivas cordenadas de cuadros delimitadores y etiquetas por cada objeto. La base de datos con la que el modelo fue preentrenado es COCO de Microsoft.

# %%
# Cargamos el modelo YOLO pre-entrenado en COCO dataset
model = YOLO("yolo-Weights/yolov8n.pt")

# %%
# Revisamos las clases que puede detectar el modelo
model.names
# Out:
# {0: 'person',
#  1: 'bicycle',
#  2: 'car',
#  3: 'motorcycle',
#  4: 'airplane',
#  5: 'bus',
#  6: 'train',
#  7: 'truck',
#  8: 'boat',
#  9: 'traffic light',
#  10: 'fire hydrant',
#  11: 'stop sign',
#  12: 'parking meter',
#  13: 'bench',
#  14: 'bird',
#  15: 'cat',
#  16: 'dog',
#  17: 'horse',
#  18: 'sheep',
#  19: 'cow',
#  20: 'elephant',
#  21: 'bear',
#  22: 'zebra',
#  23: 'giraffe',
#  24: 'backpack',
#  25: 'umbrella',
#  26: 'handbag',
#  27: 'tie',
#  28: 'suitcase',
#  29: 'frisbee',
#  30: 'skis',
#  31: 'snowboard',
#  32: 'sports ball',
#  33: 'kite',
#  34: 'baseball bat',
#  35: 'baseball glove',
#  36: 'skateboard',
#  37: 'surfboard',
#  38: 'tennis racket',
#  39: 'bottle',
#  40: 'wine glass',
#  41: 'cup',
#  42: 'fork',
#  43: 'knife',
#  44: 'spoon',
#  45: 'bowl',
#  46: 'banana',
#  47: 'apple',
#  48: 'sandwich',
#  49: 'orange',
#  50: 'broccoli',
#  51: 'carrot',
#  52: 'hot dog',
#  53: 'pizza',
#  54: 'donut',
#  55: 'cake',
#  56: 'chair',
#  57: 'couch',
#  58: 'potted plant',
#  59: 'bed',
#  60: 'dining table',
#  61: 'toilet',
#  62: 'tv',
#  63: 'laptop',
#  64: 'mouse',
#  65: 'remote',
#  66: 'keyboard',
#  67: 'cell phone',
#  68: 'microwave',
#  69: 'oven',
#  70: 'toaster',
#  71: 'sink',
#  72: 'refrigerator',
#  73: 'book',
#  74: 'clock',
#  75: 'vase',
#  76: 'scissors',
#  77: 'teddy bear',
#  78: 'hair drier',
#  79: 'toothbrush'}

# %%
# Definimos una lista de nombres con todas las clases para identificar objetos detectados
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ] # Aquí se enumeran todas las clases

# %%
# Configuramos la captura de video desde la cámara
captura = cv2.VideoCapture(0) # Se abre la cámara por defecto

# Establecemos el ancho y alto de la imagen
captura.set(cv2.CAP_PROP_FRAME_WIDTH, 640) # Ancho de la imagen
captura.set(cv2.CAP_PROP_FRAME_HEIGHT, 480) # Alto de la imagen

# Iniciamos un bucle para procesar los fotogramas de la cámara
while True:
    success, img = captura.read() # Capturamos un fotograma

    # Realizamos la detección de objetos en la imagen capturada (usando el modelo de YOLO pre-entrenado que cargamos anteriormente)
    results = model(img, stream=True)

   # Procesamos los resultados de la detección
    for r in results:
        boxes = r.boxes

        # Iteramos sobre las cajas delimitadoras detectadas
        for box in boxes:
            # Obtenemos las coordenadas de la caja delimitadora
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # Convertimos a valores enteros

            # Dibujamos la caja delimitadora en la imagen
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 1)

            # Obtenemos la confianza de la detección
            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->",confidence)

            # Obtenemos el nombre de la clase detectada
            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            # Mostramos el nombre de la clase junto a la caja delimitadora
            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0) # Color: Azul (formato BGR)
            thickness = 1
            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    # Mostramos la imagen con las detecciones
    cv2.imshow('Webcam', img)

    # Salimos del bucle si se presiona la tecla 'q'
    #if cv2.waitKey(1) == ord('q'):
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

# Liberamos la cámara y cerramos todas las ventanas
captura.release()
cv2.destroyAllWindows()
# Out:
# 2025-04-30 11:36:19.917 Python[48429:9882562] WARNING: AVCaptureDeviceTypeExternal is deprecated for Continuity Cameras. Please use AVCaptureDeviceTypeContinuityCamera and add NSCameraUseContinuityCameraDeviceType to your Info.plist.
# 0: 480x640 (no detections), 111.7ms
# Speed: 6.5ms preprocess, 111.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 110.5ms
# Speed: 2.6ms preprocess, 110.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 97.1ms
# Speed: 2.0ms preprocess, 97.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 83.0ms
# Speed: 1.2ms preprocess, 83.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 155.5ms
# Speed: 1.2ms preprocess, 155.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 mouse, 75.2ms
# Confidence ---> 0.29
# Class name --> mouse
# Speed: 1.4ms preprocess, 75.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 76.7ms
# Speed: 1.7ms preprocess, 76.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 85.3ms
# Speed: 1.7ms preprocess, 85.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 79.0ms
# Speed: 1.0ms preprocess, 79.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 80.5ms
# Speed: 1.3ms preprocess, 80.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 78.2ms
# Speed: 1.2ms preprocess, 78.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 mouse, 82.3ms
# Confidence ---> 0.3
# Class name --> mouse
# Speed: 1.5ms preprocess, 82.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 78.6ms
# Speed: 1.1ms preprocess, 78.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 76.5ms
# Speed: 1.4ms preprocess, 76.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 108.6ms
# Speed: 1.9ms preprocess, 108.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 79.2ms
# Speed: 1.5ms preprocess, 79.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 111.6ms
# Speed: 2.5ms preprocess, 111.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 96.4ms
# Speed: 1.0ms preprocess, 96.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 103.8ms
# Speed: 2.1ms preprocess, 103.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 83.7ms
# Speed: 1.2ms preprocess, 83.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 102.8ms
# Speed: 1.4ms preprocess, 102.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 91.5ms
# Speed: 1.5ms preprocess, 91.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 97.7ms
# Speed: 1.3ms preprocess, 97.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 89.3ms
# Speed: 1.4ms preprocess, 89.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 88.4ms
# Speed: 1.7ms preprocess, 88.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 92.4ms
# Speed: 2.7ms preprocess, 92.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 89.7ms
# Speed: 1.5ms preprocess, 89.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 87.8ms
# Speed: 1.3ms preprocess, 87.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 93.6ms
# Speed: 1.3ms preprocess, 93.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 mouse, 89.5ms
# Confidence ---> 0.26
# Class name --> mouse
# Speed: 1.4ms preprocess, 89.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 90.9ms
# Speed: 1.4ms preprocess, 90.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 97.4ms
# Speed: 1.4ms preprocess, 97.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 86.9ms
# Speed: 2.2ms preprocess, 86.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 mouse, 81.4ms
# Confidence ---> 0.28
# Class name --> mouse
# Speed: 1.4ms preprocess, 81.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 92.8ms
# Speed: 2.4ms preprocess, 92.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 92.6ms
# Speed: 2.3ms preprocess, 92.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 95.5ms
# Speed: 1.4ms preprocess, 95.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 118.3ms
# Speed: 19.3ms preprocess, 118.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 100.2ms
# Speed: 1.5ms preprocess, 100.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 97.3ms
# Speed: 1.5ms preprocess, 97.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 mouse, 89.9ms
# Confidence ---> 0.27
# Class name --> mouse
# Speed: 1.4ms preprocess, 89.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 88.7ms
# Speed: 1.8ms preprocess, 88.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 105.8ms
# Speed: 1.8ms preprocess, 105.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 87.0ms
# Speed: 2.0ms preprocess, 87.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 92.9ms
# Speed: 1.6ms preprocess, 92.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 97.7ms
# Speed: 1.5ms preprocess, 97.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 92.6ms
# Speed: 1.5ms preprocess, 92.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 89.7ms
# Speed: 1.4ms preprocess, 89.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 102.1ms
# Speed: 1.4ms preprocess, 102.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 mouse, 87.9ms
# Confidence ---> 0.31
# Class name --> mouse
# Speed: 1.4ms preprocess, 87.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 mouse, 91.8ms
# Confidence ---> 0.28
# Class name --> mouse
# Speed: 1.3ms preprocess, 91.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 104.1ms
# Speed: 1.3ms preprocess, 104.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 94.5ms
# Speed: 2.0ms preprocess, 94.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 89.7ms
# Speed: 1.2ms preprocess, 89.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 103.9ms
# Speed: 1.7ms preprocess, 103.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 100.0ms
# Speed: 1.4ms preprocess, 100.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 87.6ms
# Speed: 1.6ms preprocess, 87.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 86.4ms
# Speed: 1.5ms preprocess, 86.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 86.2ms
# Speed: 1.5ms preprocess, 86.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 88.4ms
# Speed: 1.4ms preprocess, 88.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 87.4ms
# Speed: 1.5ms preprocess, 87.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 86.8ms
# Speed: 1.7ms preprocess, 86.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 mouse, 87.4ms
# Confidence ---> 0.26
# Class name --> mouse
# Speed: 1.5ms preprocess, 87.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 mouse, 87.2ms
# Confidence ---> 0.26
# Class name --> mouse
# Speed: 1.7ms preprocess, 87.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 88.1ms
# Speed: 1.4ms preprocess, 88.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 173.9ms
# Speed: 1.6ms preprocess, 173.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 88.3ms
# Speed: 1.5ms preprocess, 88.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 mouse, 87.7ms
# Confidence ---> 0.27
# Class name --> mouse
# Speed: 1.4ms preprocess, 87.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 87.3ms
# Speed: 1.6ms preprocess, 87.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 88.9ms
# Speed: 1.4ms preprocess, 88.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 89.8ms
# Speed: 1.8ms preprocess, 89.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 85.5ms
# Speed: 2.2ms preprocess, 85.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 87.2ms
# Speed: 1.4ms preprocess, 87.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 86.7ms
# Speed: 1.4ms preprocess, 86.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 89.5ms
# Speed: 1.6ms preprocess, 89.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 98.2ms
# Speed: 1.4ms preprocess, 98.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 mouse, 103.4ms
# Confidence ---> 0.28
# Class name --> mouse
# Speed: 2.1ms preprocess, 103.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 93.3ms
# Speed: 1.4ms preprocess, 93.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 89.6ms
# Speed: 1.3ms preprocess, 89.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 mouse, 86.4ms
# Confidence ---> 0.26
# Class name --> mouse
# Speed: 1.6ms preprocess, 86.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 mouse, 97.8ms
# Confidence ---> 0.28
# Class name --> mouse
# Speed: 1.8ms preprocess, 97.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 mouse, 103.0ms
# Confidence ---> 0.26
# Class name --> mouse
# Speed: 1.5ms preprocess, 103.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 89.3ms
# Speed: 2.2ms preprocess, 89.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 95.5ms
# Speed: 1.4ms preprocess, 95.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 mouse, 97.4ms
# Confidence ---> 0.3
# Class name --> mouse
# Speed: 1.5ms preprocess, 97.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 93.6ms
# Speed: 1.6ms preprocess, 93.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 94.0ms
# Speed: 1.3ms preprocess, 94.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 86.0ms
# Speed: 1.4ms preprocess, 86.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 mouse, 85.9ms
# Confidence ---> 0.26
# Class name --> mouse
# Speed: 1.4ms preprocess, 85.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 mouse, 85.8ms
# Confidence ---> 0.27
# Class name --> mouse
# Speed: 1.4ms preprocess, 85.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 mouse, 196.4ms
# Confidence ---> 0.28
# Class name --> mouse
# Speed: 17.3ms preprocess, 196.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 89.6ms
# Speed: 1.5ms preprocess, 89.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 86.4ms
# Speed: 1.5ms preprocess, 86.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 mouse, 105.3ms
# Confidence ---> 0.27
# Class name --> mouse
# Speed: 26.0ms preprocess, 105.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 85.9ms
# Speed: 1.6ms preprocess, 85.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 88.3ms
# Speed: 1.4ms preprocess, 88.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 87.5ms
# Speed: 1.4ms preprocess, 87.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 mouse, 89.3ms
# Confidence ---> 0.26
# Class name --> mouse
# Speed: 2.0ms preprocess, 89.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 mouse, 88.7ms
# Confidence ---> 0.27
# Class name --> mouse
# Speed: 1.5ms preprocess, 88.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 86.2ms
# Speed: 1.6ms preprocess, 86.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 89.6ms
# Speed: 1.4ms preprocess, 89.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 mouse, 103.5ms
# Confidence ---> 0.27
# Class name --> mouse
# Speed: 1.4ms preprocess, 103.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 94.6ms
# Speed: 1.5ms preprocess, 94.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 mouse, 92.2ms
# Confidence ---> 0.27
# Class name --> mouse
# Speed: 1.6ms preprocess, 92.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 90.6ms
# Speed: 1.6ms preprocess, 90.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 90.5ms
# Speed: 1.6ms preprocess, 90.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 mouse, 91.3ms
# Confidence ---> 0.29
# Class name --> mouse
# Speed: 1.4ms preprocess, 91.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 90.4ms
# Speed: 1.8ms preprocess, 90.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 89.6ms
# Speed: 1.8ms preprocess, 89.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 88.9ms
# Speed: 1.9ms preprocess, 88.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 89.1ms
# Speed: 1.5ms preprocess, 89.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 91.4ms
# Speed: 1.5ms preprocess, 91.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 90.0ms
# Speed: 1.4ms preprocess, 90.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 88.6ms
# Speed: 1.6ms preprocess, 88.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 89.9ms
# Speed: 1.5ms preprocess, 89.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 95.5ms
# Speed: 1.8ms preprocess, 95.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 234.2ms
# Speed: 2.8ms preprocess, 234.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 167.4ms
# Speed: 3.5ms preprocess, 167.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 88.7ms
# Speed: 1.5ms preprocess, 88.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 92.7ms
# Speed: 1.5ms preprocess, 92.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 mouse, 97.3ms
# Confidence ---> 0.27
# Class name --> mouse
# Speed: 1.5ms preprocess, 97.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 181.5ms
# Speed: 2.1ms preprocess, 181.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 92.0ms
# Speed: 1.4ms preprocess, 92.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 92.3ms
# Speed: 1.5ms preprocess, 92.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 94.0ms
# Speed: 1.5ms preprocess, 94.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 90.6ms
# Speed: 1.5ms preprocess, 90.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 88.8ms
# Speed: 1.5ms preprocess, 88.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 93.9ms
# Speed: 1.4ms preprocess, 93.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 89.6ms
# Speed: 1.4ms preprocess, 89.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 89.8ms
# Speed: 1.6ms preprocess, 89.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 mouse, 88.4ms
# Confidence ---> 0.34
# Class name --> mouse
# Speed: 1.5ms preprocess, 88.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 96.7ms
# Speed: 1.4ms preprocess, 96.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 91.1ms
# Speed: 1.6ms preprocess, 91.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 86.3ms
# Speed: 1.5ms preprocess, 86.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 mouse, 86.2ms
# Confidence ---> 0.28
# Class name --> mouse
# Speed: 1.6ms preprocess, 86.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 87.0ms
# Speed: 1.4ms preprocess, 87.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 89.1ms
# Speed: 1.4ms preprocess, 89.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 85.9ms
# Speed: 1.6ms preprocess, 85.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 88.2ms
# Speed: 1.4ms preprocess, 88.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 95.9ms
# Speed: 1.4ms preprocess, 95.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 88.4ms
# Speed: 1.5ms preprocess, 88.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 92.9ms
# Speed: 1.3ms preprocess, 92.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 115.2ms
# Speed: 1.7ms preprocess, 115.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 mouse, 96.7ms
# Confidence ---> 0.28
# Class name --> mouse
# Speed: 1.6ms preprocess, 96.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 mouse, 85.6ms
# Confidence ---> 0.26
# Class name --> mouse
# Speed: 2.0ms preprocess, 85.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 89.3ms
# Speed: 1.5ms preprocess, 89.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 96.2ms
# Speed: 1.5ms preprocess, 96.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 106.5ms
# Speed: 2.5ms preprocess, 106.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 90.9ms
# Speed: 1.4ms preprocess, 90.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 103.1ms
# Speed: 1.6ms preprocess, 103.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 89.8ms
# Speed: 1.5ms preprocess, 89.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 98.4ms
# Speed: 1.6ms preprocess, 98.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 99.3ms
# Speed: 1.5ms preprocess, 99.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 90.2ms
# Speed: 2.1ms preprocess, 90.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 120.7ms
# Speed: 3.8ms preprocess, 120.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 117.1ms
# Speed: 1.7ms preprocess, 117.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 117.7ms
# Speed: 2.9ms preprocess, 117.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 102.6ms
# Speed: 1.4ms preprocess, 102.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 91.7ms
# Speed: 1.5ms preprocess, 91.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 94.3ms
# Speed: 1.4ms preprocess, 94.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 91.9ms
# Speed: 2.2ms preprocess, 91.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 93.6ms
# Speed: 1.7ms preprocess, 93.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 88.2ms
# Confidence ---> 0.46
# Class name --> person
# Speed: 1.4ms preprocess, 88.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 87.6ms
# Speed: 1.2ms preprocess, 87.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 85.5ms
# Speed: 1.3ms preprocess, 85.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 87.0ms
# Speed: 1.4ms preprocess, 87.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 86.6ms
# Speed: 1.4ms preprocess, 86.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 87.3ms
# Speed: 1.4ms preprocess, 87.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 85.0ms
# Speed: 1.5ms preprocess, 85.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 89.8ms
# Speed: 2.8ms preprocess, 89.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 88.5ms
# Speed: 1.6ms preprocess, 88.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 mouse, 85.0ms
# Confidence ---> 0.44
# Class name --> mouse
# Speed: 2.0ms preprocess, 85.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 87.5ms
# Speed: 1.3ms preprocess, 87.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 85.3ms
# Speed: 1.5ms preprocess, 85.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 84.6ms
# Speed: 1.5ms preprocess, 84.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 87.9ms
# Speed: 1.4ms preprocess, 87.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 88.3ms
# Speed: 1.3ms preprocess, 88.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 171.3ms
# Speed: 1.5ms preprocess, 171.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 88.4ms
# Speed: 1.4ms preprocess, 88.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 92.6ms
# Speed: 1.6ms preprocess, 92.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 85.7ms
# Speed: 1.6ms preprocess, 85.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 87.7ms
# Speed: 1.0ms preprocess, 87.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 96.2ms
# Speed: 1.4ms preprocess, 96.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 85.5ms
# Speed: 1.5ms preprocess, 85.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 87.6ms
# Speed: 1.4ms preprocess, 87.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 87.3ms
# Speed: 1.4ms preprocess, 87.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 toothbrush, 86.1ms
# Confidence ---> 0.8
# Class name --> toothbrush
# Speed: 1.4ms preprocess, 86.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 toothbrush, 86.1ms
# Confidence ---> 0.53
# Class name --> toothbrush
# Speed: 1.6ms preprocess, 86.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 toothbrush, 103.8ms
# Confidence ---> 0.63
# Class name --> toothbrush
# Speed: 1.5ms preprocess, 103.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 toothbrush, 91.5ms
# Confidence ---> 0.68
# Class name --> toothbrush
# Speed: 1.7ms preprocess, 91.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 toothbrush, 92.0ms
# Confidence ---> 0.69
# Class name --> toothbrush
# Speed: 1.4ms preprocess, 92.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 toothbrush, 87.4ms
# Confidence ---> 0.52
# Class name --> toothbrush
# Speed: 1.4ms preprocess, 87.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 toothbrush, 87.9ms
# Confidence ---> 0.63
# Class name --> toothbrush
# Speed: 1.1ms preprocess, 87.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 toothbrush, 90.6ms
# Confidence ---> 0.32
# Class name --> toothbrush
# Speed: 1.4ms preprocess, 90.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 88.1ms
# Speed: 1.5ms preprocess, 88.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 88.1ms
# Speed: 1.4ms preprocess, 88.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 87.4ms
# Speed: 1.5ms preprocess, 87.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 88.1ms
# Confidence ---> 0.7
# Class name --> chair
# Speed: 1.9ms preprocess, 88.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 90.0ms
# Confidence ---> 0.84
# Class name --> chair
# Speed: 1.6ms preprocess, 90.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 89.6ms
# Confidence ---> 0.88
# Class name --> chair
# Speed: 1.5ms preprocess, 89.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 90.8ms
# Confidence ---> 0.85
# Class name --> chair
# Speed: 1.6ms preprocess, 90.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 chairs, 88.6ms
# Confidence ---> 0.81
# Class name --> chair
# Confidence ---> 0.28
# Class name --> chair
# Speed: 1.4ms preprocess, 88.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 chairs, 88.9ms
# Confidence ---> 0.81
# Class name --> chair
# Confidence ---> 0.27
# Class name --> chair
# Speed: 1.3ms preprocess, 88.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 chairs, 91.1ms
# Confidence ---> 0.83
# Class name --> chair
# Confidence ---> 0.3
# Class name --> chair
# Speed: 1.5ms preprocess, 91.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 chairs, 164.3ms
# Confidence ---> 0.83
# Class name --> chair
# Confidence ---> 0.34
# Class name --> chair
# Speed: 1.4ms preprocess, 164.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 88.2ms
# Confidence ---> 0.79
# Class name --> chair
# Speed: 1.4ms preprocess, 88.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 chairs, 85.0ms
# Confidence ---> 0.85
# Class name --> chair
# Confidence ---> 0.26
# Class name --> chair
# Speed: 1.5ms preprocess, 85.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 chairs, 88.8ms
# Confidence ---> 0.82
# Class name --> chair
# Confidence ---> 0.36
# Class name --> chair
# Speed: 1.5ms preprocess, 88.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 chairs, 87.0ms
# Confidence ---> 0.8
# Class name --> chair
# Confidence ---> 0.28
# Class name --> chair
# Speed: 1.6ms preprocess, 87.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 91.7ms
# Confidence ---> 0.82
# Class name --> chair
# Speed: 1.5ms preprocess, 91.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 2 beds, 89.3ms
# Confidence ---> 0.9
# Class name --> chair
# Confidence ---> 0.26
# Class name --> bed
# Confidence ---> 0.26
# Class name --> bed
# Speed: 1.4ms preprocess, 89.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 chairs, 88.1ms
# Confidence ---> 0.89
# Class name --> chair
# Confidence ---> 0.33
# Class name --> chair
# Speed: 1.5ms preprocess, 88.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 85.6ms
# Confidence ---> 0.89
# Class name --> chair
# Speed: 1.5ms preprocess, 85.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 87.1ms
# Confidence ---> 0.89
# Class name --> chair
# Speed: 1.4ms preprocess, 87.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 1 bed, 89.5ms
# Confidence ---> 0.84
# Class name --> chair
# Confidence ---> 0.28
# Class name --> bed
# Speed: 1.1ms preprocess, 89.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 87.5ms
# Confidence ---> 0.88
# Class name --> chair
# Speed: 2.4ms preprocess, 87.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 91.2ms
# Confidence ---> 0.86
# Class name --> chair
# Speed: 1.5ms preprocess, 91.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 chairs, 89.2ms
# Confidence ---> 0.86
# Class name --> chair
# Confidence ---> 0.3
# Class name --> chair
# Speed: 1.4ms preprocess, 89.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 chairs, 89.0ms
# Confidence ---> 0.87
# Class name --> chair
# Confidence ---> 0.33
# Class name --> chair
# Speed: 1.6ms preprocess, 89.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 chairs, 90.9ms
# Confidence ---> 0.8
# Class name --> chair
# Confidence ---> 0.33
# Class name --> chair
# Speed: 1.4ms preprocess, 90.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 chairs, 89.4ms
# Confidence ---> 0.82
# Class name --> chair
# Confidence ---> 0.36
# Class name --> chair
# Speed: 1.7ms preprocess, 89.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 chairs, 88.5ms
# Confidence ---> 0.86
# Class name --> chair
# Confidence ---> 0.33
# Class name --> chair
# Speed: 1.4ms preprocess, 88.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 chairs, 93.0ms
# Confidence ---> 0.87
# Class name --> chair
# Confidence ---> 0.37
# Class name --> chair
# Speed: 1.4ms preprocess, 93.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 chairs, 88.5ms
# Confidence ---> 0.91
# Class name --> chair
# Confidence ---> 0.42
# Class name --> chair
# Speed: 1.5ms preprocess, 88.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 chairs, 1 bed, 89.8ms
# Confidence ---> 0.91
# Class name --> chair
# Confidence ---> 0.38
# Class name --> bed
# Confidence ---> 0.26
# Class name --> chair
# Speed: 1.4ms preprocess, 89.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 chairs, 1 book, 90.9ms
# Confidence ---> 0.93
# Class name --> chair
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.28
# Class name --> chair
# Speed: 1.5ms preprocess, 90.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 87.6ms
# Confidence ---> 0.95
# Class name --> chair
# Speed: 1.5ms preprocess, 87.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 suitcase, 1 chair, 87.9ms
# Confidence ---> 0.92
# Class name --> chair
# Confidence ---> 0.4
# Class name --> suitcase
# Speed: 1.6ms preprocess, 87.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 85.1ms
# Confidence ---> 0.91
# Class name --> chair
# Speed: 1.4ms preprocess, 85.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 84.2ms
# Confidence ---> 0.88
# Class name --> chair
# Speed: 1.4ms preprocess, 84.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 82.7ms
# Confidence ---> 0.89
# Class name --> chair
# Speed: 1.4ms preprocess, 82.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 1 bed, 84.3ms
# Confidence ---> 0.86
# Class name --> chair
# Confidence ---> 0.39
# Class name --> bed
# Speed: 1.4ms preprocess, 84.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 84.6ms
# Confidence ---> 0.89
# Class name --> chair
# Speed: 1.4ms preprocess, 84.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 1 bed, 168.6ms
# Confidence ---> 0.86
# Class name --> chair
# Confidence ---> 0.35
# Class name --> bed
# Speed: 1.3ms preprocess, 168.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 suitcase, 1 chair, 1 bed, 85.7ms
# Confidence ---> 0.89
# Class name --> chair
# Confidence ---> 0.29
# Class name --> bed
# Confidence ---> 0.26
# Class name --> suitcase
# Speed: 1.8ms preprocess, 85.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 suitcase, 1 chair, 83.7ms
# Confidence ---> 0.89
# Class name --> chair
# Confidence ---> 0.51
# Class name --> suitcase
# Speed: 1.5ms preprocess, 83.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 suitcase, 1 chair, 84.2ms
# Confidence ---> 0.89
# Class name --> chair
# Confidence ---> 0.29
# Class name --> suitcase
# Speed: 1.4ms preprocess, 84.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 1 bed, 83.6ms
# Confidence ---> 0.89
# Class name --> chair
# Confidence ---> 0.28
# Class name --> bed
# Speed: 1.4ms preprocess, 83.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 84.3ms
# Confidence ---> 0.9
# Class name --> chair
# Speed: 1.4ms preprocess, 84.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 83.5ms
# Confidence ---> 0.86
# Class name --> chair
# Speed: 1.3ms preprocess, 83.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 1 bed, 84.4ms
# Confidence ---> 0.88
# Class name --> chair
# Confidence ---> 0.48
# Class name --> bed
# Speed: 1.4ms preprocess, 84.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 89.2ms
# Confidence ---> 0.85
# Class name --> chair
# Speed: 1.1ms preprocess, 89.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 83.5ms
# Confidence ---> 0.91
# Class name --> chair
# Speed: 1.4ms preprocess, 83.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 1 bed, 93.5ms
# Confidence ---> 0.92
# Class name --> chair
# Confidence ---> 0.29
# Class name --> bed
# Speed: 1.3ms preprocess, 93.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 86.8ms
# Confidence ---> 0.92
# Class name --> chair
# Speed: 1.5ms preprocess, 86.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 1 bed, 83.7ms
# Confidence ---> 0.9
# Class name --> chair
# Confidence ---> 0.3
# Class name --> bed
# Speed: 1.5ms preprocess, 83.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 1 bed, 86.1ms
# Confidence ---> 0.92
# Class name --> chair
# Confidence ---> 0.29
# Class name --> bed
# Speed: 1.4ms preprocess, 86.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 1 bed, 95.5ms
# Confidence ---> 0.9
# Class name --> chair
# Confidence ---> 0.31
# Class name --> bed
# Speed: 1.3ms preprocess, 95.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 86.8ms
# Confidence ---> 0.91
# Class name --> chair
# Speed: 1.1ms preprocess, 86.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 1 bed, 85.2ms
# Confidence ---> 0.91
# Class name --> chair
# Confidence ---> 0.27
# Class name --> bed
# Speed: 1.4ms preprocess, 85.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 1 bed, 86.6ms
# Confidence ---> 0.91
# Class name --> chair
# Confidence ---> 0.32
# Class name --> bed
# Speed: 1.3ms preprocess, 86.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 85.1ms
# Confidence ---> 0.91
# Class name --> chair
# Speed: 1.3ms preprocess, 85.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 1 bed, 84.2ms
# Confidence ---> 0.92
# Class name --> chair
# Confidence ---> 0.26
# Class name --> bed
# Speed: 1.4ms preprocess, 84.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 83.2ms
# Confidence ---> 0.91
# Class name --> chair
# Speed: 1.6ms preprocess, 83.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 83.6ms
# Confidence ---> 0.91
# Class name --> chair
# Speed: 2.4ms preprocess, 83.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 85.2ms
# Confidence ---> 0.92
# Class name --> chair
# Speed: 1.6ms preprocess, 85.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 85.7ms
# Confidence ---> 0.91
# Class name --> chair
# Speed: 1.5ms preprocess, 85.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 1 bed, 92.6ms
# Confidence ---> 0.92
# Class name --> chair
# Confidence ---> 0.3
# Class name --> bed
# Speed: 1.4ms preprocess, 92.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 87.7ms
# Confidence ---> 0.9
# Class name --> chair
# Speed: 1.4ms preprocess, 87.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 85.2ms
# Confidence ---> 0.92
# Class name --> chair
# Speed: 1.3ms preprocess, 85.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 1 bed, 101.7ms
# Confidence ---> 0.91
# Class name --> chair
# Confidence ---> 0.28
# Class name --> bed
# Speed: 6.1ms preprocess, 101.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 84.6ms
# Confidence ---> 0.92
# Class name --> chair
# Speed: 1.4ms preprocess, 84.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 85.4ms
# Confidence ---> 0.91
# Class name --> chair
# Speed: 1.4ms preprocess, 85.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 1 remote, 85.5ms
# Confidence ---> 0.92
# Class name --> chair
# Confidence ---> 0.83
# Class name --> remote
# Speed: 1.5ms preprocess, 85.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 1 remote, 84.8ms
# Confidence ---> 0.92
# Class name --> chair
# Confidence ---> 0.72
# Class name --> remote
# Speed: 1.7ms preprocess, 84.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 1 remote, 112.7ms
# Confidence ---> 0.92
# Class name --> chair
# Confidence ---> 0.82
# Class name --> remote
# Speed: 1.5ms preprocess, 112.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 1 bed, 1 remote, 87.0ms
# Confidence ---> 0.95
# Class name --> remote
# Confidence ---> 0.92
# Class name --> chair
# Confidence ---> 0.27
# Class name --> bed
# Speed: 1.4ms preprocess, 87.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 remote, 84.9ms
# Confidence ---> 0.92
# Class name --> chair
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.46
# Class name --> remote
# Speed: 1.4ms preprocess, 84.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 remote, 84.3ms
# Confidence ---> 0.93
# Class name --> chair
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.55
# Class name --> remote
# Speed: 1.3ms preprocess, 84.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 remote, 83.5ms
# Confidence ---> 0.92
# Class name --> chair
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.38
# Class name --> remote
# Speed: 1.4ms preprocess, 83.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 remote, 86.3ms
# Confidence ---> 0.92
# Class name --> chair
# Confidence ---> 0.89
# Class name --> remote
# Confidence ---> 0.8
# Class name --> person
# Speed: 1.3ms preprocess, 86.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 remote, 86.3ms
# Confidence ---> 0.89
# Class name --> remote
# Confidence ---> 0.89
# Class name --> chair
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.4ms preprocess, 86.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 remote, 83.4ms
# Confidence ---> 0.9
# Class name --> chair
# Confidence ---> 0.86
# Class name --> remote
# Confidence ---> 0.84
# Class name --> person
# Speed: 1.5ms preprocess, 83.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 remote, 85.2ms
# Confidence ---> 0.9
# Class name --> chair
# Confidence ---> 0.87
# Class name --> remote
# Confidence ---> 0.83
# Class name --> person
# Speed: 1.6ms preprocess, 85.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 bed, 1 remote, 84.7ms
# Confidence ---> 0.91
# Class name --> chair
# Confidence ---> 0.85
# Class name --> remote
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.3
# Class name --> bed
# Speed: 1.4ms preprocess, 84.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 bed, 1 remote, 86.4ms
# Confidence ---> 0.89
# Class name --> remote
# Confidence ---> 0.89
# Class name --> chair
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.27
# Class name --> bed
# Speed: 1.4ms preprocess, 86.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 remote, 85.4ms
# Confidence ---> 0.91
# Class name --> chair
# Confidence ---> 0.9
# Class name --> remote
# Confidence ---> 0.81
# Class name --> person
# Speed: 1.5ms preprocess, 85.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 remote, 84.7ms
# Confidence ---> 0.9
# Class name --> remote
# Confidence ---> 0.89
# Class name --> chair
# Confidence ---> 0.82
# Class name --> person
# Speed: 1.4ms preprocess, 84.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 remote, 87.7ms
# Confidence ---> 0.91
# Class name --> chair
# Confidence ---> 0.88
# Class name --> remote
# Confidence ---> 0.83
# Class name --> person
# Speed: 1.4ms preprocess, 87.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 bed, 1 remote, 87.2ms
# Confidence ---> 0.9
# Class name --> chair
# Confidence ---> 0.89
# Class name --> remote
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.3
# Class name --> bed
# Speed: 1.4ms preprocess, 87.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 remote, 88.0ms
# Confidence ---> 0.9
# Class name --> chair
# Confidence ---> 0.88
# Class name --> remote
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.4ms preprocess, 88.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 remote, 87.0ms
# Confidence ---> 0.9
# Class name --> chair
# Confidence ---> 0.9
# Class name --> remote
# Confidence ---> 0.84
# Class name --> person
# Speed: 1.6ms preprocess, 87.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 remote, 83.8ms
# Confidence ---> 0.89
# Class name --> chair
# Confidence ---> 0.88
# Class name --> remote
# Confidence ---> 0.71
# Class name --> person
# Speed: 1.9ms preprocess, 83.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 remote, 87.3ms
# Confidence ---> 0.9
# Class name --> remote
# Confidence ---> 0.89
# Class name --> chair
# Confidence ---> 0.66
# Class name --> person
# Speed: 1.6ms preprocess, 87.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 remote, 87.6ms
# Confidence ---> 0.86
# Class name --> chair
# Confidence ---> 0.75
# Class name --> remote
# Confidence ---> 0.63
# Class name --> person
# Speed: 1.5ms preprocess, 87.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 remote, 88.7ms
# Confidence ---> 0.85
# Class name --> chair
# Confidence ---> 0.85
# Class name --> remote
# Confidence ---> 0.63
# Class name --> person
# Speed: 1.4ms preprocess, 88.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 bed, 1 remote, 85.5ms
# Confidence ---> 0.88
# Class name --> chair
# Confidence ---> 0.84
# Class name --> remote
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Confidence ---> 0.28
# Class name --> bed
# Speed: 1.4ms preprocess, 85.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 remote, 168.9ms
# Confidence ---> 0.89
# Class name --> chair
# Confidence ---> 0.88
# Class name --> remote
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Speed: 1.4ms preprocess, 168.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 remote, 92.9ms
# Confidence ---> 0.92
# Class name --> remote
# Confidence ---> 0.86
# Class name --> chair
# Confidence ---> 0.57
# Class name --> person
# Speed: 1.1ms preprocess, 92.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# ...
#
# 0: 480x640 1 chair, 1 bed, 121.5ms
# Confidence ---> 0.91
# Class name --> chair
# Confidence ---> 0.27
# Class name --> bed
# Speed: 1.8ms preprocess, 121.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 122.6ms
# Confidence ---> 0.92
# Class name --> chair
# Speed: 1.6ms preprocess, 122.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 106.5ms
# Confidence ---> 0.91
# Class name --> chair
# Speed: 1.9ms preprocess, 106.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 105.2ms
# Confidence ---> 0.93
# Class name --> chair
# Speed: 2.0ms preprocess, 105.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 102.9ms
# Confidence ---> 0.92
# Class name --> chair
# Speed: 2.1ms preprocess, 102.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 104.5ms
# Confidence ---> 0.92
# Class name --> chair
# Speed: 2.5ms preprocess, 104.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 1 bed, 113.2ms
# Confidence ---> 0.92
# Class name --> chair
# Confidence ---> 0.29
# Class name --> bed
# Speed: 2.5ms preprocess, 113.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 1 bed, 110.3ms
# Confidence ---> 0.92
# Class name --> chair
# Confidence ---> 0.31
# Class name --> bed
# Speed: 4.0ms preprocess, 110.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 1 bed, 112.9ms
# Confidence ---> 0.92
# Class name --> chair
# Confidence ---> 0.28
# Class name --> bed
# Speed: 1.7ms preprocess, 112.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 116.7ms
# Confidence ---> 0.91
# Class name --> chair
# Speed: 2.1ms preprocess, 116.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 1 bed, 121.1ms
# Confidence ---> 0.91
# Class name --> chair
# Confidence ---> 0.26
# Class name --> bed
# Speed: 2.6ms preprocess, 121.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 1 bed, 127.1ms
# Confidence ---> 0.92
# Class name --> chair
# Confidence ---> 0.3
# Class name --> bed
# Speed: 1.7ms preprocess, 127.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 1 bed, 108.0ms
# Confidence ---> 0.92
# Class name --> chair
# Confidence ---> 0.26
# Class name --> bed
# Speed: 2.1ms preprocess, 108.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 106.7ms
# Confidence ---> 0.9
# Class name --> chair
# Speed: 1.6ms preprocess, 106.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 106.4ms
# Confidence ---> 0.92
# Class name --> chair
# Speed: 3.8ms preprocess, 106.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 109.4ms
# Confidence ---> 0.93
# Class name --> chair
# Speed: 1.7ms preprocess, 109.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 143.2ms
# Confidence ---> 0.92
# Class name --> chair
# Speed: 3.9ms preprocess, 143.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 1 bed, 107.3ms
# Confidence ---> 0.92
# Class name --> chair
# Confidence ---> 0.27
# Class name --> bed
# Speed: 1.8ms preprocess, 107.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 144.1ms
# Confidence ---> 0.91
# Class name --> chair
# Speed: 2.5ms preprocess, 144.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 137.1ms
# Confidence ---> 0.92
# Class name --> chair
# Speed: 1.8ms preprocess, 137.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 133.8ms
# Confidence ---> 0.92
# Class name --> chair
# Speed: 1.6ms preprocess, 133.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 128.0ms
# Confidence ---> 0.91
# Class name --> chair
# Speed: 2.3ms preprocess, 128.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 1 bed, 129.4ms
# Confidence ---> 0.9
# Class name --> chair
# Confidence ---> 0.33
# Class name --> bed
# Speed: 2.9ms preprocess, 129.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 127.6ms
# Confidence ---> 0.91
# Class name --> chair
# Speed: 2.3ms preprocess, 127.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 122.7ms
# Confidence ---> 0.91
# Class name --> chair
# Speed: 3.0ms preprocess, 122.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 114.1ms
# Confidence ---> 0.91
# Class name --> chair
# Speed: 1.9ms preprocess, 114.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 16
#      13  results = model(img, stream=True)
#      15 # Procesamos los resultados de la detección
# ---> 16  for r in results:
#      17      boxes = r.boxes
#      19      # Iteramos sobre las cajas delimitadoras detectadas
#
# File ~/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages/torch/utils/_contextlib.py:35, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      32 try:
#      33     # Issuing `None` to a generator fires it up
#      34     with ctx_factory():
# ---> 35         response = gen.send(None)
#      37     while True:
#      38         try:
#      39             # Forward the response to our caller and get its next request
#
# File ~/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages/ultralytics/engine/predictor.py:254, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     252 # Inference
#     253 with profilers[1]:
# --> 254     preds = self.inference(im, *args, **kwargs)
#     255     if self.args.embed:
#     256         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File ~/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages/ultralytics/engine/predictor.py:142, in BasePredictor.inference(self, im, *args, **kwargs)
#     136 """Runs inference on a given image using the specified model and arguments."""
#     137 visualize = (
#     138     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     139     if self.args.visualize and (not self.source_type.tensor)
#     140     else False
#     141 )
# --> 142 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File ~/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages/ultralytics/nn/autobackend.py:456, in AutoBackend.forward(self, im, augment, visualize, embed)
#     454 # PyTorch
#     455 if self.pt or self.nn_module:
# --> 456     y = self.model(im, augment=augment, visualize=visualize, embed=embed)
#     458 # TorchScript
#     459 elif self.jit:
#
# File ~/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages/ultralytics/nn/tasks.py:108, in BaseModel.forward(self, x, *args, **kwargs)
#     106 if isinstance(x, dict):  # for cases of training and validating while training.
#     107     return self.loss(x, *args, **kwargs)
# --> 108 return self.predict(x, *args, **kwargs)
#
# File ~/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages/ultralytics/nn/tasks.py:126, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     124 if augment:
#     125     return self._predict_augment(x)
# --> 126 return self._predict_once(x, profile, visualize, embed)
#
# File ~/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages/ultralytics/nn/tasks.py:147, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     145 if profile:
#     146     self._profile_one_layer(m, x, dt)
# --> 147 x = m(x)  # run
#     148 y.append(x if m.i in self.save else None)  # save output
#     149 if visualize:
#
# File ~/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages/ultralytics/nn/modules/head.py:57, in Detect.forward(self, x)
#      54     return self.forward_end2end(x)
#      56 for i in range(self.nl):
# ---> 57     x[i] = torch.cat((self.cv2[i](x[i]), self.cv3[i](x[i])), 1)
#      58 if self.training:  # Training path
#      59     return x
#
# File ~/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages/ultralytics/nn/modules/conv.py:54, in Conv.forward_fuse(self, x)
#      52 def forward_fuse(self, x):
#      53     """Perform transposed convolution of 2D data."""
# ---> 54     return self.act(self.conv(x))
#
# File ~/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages/torch/nn/modules/conv.py:460, in Conv2d.forward(self, input)
#     459 def forward(self, input: Tensor) -> Tensor:
# --> 460     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/Documents/Notebooks_ArtificialIntelligence/.venv/lib/python3.11/site-packages/torch/nn/modules/conv.py:456, in Conv2d._conv_forward(self, input, weight, bias)
#     452 if self.padding_mode != 'zeros':
#     453     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     454                     weight, bias, self.stride,
#     455                     _pair(0), self.dilation, self.groups)
# --> 456 return F.conv2d(input, weight, bias, self.stride,
#     457                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # 🧠 Tarea: Despliegue del Sistema YOLOv8 en Jetson Nano 2GB
#
# ## 📌 Objetivo
#
# Implementar un sistema de detección en tiempo real utilizando YOLOv8 en una Jetson Nano 2GB conectada a la misma red local, con una cámara web USB.
#
# ---
#
# ## 🔐 Acceso a la Jetson Nano
#
# Se les proporcionará:
# - Nombre de usuario
# - Dirección IP de la Jetson Nano
# - Contraseña
#
# Usen la terminal de su computador para conectarse:
#
# ```bash
# ssh usuario@ip_de_jetson

# %% [markdown]
# # 📂 Opción 1: Carrera de Matemática
#
# Clonar su repositorio desde GitHub y ejecutar el sistema directamente en la Jetson Nano.
#
# ✅ Pasos:
#
# ### 1. Clonar el repositorio
# git clone https://github.com/usuario/repositorio.git
#
# ### 2. Acceder al directorio del proyecto
# cd repositorio
#
# ### 3. Crear entorno virtual e instalar dependencias
# python3 -m venv env
# source env/bin/activate
# pip install -r requirements.txt
#
# ### 4. Ejecutar el sistema
# python YOLO-Tiempo-Real.py

# %% [markdown]
# # 📦 Opción 2: Carrera de Ciencias Computacionales
#
# Desplegar el sistema dentro de un contenedor Docker.
#
# ✅ Crear un archivo Dockerfile en el repositorio:

# %% [markdown]
# ### Dockerfile
# FROM nvcr.io/nvidia/l4t-pytorch:r32.7.1-pth1.11-py3
# RUN apt-get update && apt-get install -y python3-pip libopencv-dev
# RUN pip3 install ultralytics opencv-python
#
# COPY . /app
# WORKDIR /app
#
# CMD ["python3", "YOLO-Tiempo-Real.py"]

# %% [markdown]
# ## 🐳 Pasos para construir y ejecutar:
#
# ### 1. Clonar su repositorio
# git clone https://github.com/usuario/repositorio.git
# cd repositorio
#
# ### 2. Construir la imagen Docker
# sudo docker build -t yolov8-detector .
#
# ### 3. Ejecutar el contenedor
# sudo docker run --rm -it --net=host --device=/dev/video0 yolov8-detector

# %% [markdown]
# # 📝 Entregable
#
# - Confirmación de funcionamiento con captura de pantalla o foto del sistema en ejecución.
# - Código actualizado y funcional en su repositorio de GitHub.
